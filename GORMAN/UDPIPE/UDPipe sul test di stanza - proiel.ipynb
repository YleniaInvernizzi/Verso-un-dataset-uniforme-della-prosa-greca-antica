# %%
# %pip install pandas ufal.udpipe scikit-learn seaborn matplotlib numpy tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (2.2.2)
# Requirement already satisfied: ufal.udpipe in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (1.3.1.1)
# Requirement already satisfied: scikit-learn in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (1.6.0)
# Requirement already satisfied: seaborn in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (3.9.4)
# Requirement already satisfied: numpy in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (1.26.4)
# Requirement already satisfied: tqdm in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: colorama in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\lcolo\anaconda3\envs\tesi\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import re 
from ufal.udpipe import Model, Pipeline, ProcessingError 
import sys
import csv 
import tqdm
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# Funzioni

# %%
# Function to evaluate predictions
def evaluate_predictions(predictions, gold_data):
    correct_lemmas = 0
    correct_pos = 0
    total = len(gold_data)
    wrong_lemmas = []
    wrong_postag = []

    for pred, gold in zip(predictions, gold_data):
        # Compare lemma
        if pred['LEMMA'] == gold['@lemma']:
            correct_lemmas += 1
        else:
            if gold['@lemma']!= 'punc1':
                wrong_lemmas.append([gold['@form'],gold['@lemma'],pred['LEMMA']])    
        # Compare POS tag
        if pred['XPOS'] == gold['@postag']:
            correct_pos += 1
        else:
            wrong_postag.append([gold['@form'],gold['@postag'],pred['XPOS']])    

    return total, correct_lemmas, correct_pos, pd.DataFrame(wrong_lemmas, columns = ['Form','Gold', 'Pred']), pd.DataFrame(wrong_postag, columns = ['Form','Gold', 'Pred']) 


# Function to evaluate predictions
def evaluate_predictions_per_position(predictions, gold_data):
    correct_lemmas = 0
    pos_accuracies = {i: [] for i in range(9)}  # Track accuracy for each position

    for pred, gold in zip(predictions, gold_data):
        # Compare lemma
        if pred['LEMMA'] == gold['@lemma']:
            correct_lemmas += 1

        # Compare POS tags by each character position, ensuring they are strings and of length 9
        gold_pos = str(gold['@postag'])
        pred_pos = str(pred['XPOS'])
        if type(gold_pos)==str:
          if len(gold_pos) == 9 and len(pred_pos) == 9:
              for i in range(9):
                  pos_accuracies[i].append(1 if pred_pos[i] == gold_pos[i] else 0)

    total = len(gold_data)
    return total, correct_lemmas, pos_accuracies

# %%
def convert_conllu_to_blank(input_path, output_path):
    """
    Converte un file .conllu annotato in una versione "vuota" per UDPipe, 
    mantenendo solo le colonne ID e FORM e salvando il risultato.
    
    Args:
        input_path (str): percorso del file .conllu di input.
        output_path (str): percorso del file .conllu da scrivere.
    """
    with open(input_path, 'r', encoding='utf-8') as infile:
        lines = infile.readlines()

    blank_lines = []
    for line in lines:
        line = line.rstrip('\n')
        if line.startswith('#') or line.strip() == "":
            blank_lines.append(line)
        else:
            cols = line.split('\t')
            if len(cols) >= 2:
                blank_line = f"{cols[0]}\t{cols[1]}\t" + "\t".join(["_"] * 8)
                blank_lines.append(blank_line)

    with open(output_path, 'w', encoding='utf-8') as outfile:
        outfile.write('\n'.join(blank_lines) + '\n')

# %% [markdown]
# Preprocessing

# %% [markdown]
# UDPipe

# %%
#Scaricare il modello linguistico: Da runnare una sola volta, LO DEVO RIRUNNARE PER SCARICARE PROIEL
#!curl -k https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3131/ancient_greek-proiel-ud-2.5-191206.udpipe -O ancient_greek-proiel-ud-2.5-191206.udpipe

# %% [markdown]
# Controllo importante! Dopo aver usato UDPipe, controllare che la lunghezza del dataframe finale corrisponda.

# %%
MODEL_PATHS = {
    'perseus': {
        'file': 'ancient_greek-perseus-ud-2.5-191206.udpipe',
        'url': 'https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3131/ancient_greek-perseus-ud-2.5-191206.udpipe'
    },
    'proiel': {
        'file': 'ancient_greek-proiel-ud-2.5-191206.udpipe',
        'url': 'https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3131/ancient_greek-proiel-ud-2.5-191206.udpipe'
    }
}

# %%
#load the model for ancient greek
#model = Model.load(MODEL_PATHS['perseus']['file'])
model = Model.load(MODEL_PATHS['proiel']['file'])

# %%
if not model:                                           #dice solo se il modello è stato caricato
    sys.stderr.write("Cannot load model from file")
    sys.exit(1)
sys.stderr.write('done\n')
# Out:
# done
# 5

# %%
# Create a pipeline
pipeline = Pipeline(model, "conllu", Pipeline.DEFAULT, Pipeline.DEFAULT, "conllu")      #sto passando il modello, la modalità horizontal, le pipeline di lemma e pos, output in connllu

# %%
import glob
from conllu import parse

input_dir = "file udpipe input output con test stanza/input"        #connllu con solo frase e form ma colonne vuote, che il modello deve riempire
output_file = "file udpipe input output con test stanza/output/output_stanzatest_udpipe_proiel.conllu"            #Connllu in cui ha fatto lemmatizzazione e pos il modello 


for input_file in tqdm.tqdm(glob.glob(os.path.join(input_dir, "*.conllu"))):
    filename = os.path.basename(input_file)

    try: 
        with open(input_file, "r", encoding="utf-8") as f:
            conllu_text = f.read()

        sentences = parse(conllu_text)

        processed_sentences = []
        for i, sentence in enumerate(sentences):
            conllu_str = sentence.serialize()
            result = pipeline.process(conllu_str)

            if not result.strip(): #mancano degli id in output  no anomalies 
                print(f"⚠️ Empty output for sentence {i+1} in file {filename}")
                print(sentence)
            else:
                processed_sentences.append(result)

        final_output = "\n".join(processed_sentences)

        with open(output_file, "w", encoding="utf-8") as f:
            f.write(final_output)

    except Exception as e:
        print(f"❌ Failed on file: {filename}")
        print(f"Error: {e}")
# Out:
# 100%|██████████| 1/1 [01:11<00:00, 71.12s/it]

# %% [markdown]
# Performance

# %%
def conllu_to_csv(input_file, output_file):
    # Assicurati che la directory di output esista
    output_dir = os.path.dirname(output_file)
    if output_dir: # Crea solo se non è vuoto
        os.makedirs(output_dir, exist_ok=True)

    with open(input_file, "r", encoding="utf-8") as conllu_file, open(output_file, "w", encoding="utf-8", newline="") as csv_file:
        writer = csv.writer(csv_file)
        
        # Scrive l'intestazione del CSV (adatta le colonne secondo il tuo caso)
        writer.writerow(["ID", "FORM", "LEMMA", "UPOS", "XPOS", "FEATS", "HEAD", "DEPREL", "DEPS", "MISC"])
        
        for line in conllu_file:
            line = line.strip()
            if not line or line.startswith("#"):
                # Ignora righe vuote e commenti
                continue
            # Divide la riga in colonne basandosi sulla tabulazione
            columns = line.split("\t")
            writer.writerow(columns)

# %%
#convert conllu to csv 
#Conversione degli output UDPipe conllu to csv

conllu_to_csv('file udpipe input output con test stanza/output/output_stanzatest_udpipe_proiel.conllu','file udpipe input output con test stanza/output/output_stanzatest_udpipe_proiel.csv')

# %%
import pandas as pd

# Classe per il calcolo delle metriche
class Score:
    def __init__(self, correct, gold_total, system_total, aligned_total=None):
        self.correct = correct
        self.gold_total = gold_total
        self.system_total = system_total
        self.aligned_total = aligned_total or min(gold_total, system_total)
        self.precision = correct / system_total if system_total else 0.0
        self.recall = correct / gold_total if gold_total else 0.0
        self.f1 = 2 * correct / (system_total + gold_total) if (system_total + gold_total) else 0.0
        self.aligned_accuracy = correct / self.aligned_total if self.aligned_total else 0.0

    def as_dict(self):
        return {
            'correct': self.correct,
            'gold_total': self.gold_total,
            'system_total': self.system_total,
            'precision': self.precision,
            'recall': self.recall,
            'f1': self.f1,
            'aligned_accuracy': self.aligned_accuracy
        }

# Funzione di valutazione
def evaluate_predictions(predictions, gold_data):
    correct_lemmas = 0
    correct_pos = 0
    total = len(gold_data)
    wrong_lemmas = []
    wrong_postag = []

    for pred, gold in zip(predictions, gold_data):
        gold_lemma = gold['@lemma']
        gold_pos = gold['@postag']
        pred_lemma = pred['LEMMA']
        pred_pos = pred['XPOS']

        if pred_lemma == gold_lemma:
            correct_lemmas += 1
        else:
            if gold_lemma != 'punc1':
                wrong_lemmas.append([gold['@form'], gold_lemma, pred_lemma])

        if pred_pos == gold_pos:
            correct_pos += 1
        else:
            wrong_postag.append([gold['@form'], gold_pos, pred_pos])

    # Crea oggetti Score per lemma e POS
    lemma_score = Score(correct_lemmas, total, total)
    pos_score = Score(correct_pos, total, total)

    # Restituisce le metriche e gli errori come DataFrame
    return {
        'total': total,
        'lemma_score': lemma_score,
        'pos_score': pos_score,
        'wrong_lemmas': pd.DataFrame(wrong_lemmas, columns=['Form', 'Gold', 'Pred']),
        'wrong_postag': pd.DataFrame(wrong_postag, columns=['Form', 'Gold', 'Pred'])
    }
#ACCURACY: noi possiamo fare solo questa, non possiamo fare le altre metriche, perchè non distinguiamo tra classi. non abbiamo positivi e negativi!

# %%
def estrai_sent_id(file_path):
    """
    Estrae tutti i valori di `sent_id` da un file CoNLL-U.

    Parametri:
        file_path (str): Percorso al file CoNLL-U.

    Ritorna:
        list[str]: Lista di stringhe contenenti i sent_id trovati.
    """
    sent_ids = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line.startswith('# sent_id ='):
                sent_id = line[len('# sent_id ='):].strip()
                sent_ids.append(sent_id)
    return sent_ids

file = "C:/Users/lcolo/Desktop/TESI/GRCGorman/dati/train_dev_test/grc_gorman-ud-test.conllu"
lista_sent_id = estrai_sent_id(file)
print(lista_sent_id)
from pathlib import Path
import pandas as pd

df_list = []

for sent_id in lista_sent_id:
    try:
        dir_opera, indice = sent_id.split('#')
        csv_path = Path('output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag') / dir_opera / f"{indice}.csv"
        csv_path = csv_path.resolve()

        print(f"🔍 Controllo file: {csv_path}")

        if not csv_path.exists():
            print(f"⚠️ File non trovato: {csv_path}")
            continue

        df = pd.read_csv(csv_path, sep=";")  # ← qui la correzione
        df_list.append(df)

    except Exception as e:
        print(f"❌ Errore con sent_id {sent_id}: {e}")

if df_list:
    df_concat = pd.concat(df_list, ignore_index=True)
    print(f"✅ CSV concatenato con {len(df_concat)} righe.")
else:
    print("❌ Nessun file CSV valido trovato.")
# Out:
# ['aeschines-1-1-50-bu1.xml#164', 'aeschines-1-1-50-bu1.xml#165', 'aeschines-1-1-50-bu1.xml#166', 'aeschines-1-1-50-bu1.xml#167', 'aeschines-1-1-50-bu1.xml#168', 'aeschines-1-1-50-bu1.xml#169', 'aeschines-1-1-50-bu1.xml#170', 'aeschines-1-1-50-bu1.xml#171', 'aeschines-1-1-50-bu1.xml#172', 'aeschines-1-1-50-bu1.xml#173', 'aeschines-1-1-50-bu1.xml#174', 'aeschines-1-1-50-bu1.xml#175', 'aeschines-1-1-50-bu1.xml#176', 'aeschines-1-1-50-bu1.xml#177', 'aeschines-1-1-50-bu1.xml#178', 'aeschines-1-1-50-bu1.xml#179', 'aeschines-1-1-50-bu1.xml#180', 'aeschines-1-1-50-bu1.xml#181', 'aeschines-1-1-50-bu1.xml#182', 'aeschines-1-1-50-bu1.xml#183', 'aeschines-1-101-150-bu1.xml#146', 'aeschines-1-101-150-bu1.xml#147', 'aeschines-1-101-150-bu1.xml#148', 'aeschines-1-101-150-bu1.xml#149', 'aeschines-1-101-150-bu1.xml#150', 'aeschines-1-101-150-bu1.xml#151', 'aeschines-1-101-150-bu1.xml#152', 'aeschines-1-101-150-bu1.xml#153', 'aeschines-1-101-150-bu1.xml#154', 'aeschines-1-101-150-bu1.xml#155', 'aeschines-1-101-150-bu1.xml#156', 'aeschines-1-101-150-bu1.xml#157', 'aeschines-1-101-150-bu1.xml#158', 'aeschines-1-101-150-bu1.xml#159', 'aeschines-1-101-150-bu1.xml#160', 'aeschines-1-101-150-bu1.xml#161', 'aeschines-1-101-150-bu1.xml#162', 'aeschines-1-151-196-bu1.xml#144', 'aeschines-1-151-196-bu1.xml#145', 'aeschines-1-151-196-bu1.xml#146', 'aeschines-1-151-196-bu1.xml#147', 'aeschines-1-151-196-bu1.xml#148', 'aeschines-1-151-196-bu1.xml#149', 'aeschines-1-151-196-bu1.xml#150', 'aeschines-1-151-196-bu1.xml#151', 'aeschines-1-151-196-bu1.xml#152', 'aeschines-1-151
csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\appian-bc-1-8-10-bu1.xml\247.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\297.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\298.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\299.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\300.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\301.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\302.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\303.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\304.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\aristotle-politics-book-1-bu1.xml\305.csv
# ...
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\184.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\185.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\186.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\187.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\188.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\189.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\190.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\191.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-1-5-7-bu1.xml\192.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\368.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\369.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\370.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\371.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\372.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\373.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\374.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\375.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\376.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\377.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\378.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\379.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\380.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\381.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\382.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\383.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\384.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\385.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\386.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\387.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\388.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\389.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\390.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\391.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\392.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\393.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\394.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\395.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\396.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\397.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\398.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\399.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\400.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\401.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\402.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\403.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\404.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\405.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\406.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\407.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\408.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\409.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\410.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-2-bu1.xml\411.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\412.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\413.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\414.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\415.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\416.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\417.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\418.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\419.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\420.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\421.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\422.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\423.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\424.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\425.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\426.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\427.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\428.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\429.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\430.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\431.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\432.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\433.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\434.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\435.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\436.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\437.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\438.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\439.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\440.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\441.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\442.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\443.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\444.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\445.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\446.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\447.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\448.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\449.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\450.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\451.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\452.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\453.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\454.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\455.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\456.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\457.csv
# 🔍 Controllo file: C:\Users\lcolo\Desktop\TESI\CODICI DEFINITIVI DIZ UNICO\output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\xen-hell-3-bu1.xml\458.csv
# ✅ CSV concatenato con 53708 righe.

# %%
output_udpipe = pd.read_csv('file udpipe input output con test stanza/output/output_stanzatest_udpipe_proiel.csv')
opera = df_concat
predictions = output_udpipe[['FORM', 'LEMMA', 'XPOS']].to_dict('records')       
gold_data = opera [['@form', '@lemma', '@postag']].to_dict('records')
results = evaluate_predictions(predictions, gold_data)

print("Lemma Metrics:", results['lemma_score'].as_dict())
print("POS Metrics:", results['pos_score'].as_dict())

# Per visualizzare gli errori
print(results['wrong_lemmas'].head())
print(results['wrong_postag'].head())
# Out:
# Lemma Metrics: {'correct': 37744, 'gold_total': 53708, 'system_total': 53708, 'precision': 0.7027630892976837, 'recall': 0.7027630892976837, 'f1': 0.7027630892976837, 'aligned_accuracy': 0.7027630892976837}
# POS Metrics: {'correct': 0, 'gold_total': 53708, 'system_total': 53708, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'aligned_accuracy': 0.0}
#        Form   Gold   Pred
# 0        δ᾽     δέ     δ᾽
# 1       ἄρα    ἄρα    ἆρα
# 2         ,   punc      ,
# 3  τράπηται  τρέπω  τράπω
# 4         ,   punc      ,
#        Form       Gold Pred
# 0       ἐὰν  c--------   G-
# 1        δ᾽  d--------   V-
# 2       ἄρα  d--------   Df
# 3  ὑπακούσῃ  v3sasa---   V-
# 4       μέν  d--------   Df

# %%
#correct sono quanti lemmi in questo caso udpipe ha azzeccato uguali a stanza rispetto al totale.
#gold total è il numero totale di token, di form di stanza del test. system total è uguale ma sono quelle di udpipe. 
#aligned acuracy è semplicemente l'accuracy.

# %%
#questo codice è servito per creare un conllu vuoto con le frasi presenti nel test di Stanza. l'esigenza è dovuta al fatto che il conllu fornito da Giovanni non era coerente con i miei file. 
'''from pathlib import Path
import pandas as pd

output_lines = []

for sent_id in lista_sent_id:
    try:
        dir_opera, indice = sent_id.split('#')
        csv_path = Path('output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag') / dir_opera / f"{indice}.csv"
        csv_path = csv_path.resolve()

        print(f"🔍 Controllo file: {csv_path}")
        if not csv_path.exists():
            print(f"⚠️ File non trovato: {csv_path}")
            continue

        df = pd.read_csv(csv_path, sep=';')
        df = df.reset_index(drop=True)
        df["@id"] = range(1, len(df) + 1)

        # Header
        output_lines.append(f"# sent_id = {sent_id}")
        text_line = " ".join(df["@form"].astype(str))
        output_lines.append(f"# text = {text_line}")

        # Riga per ogni token (solo form, gli altri 9 campi sono "_")
        for i, row in df.iterrows():
            token_line = f"{row['@id']}\t{row['@form']}\t_\t_\t_\t_\t_\t_\t_\t_"
            output_lines.append(token_line)

        output_lines.append("")  # Riga vuota tra frasi

    except Exception as e:
        print(f"❌ Errore con {sent_id}: {e}")

# Salva il file
with open("frasi_udpipe_vuote.conllu", "w", encoding="utf-8") as f:
    f.write("\n".join(output_lines))

print("✅ File conllu (vuoto) generato: frasi_udpipe_vuote.conllu")'''
# Out:
# 'from pathlib import Path\nimport pandas as pd\n\noutput_lines = []\n\nfor sent_id in lista_sent_id:\n    try:\n        dir_opera, indice = sent_id.split(\'#\')\n        csv_path = Path(\'output_gorman_no_anomalies_aggiornati_per_lemmi_e_postag\') / dir_opera / f"{indice}.csv"\n        csv_path = csv_path.resolve()\n\n        print(f"🔍 Controllo file: {csv_path}")\n        if not csv_path.exists():\n            print(f"⚠️ File non trovato: {csv_path}")\n            continue\n\n        df = pd.read_csv(csv_path, sep=\';\')\n        df = df.reset_index(drop=True)\n        df["@id"] = range(1, len(df) + 1)\n\n        # Header\n        output_lines.append(f"# sent_id = {sent_id}")\n        text_line = " ".join(df["@form"].astype(str))\n        output_lines.append(f"# text = {text_line}")\n\n        # Riga per ogni token (solo form, gli altri 9 campi sono "_")\n        for i, row in df.iterrows():\n            token_line = f"{row[\'@id\']}\t{row[\'@form\']}\t_\t_\t_\t_\t_\t_\t_\t_"\n            output_lines.append(token_line)\n\n        output_lines.append("")  # Riga vuota tra frasi\n\n    except Exception as e:\n        print(f"❌ Errore con {sent_id}: {e}")\n\n# Salva il file\nwith open("frasi_udpipe_vuote.conllu", "w", encoding="utf-8") as f:\n    f.write("\n".join(output_lines))\n\nprint("✅ File conllu (vuoto) generato: frasi_udpipe_vuote.conllu")'
