# %%
import os 
import re
import pandas as pd
import numpy as np

# %%
dir_lis = os.listdir('output_gorman_con_relation')

# Lista per salvare tutti i percorsi dei file CSV
csv_file_paths = []

# Directory principale che contiene le sottodirectory
main_directory = 'output_gorman_con_relation'

#per ogni cartella in output gorman devo ottenere la directory completa della singola cartella dell'autore. per farlo itero col ciclo for su tutte le cartelle presenti in gorman e concateno,
#per ottenere la directory della cartella della singola opera, la main directory col nome della cratella.
#per farlo uso la funzione di os che si chiama os.path join che fa una concatenazione di stringhe.
for folder in dir_lis:
  folder_path = os.path.join(main_directory, folder)
  #check is folder_path is folder dir
  if os.path.isdir(folder_path):  #ora voglio per ogni cartella una lista vuota poi da andare a riempire con i csv di ogni singola cartella.
    singola_cartella = []
    for file in os.listdir(folder_path): #per ogni file che sta nella mia cartella
      if file.endswith('.csv'): #controllo per vedere se sono davvero tutti csv i file.
        file_path = os.path.join(folder_path, file) #se il file è un csv la sua directory completa me la metti nella lista.
        singola_cartella.append(file_path)

  csv_file_paths.append(singola_cartella)
csv_file_paths = sorted(csv_file_paths)
# Lista per conservare i DataFrame filtrati
#per ogni lista creo una lista di di dataframe. questi sono i csv filtrati con le info che mi servono.
#ora lo trasformo in una funzione che prenda in input una lista di csv.
def filter_dataframe(csv_file_paths):
  dataframes_tot = [] #è una lista vuota in cui mettere i dataframe filtrati.
# Leggi, filtra e aggiungi ogni DataFrame alla lista
  for file_path in csv_file_paths:
    # Leggi il CSV in un DataFrame
      df = pd.read_csv(file_path)

    # Filtra il DataFrame mantenendo solo le righe dove '@lemma' è una stringa
      df_filtered = df[df['@lemma'].apply(lambda x: isinstance(x, str))]

    # Aggiungi il DataFrame filtrato alla lista
      dataframes_tot.append(df_filtered)

# Visualizza le prime righe di ciascun DataFrame per controllare la struttura
      data_info = {f"File {i+1}": df.head() for i, df in enumerate(dataframes_tot)}

# Mostra la struttura dei dati
      #for file_name, df_head in data_info.items():
       # print(f"\n{file_name}:")
        #print(df_head)
  return dataframes_tot
# Function to extract the numeric part from the filename
def extract_number(file_path):
    # Use regex to find the numeric part of the filename
    return int(re.search(r'(\d+)\.csv$', file_path).group(1))
all_sorted_csv_filepaths = []
for folder in csv_file_paths:
  #print(folder)
  sorted_files = sorted(folder, key=extract_number)
  all_sorted_csv_filepaths.append(sorted_files)

# %%
dataframes = [filter_dataframe(lis) for lis in all_sorted_csv_filepaths]

# %%
list_dir = os.listdir('output_gorman_con_relation')
all_opera = {}
for i,opera in enumerate(list_dir):
    full_text = ''
    for sent in dataframes[i]:
        full_text += ' '.join(sent['@form'])
        all_opera[opera] = full_text

# %%
all_opera = {}
for i,opera in enumerate(list_dir):
    all_data = pd.concat(dataframes[i],ignore_index=True)
   
    #for sent in dataframes[i]:
    full_text = ' '.join(all_data['@form'])
    all_opera[opera] = full_text

# %%
opera_names = list(all_opera.keys())

# %%
#STEP ci indica il numero di frasi per chunk 
STEP = 18
all_opera_split = {}
for key in opera_names:
    joint_text = []
    text = all_opera[key]
    sents = text.split('.')
    for i in range(0, len(sents), STEP):
        joint_text.append('.'.join(sents[i:i+STEP])+'.')
    all_opera_split[key] = joint_text

# %%
'''import os
import shutil
dir = 'output_gorman'

lis_dir = os.listdir(dir)
ateneo = []
for i in lis_dir:
    if i.split('-')[0]=='athen13' or i.split('-')=='athen12':
        ateneo.append(i)
ateneo_to_remove = ['athen13-10-19-2019.xml',
 'athen13-20-29-2019.xml',
 'athen13-40-49-2019.xml',
 'athen13-70-79-2019.xml',
 'athen13-80-89-2019.xml',
 'athen13-90-95-2019.xml',
  'athen13-60-69-2019.xml',
 'athen13-50-59-2019.xml',
 'athen13-30-39-2019.xml',
 'athen13-1-9-2019.xml']
dest = 'output_gorman_ateneo_rimossi'
for i in ateneo_to_remove:
    shutil.move(dir+'/'+i,dest +'/' + i )'''
# Out:
# "import os\nimport shutil\ndir = 'output_gorman'\n\nlis_dir = os.listdir(dir)\nateneo = []\nfor i in lis_dir:\n    if i.split('-')[0]=='athen13' or i.split('-')=='athen12':\n        ateneo.append(i)\nateneo_to_remove = ['athen13-10-19-2019.xml',\n 'athen13-20-29-2019.xml',\n 'athen13-40-49-2019.xml',\n 'athen13-70-79-2019.xml',\n 'athen13-80-89-2019.xml',\n 'athen13-90-95-2019.xml',\n  'athen13-60-69-2019.xml',\n 'athen13-50-59-2019.xml',\n 'athen13-30-39-2019.xml',\n 'athen13-1-9-2019.xml']\ndest = 'output_gorman_ateneo_rimossi'\nfor i in ateneo_to_remove:\n    shutil.move(dir+'/'+i,dest +'/' + i )"

# %%
'''import os
import shutil
dir = 'output_gorman_con_relation'

lis_dir = os.listdir(dir)
ateneo = []
for i in lis_dir:
    if i.split('-')[0]=='athen13' or i.split('-')=='athen12':
        ateneo.append(i)
ateneo_to_remove = ['athen13-10-19-2019.xml',
 'athen13-20-29-2019.xml',
 'athen13-40-49-2019.xml',
 'athen13-70-79-2019.xml',
 'athen13-80-89-2019.xml',
 'athen13-90-95-2019.xml',
  'athen13-60-69-2019.xml',
 'athen13-50-59-2019.xml',
 'athen13-30-39-2019.xml',
 'athen13-1-9-2019.xml']
dest = 'output_gorman_ateneo_con_relation_rimossi'
for i in ateneo_to_remove:
    shutil.move(dir+'/'+i,dest +'/' + i )'''
# Out:
# "import os\nimport shutil\ndir = 'output_gorman_con_relation'\n\nlis_dir = os.listdir(dir)\nateneo = []\nfor i in lis_dir:\n    if i.split('-')[0]=='athen13' or i.split('-')=='athen12':\n        ateneo.append(i)\nateneo_to_remove = ['athen13-10-19-2019.xml',\n 'athen13-20-29-2019.xml',\n 'athen13-40-49-2019.xml',\n 'athen13-70-79-2019.xml',\n 'athen13-80-89-2019.xml',\n 'athen13-90-95-2019.xml',\n  'athen13-60-69-2019.xml',\n 'athen13-50-59-2019.xml',\n 'athen13-30-39-2019.xml',\n 'athen13-1-9-2019.xml']\ndest = 'output_gorman_ateneo_con_relation_rimossi'\nfor i in ateneo_to_remove:\n    shutil.move(dir+'/'+i,dest +'/' + i )"

# %%
len(opera_names)
# Out:
# 142

# %%
opera_names
# Out:
#  'josephus-bj-1-3-5-bu2.xml',
#  'josephus-bj-1-6-10-bu1.xml',
#  'lysias-1-bu1.xml',
#  'lysias-12-bu1.xml',
#  'lysias-13-bu1.xml',
#  'lysias-14-bu1.xml',
#  'lysias-15.xml',
#  'lysias-19-bu1.xml',
#  'lysias-23-bu1.xml',
#  'plato-apology.xml',
#  'plut-alcib-1-17-bu1.xml',
#  'plut-alcib-18-39-bu1.xml',
#  'plut-fortuna-romanorum-bu1.xml',
#  'plutarch-alex-fort-aut-virt-bu2.xml',
#  'plutarch-lycurgus-1-15-bu4.xml',
#  'plutarch-lycurgus-16-31-bu2.xml',
#  'polybius-10-1-10-bu1.xml',
#  'polybius-10-11-20-bu1.xml',
#  'polybius-10-21-35-bu2.xml',
#  'polybius-10-36-49-bu1.xml',
#  'polybius-2-1-10-bu1.xml',
#  'polybius-2-11-20-bu1.xml',
#  'polybius-2-21-30-bu2.xml',
#  'polybius-2-31-40-bu2.xml',
#  'polybius-2-41-50-bu1.xml',
#  'polybius-2-51-60-bu1.xml',
#  'polybius-2-61-71-bu2.xml',
#  'polybius-21-1-10-bu1.xml',
#  'polybius-21-11-20-bu1.xml',
#  'polybius-21-21-30-bu1.xml',
#  'polybius-21-31-47-bu1.xml',
#  'polybius-6-16-30-bu1.xml',
#  'polybius-6-2-15-bu1.xml',
#  'polybius-6-31-45-bu1.xml',
#  'polybius-6-46-58-bu1.xml',
#  'polybius-9-1-20-bu1.xml',
#  'polybius-9-21-33-bu1.xml',
#  'polybius-9-34-45-bu1.xml',
#  'polybius1-1-9-2017.xml',
#  'polybius1-10-19-2017.xml',
#  'polybius1-20-29-2017.xml',
#  'polybius1-30-39-2017.xml',
#  'polybius1-40-49-2017.xml',
#  'polybius1-50-59-2017.xml',
#  'polybius1-60-69-2017.xml',
#  'polybius1-70-79-2017.xml',
#  'polybius1-80-88-2017.xml',
#  'ps-xen-ath-pol-bu2.xml',
#  'thuc-1-1-20-bu5.xml',
#  'thuc-1-101-120-bu2.xml',
#  'thuc-1-121-146-bu3.xml',
#  'thuc-1-21-40-bu4.xml',
#  'thuc-1-41-60-bu3.xml',
#  'thuc-1-61-80-bu3.xml',
#  'thuc-1-81-100-bu2.xml',
#  'thuc-3-1-20-bu1.xml',
#  'thuc-3-21-40-bu1.xml',
#  'xen-cyr-1-1-2-bu1.xml',
#  'xen-cyr-1-3-4-bu1.xml',
#  'xen-cyr-1-5-bu1.xml',
#  'xen-cyr-1-6-bu1.xml',
#  'xen-cyr-7-1-3-tree.xml',
#  'xen-cyr-7-4-5-tree.xml',
#  'xen-cyr-8-1-8-4-bu1.xml',
#  'xen-cyr-8-5-7-bu1.xml',
#  'xen-cyr-8-8-bu1.xml',
#  'xen-hell-1-1-4-bu2.xml',
#  'xen-hell-1-5-7-bu1.xml',
#  'xen-hell-2-bu1.xml',
#  'xen-hell-3-bu1.xml']

# %% [markdown]
# Basandoti sulla tua conoscenza del greco data da Perseus Project e LSJ fai la lemmatizzazione del seguente testo, generando un dataframe csv che ha come prima colonna la form @form, e come colonne successive tutti i possibili lemmi di quella forma con i nomi @lemmaPerseus1, @lemmaPerseus2 etc... disponi ogni forma su una nuova riga:

# %%
#%pip install --upgrade openai

# %%
'''from openai import OpenAI 
import os

## Set the API key and model name
MODEL="gpt-4o"
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "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")
)'''
# Out:
# 'from openai import OpenAI \nimport os\n\n## Set the API key and model name\nMODEL="gpt-4o"\nclient = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "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")\n)'

# %%
'''opera_names[33]'''
# Out:
# 'opera_names[33]'

# %%
'''# Il testo da analizzare
greek_text = all_opera[opera_names[33]]

prompt = f"""Basandoti sulla tua conoscenza del greco data da Perseus Project e LSJ fai la lemmatizzazione del seguente testo, generando un dataframe csv che ha come prima colonna la form @form, e come colonne successive tutti i possibili lemmi di quella forma con i nomi @lemmaPerseus1, @lemmaPerseus2 etc... disponi ogni forma su una nuova riga:

{greek_text}
"""

completion = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "Sei un assistente utile e competente in greco antico, con accesso virtuale a Perseus Project e LSJ."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0
)

# Stampa la risposta del modello
print(completion.choices[0].message.content)'''
# Out:
# '# Il testo da analizzare\ngreek_text = all_opera[opera_names[33]]\n\nprompt = f"""Basandoti sulla tua conoscenza del greco data da Perseus Project e LSJ fai la lemmatizzazione del seguente testo, generando un dataframe csv che ha come prima colonna la form @form, e come colonne successive tutti i possibili lemmi di quella forma con i nomi @lemmaPerseus1, @lemmaPerseus2 etc... disponi ogni forma su una nuova riga:\n\n{greek_text}\n"""\n\ncompletion = client.chat.completions.create(\n    model=MODEL,\n    messages=[\n        {"role": "system", "content": "Sei un assistente utile e competente in greco antico, con accesso virtuale a Perseus Project e LSJ."},\n        {"role": "user", "content": prompt}\n    ],\n    temperature=0.0\n)\n\n# Stampa la risposta del modello\nprint(completion.choices[0].message.content)'

# %%
'''# Il testo da analizzare
greek_text = all_opera[opera_names[0]]

prompt = f"""Basandoti sulla tua conoscenza del greco data da Perseus Project e LSJ fai il pos tagging in formato AGDT (ANCIENT GREEK DEPENDENCY TREEBANK, per es. per l'avverbio è così d--------) 
delle particelle 
del seguente testo, generando un dataframe csv che ha come prima colonna la form @form,
 e come SECONDA COLONNA il pos tagging delle particelle e un trattino delle non particelle. 
 Per particelle greche intendo ad esempio ἢ,ἤπερ,'ἀλλʼ', 'ἀλλά', 'ἀλλὰ', 'ἀλλ’',"οὔτε", "μήτε","οὐτ'", "μὴτ'","οὔθʼ", "μὴθʼ",'μήθ’','μήτ’','οὔτ’','οὔτʼ','οὔθ’',"εἴτε","-τ'", "τ'",
   "τε", "-τ' ", "τ' ", "τε ", 'τέ','-θ’','θ’','-τ’','τ’','-τε','τʼ','μέν', '-δέ', 'δέ','μὲν', 'δὲ', '-δʼ','-δ’','δʼ,','δ’','-δὲ','δʼ',δή etc. 
   Cerca di capire dal contesto se si tratta di avverbi o di congiunzioni coordinanti o di congiunzioni subordinanti etc. e fai il pos tagging di conseguenza... 
   disponi ogni forma su una nuova riga. Fai tutto il testo per intero:

{greek_text}
"""

completion = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "Sei un assistente utile e competente in greco antico, con accesso virtuale a Perseus Project e LSJ."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0, max_tokens = 16384
)

# Stampa la risposta del modello
print(completion.choices[0].message.content)'''
# Out:
# '# Il testo da analizzare\ngreek_text = all_opera[opera_names[0]]\n\nprompt = f"""Basandoti sulla tua conoscenza del greco data da Perseus Project e LSJ fai il pos tagging in formato AGDT (ANCIENT GREEK DEPENDENCY TREEBANK, per es. per l\'avverbio è così d--------) \ndelle particelle \ndel seguente testo, generando un dataframe csv che ha come prima colonna la form @form,\n e come SECONDA COLONNA il pos tagging delle particelle e un trattino delle non particelle. \n Per particelle greche intendo ad esempio ἢ,ἤπερ,\'ἀλλʼ\', \'ἀλλά\', \'ἀλλὰ\', \'ἀλλ’\',"οὔτε", "μήτε","οὐτ\'", "μὴτ\'","οὔθʼ", "μὴθʼ",\'μήθ’\',\'μήτ’\',\'οὔτ’\',\'οὔτʼ\',\'οὔθ’\',"εἴτε","-τ\'", "τ\'",\n   "τε", "-τ\' ", "τ\' ", "τε ", \'τέ\',\'-θ’\',\'θ’\',\'-τ’\',\'τ’\',\'-τε\',\'τʼ\',\'μέν\', \'-δέ\', \'δέ\',\'μὲν\', \'δὲ\', \'-δʼ\',\'-δ’\',\'δʼ,\',\'δ’\',\'-δὲ\',\'δʼ\',δή etc. \n   Cerca di capire dal contesto se si tratta di avverbi o di congiunzioni coordinanti o di congiunzioni subordinanti etc. e fai il pos tagging di conseguenza... \n   disponi ogni forma su una nuova riga. Fai tutto il testo per intero:\n\n{greek_text}\n"""\n\ncompletion = client.chat.completions.create(\n    model=MODEL,\n    messages=[\n        {"role": "system", "content": "Sei un assistente utile e competente in greco antico, con accesso virtuale a Perseus Project e LSJ."},\n        {"role": "user", "content": prompt}\n    ],\n    temperature=0.0, max_tokens = 16384\n)\n\n# Stampa la risposta del modello\nprint(completion.choices[0].message.content)'

# %%
#stampare i vari chunks in celle separate  
from IPython.display import display
num = 117
for i in range(len(all_opera_split[opera_names[num]])):
    display(opera_names[num])
    display(all_opera_split[opera_names[num]][i])
# Out:
# 'polybius1-70-79-2017.xml'
# %%
dir_lis = os.listdir('output_gorman_con_relation')

# Lista per salvare tutti i percorsi dei file CSV
csv_file_paths = []

# Directory principale che contiene le sottodirectory
main_directory = 'output_gorman_con_relation'

#per ogni cartella in output gorman devo ottenere la directory completa della singola cartella dell'autore. per farlo itero col ciclo for su tutte le cartelle presenti in gorman e concateno,
#per ottenere la directory della cartella della singola opera, la main directory col nome della cratella.
#per farlo uso la funzione di os che si chiama os.path join che fa una concatenazione di stringhe.
for folder in dir_lis:
  folder_path = os.path.join(main_directory, folder)
  #check is folder_path is folder dir
  if os.path.isdir(folder_path):  #ora voglio per ogni cartella una lista vuota poi da andare a riempire con i csv di ogni singola cartella.
    singola_cartella = []
    for file in os.listdir(folder_path): #per ogni file che sta nella mia cartella
      if file.endswith('.csv'): #controllo per vedere se sono davvero tutti csv i file.
        file_path = os.path.join(folder_path, file) #se il file è un csv la sua directory completa me la metti nella lista.
        singola_cartella.append(file_path)

  csv_file_paths.append(singola_cartella)
csv_file_paths = sorted(csv_file_paths)
# Lista per conservare i DataFrame filtrati
#per ogni lista creo una lista di di dataframe. questi sono i csv filtrati con le info che mi servono.
#ora lo trasformo in una funzione che prenda in input una lista di csv.
def filter_dataframe(csv_file_paths):
  dataframes_tot = [] #è una lista vuota in cui mettere i dataframe filtrati.
# Leggi, filtra e aggiungi ogni DataFrame alla lista
  for file_path in csv_file_paths:
    # Leggi il CSV in un DataFrame
      df = pd.read_csv(file_path)

    # Filtra il DataFrame mantenendo solo le righe dove '@lemma' è una stringa
      df_filtered = df[df['@lemma'].apply(lambda x: isinstance(x, str))]

    # Aggiungi il DataFrame filtrato alla lista
      dataframes_tot.append(df_filtered)

# Visualizza le prime righe di ciascun DataFrame per controllare la struttura
      data_info = {f"File {i+1}": df.head() for i, df in enumerate(dataframes_tot)}

# Mostra la struttura dei dati
      #for file_name, df_head in data_info.items():
       # print(f"\n{file_name}:")
        #print(df_head)
  return dataframes_tot
# Function to extract the numeric part from the filename
def extract_number(file_path):
    # Use regex to find the numeric part of the filename
    return int(re.search(r'(\d+)\.csv$', file_path).group(1))
all_sorted_csv_filepaths = []
for folder in csv_file_paths:
  #print(folder)
  sorted_files = sorted(folder, key=extract_number)
  all_sorted_csv_filepaths.append(sorted_files)

# %% [markdown]
# qui è solo GORMAN!!!

# %%
dataframes = [filter_dataframe(lis) for lis in all_sorted_csv_filepaths] #Filtra il DataFrame mantenendo solo le righe dove '@lemma' è una stringa

# %%
#concatenazione dei dataframes di un'opera in un unico dataframe 
#nell'esempio abbiamo la prima opera. così in una tabella ho tutta l'opera e non frase per frase. 

#per farli tutti e metterli in una lista, è una lista in cui ogni dataframe corrisponde a tutta una singola opera es. eschine 1-50 è un'opera:
dataframes_unificati = []
for i in range(len(dataframes)):
    dataframes_unificati.append(pd.concat(dataframes[i],ignore_index=True))

# %%
import pandas as pd
#TUTTI I LEMMI CON TUTTI I POSTAG DI GORMAN, SU CUI APPLICARE STATISTICA PER VEDERE QUANTI LEMMI DIVERSI DI GORMAN PER CIASCUNA FORM 
def create_dataframe_of_lemmas_postags(dataframes_unificati):
    """
    Crea un DataFrame in cui ogni riga corrisponde a una form e le colonne
    sono form, lemma1, lemma2, ..., postag1, postag2, ...
    
    Parameters
    ----------
    dataframes_unificati : list of pd.DataFrame
        Lista di DataFrame da concatenare.

    Returns
    -------
    pd.DataFrame
        Un DataFrame con colonne:
        ['form', 'lemma1', 'lemma2', ..., 'postag1', 'postag2', ...]
    """
    # Concatena i DataFrame e seleziona le colonne di interesse
    df_per_lemma = pd.concat(dataframes_unificati, ignore_index=True)[
        ['@id','@form','@lemma','@postag','@relation']
    ]
    
    # Creiamo un dizionario temporaneo per raccogliere i lemmi e i postag unici per form
    lemma_dict = {}
    # Ricaviamo la lista delle form uniche (mantiene l'ordine di apparizione)
    forms = df_per_lemma['@form'].dropna().unique()
    
    for form in forms:
        # Estrai tutti i lemmi e i postag unici corrispondenti a questa form
        lemmas = (
            df_per_lemma.loc[df_per_lemma['@form'] == form, '@lemma']
            .dropna()
            .unique()
            .tolist()
        )
        postags = (
            df_per_lemma.loc[df_per_lemma['@form'] == form, '@postag']
            .dropna()
            .unique()
            .tolist()
        )
        lemma_dict[form] = {'lemmas': lemmas, 'postags': postags}
    #count_lemma = 0
    #count_pos = 0
    #for form in lemma_dict:


    # Troviamo quanti sono i lemmi massimi e i postag massimi associati a una form
    max_lemmas = max(len(info['lemmas']) for info in lemma_dict.values())
    max_postags = max(len(info['postags']) for info in lemma_dict.values())
    
    # Creiamo la lista delle colonne: form, lemma1..lemmaN, postag1..postagM
    columns = (['form']
               + [f'lemma{i}' for i in range(1, max_lemmas + 1)]
               + [f'postag{i}' for i in range(1, max_postags + 1)])
    
    # Creiamo le righe del dataframe
    rows = []
    for form, info in lemma_dict.items():
        row = {'form': form}
        
        # Inseriamo lemma1, lemma2, ...
        for i, lemma in enumerate(info['lemmas'], start=1):
            row[f'lemma{i}'] = lemma
        # Per i lemmi mancanti, se vuoi puoi lasciarli a None (il dict non li avrà, ma la riga verrà comunque allineata con reindex)
        
        # Inseriamo postag1, postag2, ...
        for i, postag in enumerate(info['postags'], start=1):
            row[f'postag{i}'] = postag
        # Stessa logica per eventuali postag mancanti.
        
        rows.append(row)
    
    # Convertiamo in DataFrame
    final_df = pd.DataFrame(rows, columns=columns)
    
    return final_df, lemma_dict



# ------------------ Esempio d'uso -------------------

# Supponiamo di avere già una lista di DataFrame
# dataframes_unificati = [df1, df2, ...]

# Creiamo il DataFrame finale
# df_lemmas_postags = create_dataframe_of_lemmas_postags(dataframes_unificati)
# print(df_lemmas_postags)

# %%
lemma_pos_dic_gorman, dizionario_gorman_statistica = create_dataframe_of_lemmas_postags(dataframes_unificati)

# %%
dizionario_gorman_statistica
# Out:
# {'οὐδένα': {'lemmas': ['οὐδείς'],
#   'postags': ['p-s---ma-',
#    'a-s---ma_',
#    'a-s---ma-',
#    'p-p---na-',
#    'p-s---fa-']},
#  'πώποτε': {'lemmas': ['πώποτε'], 'postags': ['d--------']},
#  'τῶν': {'lemmas': ['ὁ', 'ὅς'],
#   'postags': ['l-p---mg-',
#    'l-p---ng-',
#    'l-p---fg-',
#    'p-p---ng-',
#    'p-p---mg-',
#    'l-p----g-',
#    'p-p---fg-',
#    'l-s---ma-',
#    'l-p---fn-']},
#  'πολιτῶν': {'lemmas': ['πολίτης'], 'postags': ['n-p---mg-']},
#  ',': {'lemmas': ['punc1', ',', 'ἒ', '·'],
#   'postags': ['u--------', 'e--------']},
#  'ὦ': {'lemmas': ['ὦ', 'εἰμί'], 'postags': ['i--------', 'v1spsa---']},
#  'ἄνδρες': {'lemmas': ['ἀνήρ'], 'postags': ['n-p---mv-', 'n-p---mn-']},
#  'Ἀθηναῖοι': {'lemmas': ['Ἀθηναῖος'],
#   'postags': ['a-p---mv-', 'a-p---mn-', 'n-p---mn-', 'n-p---mv-']},
#  'οὔ': {'lemmas': ['οὐ', 'οὔτε', 'οὐκ', 'οὔ'],
#   'postags': ['d--------', 'd-------_', 'c--------']},
#  '-τε': {'lemmas': ['τε', '-τε', 'οὔτε'],
#   'postags': ['d--------', 'c--------', 'δ--------']},
#  'γραφὴν': {'lemmas': ['γραφής', 'γραφή'],
#   'postags': ['n-s---ma-', 'n-s---fa-']},
#  'γραψάμενος': {'lemmas': ['γράφω'], 'postags': ['v-sapmmn-']},
#  '-τ᾽': {'lemmas': ['τε', 'οὔτε', '-τε'],
#   'postags': ['c--------', 'd--------']},
#  'ἐν': {'lemmas': ['ἐν', 'εἰς'], 'postags': ['r--------', 'd--------']},
#  'εὐθύναις': {'lemmas': ['εὔθυνα'], 'postags': ['n-p---fd-']},
#  'λυπήσας': {'lemmas': ['λυπέω'], 'postags': ['v-sapamn-']},
#  'ἀλλ᾽': {'lemmas': ['ἀλλά', 'ἀλλ᾽'], 'postags': ['c--------', 'd--------']},
#  'ὡς': {'lemmas': ['ὡς', 'ὥς'],
#   'postags': ['c--------', 'd--------', 'r--------', 'd-------_']},
#  'ἔγωγε': {'lemmas': ['ἐγώ'], 'postags': ['p1s---mn-']},
#  'νομίζω': {'lemmas': ['νομίζω'], 'postags': ['v1spia---', 'v1spsa---']},
#  'μέτριον': {'lemmas': ['μέτριος'],
#   'postags': ['a-s---ma-', 'a-s---nn-', 'a-s---na-']},
#  'ἐμαυτὸν': {'lemmas': ['ἐμαυτοῦ'], 'postags': ['p-s---ma-']},
#  'πρὸς': {'lemmas': ['πρός'],
#   'postags': ['r--------', 'd-------_', 'd--------']},
#  'ἕκαστα': {'lemmas': ['ἕκαστος'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'τούτων': {'lemmas': ['οὗτος'],
#   'postags': ['p-p---ng-',
#    'p-p---mg-',
#    'a-p---mg_',
#    'a-p---ng_',
#    'p-p---fg-',
#    'a-p---fg_',
#    'a-p---ng-',
#    'a-p---mg-',
#    'a-p---fg-']},
#  'παρεσχηκώς': {'lemmas': ['παρέχω'], 'postags': ['v-srpamn-']},
#  'ὁρῶν': {'lemmas': ['ὁράω'],
#   'postags': ['v-sppamn-', 'v-sppann-', 'v-sppamv-']},
#  'δὲ': {'lemmas': ['δέ', 'δὲ', 'οὐδέ'], 'postags': ['c--------', 'd--------']},
#  'τήν': {'lemmas': ['ὁ', 'ὅς'], 'postags': ['l-s---fa-', 'p-s---fa-']},
#  'τε': {'lemmas': ['τε'], 'postags': ['d--------', 'c--------']},
#  'πόλιν': {'lemmas': ['πόλις'], 'postags': ['n-s---fa-']},
#  'μεγάλα': {'lemmas': ['μέγας'],
#   'postags': ['a-p---na_',
#    'a-p---na-',
#    'a-p---nn-',
#    'a-d---fn-',
#    'a-p---nd-',
#    'a-s---na-',
#    'a-s---fn-']},
#  'βλαπτομένην': {'lemmas': ['βλάπτω'], 'postags': ['v-sppefa-']},
#  'ὑπὸ': {'lemmas': ['ὑπό'], 'postags': ['r--------']},
#  'Τιμάρχου': {'lemmas': ['Τίμαρχος'], 'postags': ['n-s---mg-']},
#  'τουτουὶ': {'lemmas': ['οὗτος'],
#   'postags': ['a-s---mg_', 'p-s---mg-', 'a-s---mg-', 'a-s---ng_']},
#  'δημηγοροῦντος': {'lemmas': ['δημηγορέω'], 'postags': ['v-sppamg-']},
#  'παρὰ': {'lemmas': ['παρά', 'πηρά'], 'postags': ['r--------', 'd--------']},
#  'τοὺς': {'lemmas': ['ὁ', 'ὅ', 'ὅς'], 'postags': ['l-p---ma-', 'p-p---ma-']},
#  'νόμους': {'lemmas': ['νόμος'], 'postags': ['n-p---ma-']},
#  'καὶ': {'lemmas': ['καί', 'καὶ'],
#   'postags': ['c--------', 'd--------', 'd-------_', 'd-------s']},
#  'αὐτὸς': {'lemmas': ['αὐτός'],
#   'postags': ['p-s---mn-', 'a-s---mn_', 'a-s---mn-']},
#  'ἰδίᾳ': {'lemmas': ['ἴδιος', 'ἰδίᾳ'], 'postags': ['a-s---fd-', 'd--------']},
#  'συκοφαντούμενος': {'lemmas': ['συκοφαντέω'], 'postags': ['v-sppemn-']},
#  '(': {'lemmas': ['punc1', '(', '̔', '（'], 'postags': ['u--------']},
#  'ὃν': {'lemmas': ['ὅς'],
#   'postags': ['a-s---ma_',
#    'p-s---ma-',
#    'a-s---ma-',
#    'p-s---na-',
#    'p-s---nn-']},
#  'τρόπον': {'lemmas': ['τρόπος'], 'postags': ['n-s---ma-', 'n-s---na-']},
#  'προϊόντος': {'lemmas': ['πρόειμι1', 'πρόειμι2'],
#   'postags': ['v-sppamg-', 'v-sppang-']},
#  'ἐπιδείξω': {'lemmas': ['ἐπιδείκνυμι'],
#   'postags': ['v1sfia---', 'v1sasa---']},
#  'τοῦ': {'lemmas': ['ὁ', 'ὅς', 'ὀ', 'ὁς', 'τις', 'τὁ'],
#   'postags': ['l-s---mg-',
#    'l-s---ng-',
#    'p-s---ng-',
#    'l-s---fg-',
#    'a-s---ng-',
#    'p-s---mg-',
#    'l-p---mg-',
#    'l-p---ng-']},
#  'λόγου': {'lemmas': ['λόγος', 'λογόω'],
#   'postags': ['n-s---mg-', 'v2spma---']},
#  ')': {'lemmas': ['punc1', ')', '̓', '）'], 'postags': ['u--------']},
#  'ἕν': {'lemmas': ['εἷς'],
#   'postags': ['a-s---na_',
#    'a-s---nn_',
#    'n-s---na-',
#    'a-s---na-',
#    'n-s---nn-',
#    'a-s---nn-']},
#  'τι': {'lemmas': ['τις'],
#   'postags': ['p-s---na-',
#    'a-s---na_',
#    'p-s---nn-',
#    'a-s---nn_',
#    'a-s---na-',
#    'a-s---nn-',
#    'p-s---nv-']},
#  'αἰσχίστων': {'lemmas': ['αἰσχρός'], 'postags': ['a-p---ngs']},
#  'ἡγησάμην': {'lemmas': ['ἡγέομαι'], 'postags': ['v1saim---']},
#  'εἶναι': {'lemmas': ['εἰμί'], 'postags': ['v--pna---']},
#  'μὴ': {'lemmas': ['μή', 'μὴ'],
#   'postags': ['d--------', 'c--------', 'd-------_', 'd-------------']},
#  'βοηθῆσαι': {'lemmas': ['βοηθέω'], 'postags': ['v--ana---']},
#  'τῇ': {'lemmas': ['ὁ', 'ὅς', 'τῇ', 'ὁς'],
#   'postags': ['l-s---fd-',
#    'l-----fd-',
#    'l-s---md-',
#    'l-s----d------',
#    'l-s---fg-',
#    'l-s---mg-',
#    'p-s---fd-',
#    'd--------',
#    'l-s---fa-']},
#  'πόλει': {'lemmas': ['πόλις'],
#   'postags': ['n-s---fd-', 'n-s---fn-', 'n-d---fn-']},
#  'πάσῃ': {'lemmas': ['πᾶς'], 'postags': ['a-s---fd-']},
#  'τοῖς': {'lemmas': ['ὁ'],
#   'postags': ['l-p---md-',
#    'l-p---nd-',
#    'l-p----d------',
#    'l-p---fd-',
#    'l-p---mg-']},
#  'νόμοις': {'lemmas': ['νόμος'], 'postags': ['n-p---md-']},
#  'ὑμῖν': {'lemmas': ['σύ'],
#   'postags': ['p-p---md-',
#    'p2p---md-',
#    'p2p----d-',
#    'p2p---fd-',
#    'p-p----d-',
#    'p-p----g-']},
#  'ἐμαυτῷ': {'lemmas': ['ἐμαυτοῦ'], 'postags': ['p-s---md-']},
#  ':': {'lemmas': ['punc1', 'ἒ'], 'postags': ['u--------', 'e--------']},
#  'εἰδὼς': {'lemmas': ['οἶδα', 'εἰδοί'], 'postags': ['v-srpamn-', 'n-p---ma-']},
#  'δ᾽': {'lemmas': ['δέ', 'δ᾽'],
#   'postags': ['d--------', 'c--------', 'a-_---___', 'd-------------']},
#  'αὐτὸν': {'lemmas': ['αὐτός'],
#   'postags': ['p-s---ma-', 'a-s---ma_', 'a-s---ma-', 'p-s---na-']},
#  'ἔνοχον': {'lemmas': ['ἔνοχος'], 'postags': ['a-s---ma-']},
#  'ὄντα': {'lemmas': ['εἰμί', 'εἴμι', 'ὄντα'],
#   'postags': ['v-sppama-',
#    'v-pppana-',
#    'v-pppann-',
#    'n-p---nn-',
#    'n-p---na-']},
#  'οἷς': {'lemmas': ['ὅς'],
#   'postags': ['p-p---nd-',
#    'p-p---md-',
#    'a-p---md_',
#    'a-p---nd_',
#    'a-p---md-']},
#  'ὀλίγῳ': {'lemmas': ['ὀλίγος'], 'postags': ['a-s---nd-', 'a-s---md-']},
#  'πρότερον': {'lemmas': ['πρότερος'],
#   'postags': ['a-s---na-', 'a-s---ma-', 'd-------c', 'a-s---nn-']},
#  'ἠκούσατε': {'lemmas': ['ἀκούω'], 'postags': ['v2paia---']},
#  'ἀναγιγνώσκοντος': {'lemmas': ['ἀναγιγνώσκω'], 'postags': ['v-sppamg-']},
#  'γραμματέως': {'lemmas': ['γραμματεύς'], 'postags': ['n-s---mg-']},
#  'ἐπήγγειλα': {'lemmas': ['ἐπαγγέλλω'], 'postags': ['v1saia---']},
#  'αὐτῷ': {'lemmas': ['αὐτός'],
#   'postags': ['p-s---md-',
#    'a-s---md_',
#    'a-s---nd_',
#    'p-s---nd-',
#    'a-s---md-',
#    'a-s---nd-',
#    'p-s----d-']},
#  'τὴν': {'lemmas': ['ὁ', 'ὅς'], 'postags': ['l-s---fa-', 'p-s---fa-']},
#  'δοκιμασίαν': {'lemmas': ['δοκιμασία'], 'postags': ['n-s---fa-']},
#  'ταυτηνί': {'lemmas': ['οὗτος'], 'postags': ['a-s---fa_']},
#  '.': {'lemmas': ['punc1', 'ἒ', '.', 'punct1'],
#   'postags': ['u--------', 'e--------']},
#  'ἔοικεν': {'lemmas': ['ἔοικα'], 'postags': ['v3sria---', 'v3plia---']},
#  'οἱ': {'lemmas': ['ὁ', 'ἕ', 'οὗ', 'ὀ'],
#   'postags': ['l-p---mn-',
#    'p-s---md-',
#    'p-s---fd-',
#    'l-s---md-',
#    'l-s---mn-',
#    'l-p---mg-',
#    'l-p---mv-']},
#  'εἰωθότες': {'lemmas': ['ἔθω'], 'postags': ['v-prpamn-']},
#  'λόγοι': {'lemmas': ['λόγος'], 'postags': ['n-p---mn-']},
#  'λέγεσθαι': {'lemmas': ['λέγω3', 'λέγω2'], 'postags': ['v--pne---']},
#  'ἐπὶ': {'lemmas': ['ἐπί'], 'postags': ['r--------']},
#  'δημοσίοις': {'lemmas': ['δημόσιος'], 'postags': ['a-p---md-', 'a-p---nd-']},
#  'ἀγῶσιν': {'lemmas': ['ἀγών'], 'postags': ['n-p---md-']},
#  'οὐκ': {'lemmas': ['οὐ'],
#   'postags': ['d--------', 'c--------', 'd-------------']},
#  'εἰσὶ': {'lemmas': ['εἰμί'], 'postags': ['v3ppia---']},
#  'ψευδεῖς': {'lemmas': ['ψευδής'],
#   'postags': ['a-p---mn-', 'a-p---ma-', 'a-p---fn-', 'a-p---fa-']},
#  'αἱ': {'lemmas': ['ὁ'], 'postags': ['l-p---fn-']},
#  'γὰρ': {'lemmas': ['γάρ'], 'postags': ['d--------', 'd-------------']},
#  'ἴδιαι': {'lemmas': ['ἴδιος'], 'postags': ['a-p---fn-']},
#  'ἔχθραι': {'lemmas': ['ἔχθρα'], 'postags': ['n-p---fn-']},
#  'πολλὰ': {'lemmas': ['πολύς'],
#   'postags': ['a-p---na-',
#    'a-p---nn-',
#    'a-p---fa-',
#    'a-d---fn-',
#    'a-d---fa-',
#    'a-s---fn-']},
#  'πάνυ': {'lemmas': ['πάνυ'], 'postags': ['d--------']},
#  'κοινῶν': {'lemmas': ['κοινός'],
#   'postags': ['a-p---ng-', 'a-p---fg-', 'a-p---mg-']},
#  'ἐπανορθοῦσι': {'lemmas': ['ἐπανορθόω'], 'postags': ['v3ppia---']},
#  'μὲν': {'lemmas': ['μέν', 'μὲν'],
#   'postags': ['d--------', 'd-------------', 'c--------']},
#  'οὖν': {'lemmas': ['οὖν'], 'postags': ['d--------']},
#  'ὅλου': {'lemmas': ['ὅλος', 'ὅλοξ'], 'postags': ['a-s---mg-', 'a-s---ng-']},
#  'ἀγῶνος': {'lemmas': ['ἀγών'], 'postags': ['n-s---mg-']},
#  'φανήσεται': {'lemmas': ['φαίνω', 'φανάω'],
#   'postags': ['v3sfip---', 'v3sfim---', 'v3sasm---']},
#  '-θ᾽': {'lemmas': ['τε', 'οὔτε', '-τε'],
#   'postags': ['d--------', 'c--------']},
#  'ἡ': {'lemmas': ['ὁ'], 'postags': ['l-s---fn-', 'l-s---fv-']},
#  'πόλις': {'lemmas': ['πόλις', 'πόόλις'],
#   'postags': ['n-p---fa-', 'n-s---fn-']},
#  'αἰτία': {'lemmas': ['αἴτιος', 'αἰτία'],
#   'postags': ['a-s---fn-', 'n-s---fn-']},
#  'οὖσα': {'lemmas': ['εἰμί'],
#   'postags': ['v-sppafn-', 'v-sppmfn-', 'v-spgafn-']},
#  'Τιμάρχῳ': {'lemmas': ['Τίμαρχος'], 'postags': ['n-s---md-']},
#  'νόμοι': {'lemmas': ['νόμος'], 'postags': ['n-p---mn-']},
#  'ὑμεῖς': {'lemmas': ['σύ'],
#   'postags': ['p-p---mn-', 'p2p----n-', 'p-p---fn-', 'p2p---mn-']},
#  'ἐγώ': {'lemmas': ['ἐγώ'],
#   'postags': ['p1s---mn-', 'p-s----n-', 'p1s---fn-']},
#  'οὗτος': {'lemmas': ['οὗτος'],
#   'postags': ['p-s---mn-', 'a-s---mn_', 'a-s---mn-', 'p-s---mv-']},
#  'ἑαυτῷ': {'lemmas': ['ἑαυτοῦ'], 'postags': ['p-s---md-', 'p-s---nd-']},
#  'αἴτιος': {'lemmas': ['αἴτιος'], 'postags': ['a-s---mn-']},
#  'προεῖπον': {'lemmas': ['προεῖπον'],
#   'postags': ['v3paia---', 'v1saia---', 'v1paia---']},
#  'αἰσχρῶς': {'lemmas': ['αἰσχρός'], 'postags': ['d-------_', 'd--------']},
#  'βεβιωκότι': {'lemmas': ['βιόω'], 'postags': ['v-srpamd-']},
#  'δημηγορεῖν': {'lemmas': ['δημηγορέω'], 'postags': ['v--pna---']},
#  'ἐπίταγμα': {'lemmas': ['ἐπίταγμα'], 'postags': ['n-s---na-', 'n-s---nn-']},
#  'ὥς': {'lemmas': ['ὡς', 'ὥς'], 'postags': ['c--------', 'd--------']},
#  'γε': {'lemmas': ['γε'], 'postags': ['d--------']},
#  'δὴ': {'lemmas': ['δή'], 'postags': ['d--------']},
#  'ἐγὼ': {'lemmas': ['ἐγώ'],
#   'postags': ['p1s---mn-', 'p-s---mn-', 'p-s----n-', 'p1s---fn-']},
#  'κρίνω': {'lemmas': ['κρίνω'], 'postags': ['v1spia---', 'v1sasa---']},
#  'οὐ': {'lemmas': ['οὐ', 'οὐκ', 'οὐδέ'],
#   'postags': ['d--------', 'd-------_', 'c--------', 'd-------------']},
#  'χαλεπὸν': {'lemmas': ['χαλεπός'],
#   'postags': ['a-s---na-', 'a-s---nn-', 'a-s---ma-']},
#  'ἐπιτάξαντες': {'lemmas': ['ἐπιτάσσω'], 'postags': ['v-papamn-']},
#  'ἀλλὰ': {'lemmas': ['ἀλλά', 'ἀλλὰ'], 'postags': ['c--------', 'd--------']},
#  'ῥᾴδιον': {'lemmas': ['ῥᾴδιος', 'ῥαίδιον'],
#   'postags': ['a-s---na-',
#    'a-s---ma-',
#    'a-s---nn-',
#    'n-s---nn-',
#    'a-s---nac',
#    'a-s---nnc']},
#  'ἐμὲ': {'lemmas': ['ἐγώ'],
#   'postags': ['p1s---ma-', 'p-s----a-', 'p-s---ma-', 'p1s---fa-']},
#  'ἐξῆν': {'lemmas': ['ἔξεστι'],
#   'postags': ['v3siia---', 'v3piia---', 'v1siia---']},
#  'εἰ': {'lemmas': ['εἰ'], 'postags': ['c--------']},
#  'ἐσωφρόνει': {'lemmas': ['σωφρονέω'], 'postags': ['v3siia---']},
#  'συκοφαντεῖν': {'lemmas': ['συκοφαντέω'], 'postags': ['v--pna---']},
#  'περὶ': {'lemmas': ['περί'], 'postags': ['r--------']},
#  'μετρίως': {'lemmas': ['μέτριος'],
#   'postags': ['d-------_', 'd--------', 'd-------p']},
#  'ἐλπίζω': {'lemmas': ['ἐλπίζω'], 'postags': ['v1spia---']},
#  'μοι': {'lemmas': ['ἐγώ'],
#   'postags': ['p1s---md-',
#    'p1s---fd-',
#    'p-s---md-',
#    'p-s---fd-',
#    'p-s----d-']},
#  'προειρῆσθαι': {'lemmas': ['προερέω'], 'postags': ['v--rne---']},
#  'ἀγνοῶ': {'lemmas': ['ἀγνοέω'], 'postags': ['v1spia---']},
#  'δέ': {'lemmas': ['δέ'], 'postags': ['d--------', 'c--------']},
#  'ἃ': {'lemmas': ['ὅς', 'ὁ', 'ὁς'],
#   'postags': ['p-p---na-',
#    'p-p---nn-',
#    'a-p---nn_',
#    'p-s---fn-',
#    'l-s---fn-',
#    'l-p---nn-',
#    'a-p---na_',
#    'l-p---na-',
#    'p-p---fa-',
#    'p-s---na-']},
#  'μέλλω': {'lemmas': ['μέλλω'], 'postags': ['v1spia---', 'v1spsa---']},
#  'πρώτοις': {'lemmas': ['πρότερος', 'πρῶτος'],
#   'postags': ['a-p---nd-', 'a-p---md-']},
#  'λέγειν': {'lemmas': ['λέγω3', 'λέγω1', 'λέγω2', 'λέγω'],
#   'postags': ['v--pna---']},
#  'ὅτι': {'lemmas': ['ὅτι2', 'ὅτι1', 'ὅστις', 'ὅτι', 'ὅτι3'],
#   'postags': ['c--------',
#    'd--------',
#    'p-s---nn-',
#    'p-s---na-',
#    'a-s---na_',
#    'a--------']},
#  'φανεῖσθε': {'lemmas': ['φαίνω'], 'postags': ['v2pfim---']},
#  'ἑτέρων': {'lemmas': ['ἕτερος'],
#   'postags': ['a-p---mg-',
#    'a-p---ng-',
#    'a-p---fg-',
#    'p-p---ng-',
#    'p-p---mg-']},
#  'ἀκηκοότες': {'lemmas': ['ἀκούω'], 'postags': ['v-prpamn-']},
#  'ἀλλά': {'lemmas': ['ἀλλά'], 'postags': ['d--------', 'c--------']},
#  'δοκεῖ': {'lemmas': ['δοκέω'], 'postags': ['v3spia---']},
#  'καιρὸς': {'lemmas': ['καιρός'], 'postags': ['n-s---mn-']},
#  'νῦν': {'lemmas': ['νῦν'], 'postags': ['d--------']},
#  'ὑμᾶς': {'lemmas': ['σύ', 'ὑμός'],
#   'postags': ['p-p---ma-',
#    'p2p---ma-',
#    'p2p----a-',
#    'p-p----a-',
#    'a-s---fg-']},
#  'τῷ': {'lemmas': ['ὁ', 'τίς', 'ὅς', 'τις'],
#   'postags': ['l-s---md-',
#    'l-s---nd-',
#    'p-s---md-',
#    'p-s---nd-',
#    'l-s----d------',
#    'l-s---ng-',
#    'p-s---ng-',
#    'p-s----d-',
#    'a-s---nd-',
#    'l-s---fd-']},
#  'λόγῳ': {'lemmas': ['λόγος'], 'postags': ['n-s---md-']},
#  'χρήσασθαι': {'lemmas': ['χράω2', 'χράω'], 'postags': ['v--anm---']},
#  'ὁμολογοῦνται': {'lemmas': ['ὁμολογέω'], 'postags': ['v3ppie---']},
#  'τρεῖς': {'lemmas': ['τρεῖς'],
#   'postags': ['a-_---___',
#    'a-p---mn_',
#    'a-p---ma-',
#    'a-p---fa-',
#    'a-p---fn-',
#    'a-p---mn-',
#    'a-p---fa_',
#    'a-p---md-',
#    'm--------']},
#  'πολιτεῖαι': {'lemmas': ['πολιτεία'], 'postags': ['n-p---fn-']},
#  'πᾶσιν': {'lemmas': ['πᾶς', 'πάν', 'πᾶσις'],
#   'postags': ['a-p---md-', 'a-p---nd-', 'n-s---fa-']},
#  'ἀνθρώποις': {'lemmas': ['ἄνθρωπος'], 'postags': ['n-p---md-']},
#  'τυραννὶς': {'lemmas': ['τυραννίς'], 'postags': ['n-s---fn-']},
#  'ὀλιγαρχία': {'lemmas': ['ὀλιγαρχία'], 'postags': ['n-s---fn-']},
#  'δημοκρατία': {'lemmas': ['δημοκρατία'],
#   'postags': ['n-s---fn-', 'n-d---fn-']},
#  'διοικοῦνται': {'lemmas': ['διοικέω'], 'postags': ['v3ppie---']},
#  'τυραννίδες': {'lemmas': ['τυραννίς'], 'postags': ['n-p---fn-']},
#  'ὀλιγαρχίαι': {'lemmas': ['ὀλιγαρχία'], 'postags': ['n-p---fn-']},
#  'τρόποις': {'lemmas': ['τρόπος'], 'postags': ['n-p---md-']},
#  'ἐφεστηκότων': {'lemmas': ['ἐφίστημι'], 'postags': ['v-prpamg-']},
#  'πόλεις': {'lemmas': ['πόλις', 'πόόλις', 'πολίς'],
#   'postags': ['n-p---fn-', 'n-p---fa-', 'n-p---fd-']},
#  'δημοκρατούμεναι': {'lemmas': ['δημοκρατέομαι'], 'postags': ['v-pppefn-']},
#  'κειμένοις': {'lemmas': ['κεῖμαι'], 'postags': ['v-prpemd-']},
#  'εὖ': {'lemmas': ['εὖ'], 'postags': ['d--------']},
#  'ἴστε': {'lemmas': ['οἶδα'], 'postags': ['v2prma---', 'v2pria---']},
#  'τὰ': {'lemmas': ['ὁ', 'τίς', 'ὅς', 'ὃς', 'ὁς'],
#   'postags': ['l-p---na-',
#    'l-p---nn-',
#    'x-p---nn-',
#    'p-p---nn-',
#    'p-p---na-',
#    'l-p---nd-']},
#  'δημοκρατουμένων': {'lemmas': ['δημοκρατέομαι'], 'postags': ['v-pppemg-']},
#  'σώματα': {'lemmas': ['σῶμα'], 'postags': ['n-p---na-', 'n-p---nn-']},
#  'πολιτείαν': {'lemmas': ['πολιτεία'], 'postags': ['n-s---fa-']},
#  'σῴζουσι': {'lemmas': ['σώζω'], 'postags': ['v3ppia---']},
#  'τυράννων': {'lemmas': ['τύραννος'], 'postags': ['n-p---mg-']},
#  'ὀλιγαρχικῶν': {'lemmas': ['ὀλιγαρχικός'], 'postags': ['a-p---mg-']},
#  'ἀπιστία': {'lemmas': ['ἀπιστία'], 'postags': ['n-s---fn-']},
#  'μετὰ': {'lemmas': ['μετά', 'μετὰ'],
#   'postags': ['r--------', 'd-------s', 'd--------']},
#  'ὅπλων': {'lemmas': ['ὅπλον'], 'postags': ['n-p---ng-']},
#  'φρουρά': {'lemmas': ['φρουρά'], 'postags': ['n-s---fn-']},
#  'φυλακτέον': {'lemmas': ['φυλακτέος'], 'postags': ['a-s---nn-']},
#  'ὀλιγαρχικοῖς': {'lemmas': ['ὀλιγαρχικός'], 'postags': ['a-p---md-']},
#  'ἄνισον': {'lemmas': ['ἄνισος'], 'postags': ['a-s---fa-', 'a-s---na-']},
#  'πολιτευομένοις': {'lemmas': ['πολιτεύω'], 'postags': ['v-pppemd-']},
#  'χειρῶν': {'lemmas': ['χείρ', 'χειρόω'],
#   'postags': ['n-p---fg-', 'v-sppann-', 'v-sppamn-']},
#  'νόμῳ': {'lemmas': ['νόμος'], 'postags': ['n-s---md-']},
#  'τὰς': {'lemmas': ['ὁ', 'ὅς'],
#   'postags': ['l-p---fa-', 'l-s---fg-', 'p-p---fa-']},
#  'πολιτείας': {'lemmas': ['πολιτεία'], 'postags': ['n-p---fa-', 'n-s---fg-']},
#  'καταλύοντας': {'lemmas': ['καταλύω'], 'postags': ['v-pppama-']},
#  'ἴσην': {'lemmas': ['ἴσος'], 'postags': ['a-s---fa-']},
#  'ἔννομον': {'lemmas': ['ἔννομος'], 'postags': ['a-s---fa-', 'a-s---na-']},
#  'ἔχουσι': {'lemmas': ['ἔχω'],
#   'postags': ['v-pppamd-', 'v3ppia---', 'v-pppand-', 'v3ppia--------']},
#  'ἢ': {'lemmas': ['ἤ1', 'ἢ', 'ἤ', 'ἤ2'],
#   'postags': ['d--------', 'c--------', 'd-------_', 'd-------------']},
#  'λέγοντας': {'lemmas': ['λέγω3', 'λέγω'], 'postags': ['v-pppama-']},
#  'βεβιωκότας': {'lemmas': ['βιόω'], 'postags': ['v-prpama-']},
#  'ἐντεῦθεν': {'lemmas': ['ἐντεῦθεν'], 'postags': ['d--------']},
#  'ἰσχύσετε': {'lemmas': ['ἰσχύω'], 'postags': ['v2pfia---']},
#  'ὅταν': {'lemmas': ['ὅταν'], 'postags': ['c--------']},
#  'εὐνομῆσθε': {'lemmas': ['εὐνομέομαι'], 'postags': ['v2ppse---']},
#  'καταλύησθε': {'lemmas': ['καταλύω'], 'postags': ['v2ppse---']},
#  'παρανομούντων': {'lemmas': ['παρανομέω'], 'postags': ['v-pppamg-']},
#  'προσήκειν': {'lemmas': ['προσήκω'], 'postags': ['v--pna---']},
#  'νομοθετῶμεν': {'lemmas': ['νομοθετέω'], 'postags': ['v1ppsa---']},
#  'τοῦθ᾽': {'lemmas': ['οὗτος'],
#   'postags': ['p-s---na-', 'p-s---nn-', 'a-s---na_']},
#  'ἡμᾶς': {'lemmas': ['ἐγώ', 'ἔγω'],
#   'postags': ['p1p---ma-',
#    'p-s---mn-',
#    'p1p---fa-',
#    'n-p---ma-',
#    'p-p---ma-',
#    'p-p----a-']},
#  'σκοπεῖν': {'lemmas': ['σκοπέω', 'σκοπάω'], 'postags': ['v--pna---']},
#  'ὅπως': {'lemmas': ['ὅπως'],
#   'postags': ['c--------', 'd--------', 'd-------_']},
#  'καλῶς': {'lemmas': ['καλός'], 'postags': ['d--------', 'd-------p']},
#  'ἔχοντας': {'lemmas': ['ἔχω'], 'postags': ['v-pppama-']},
#  'συμφέροντας': {'lemmas': ['συμφέρω'], 'postags': ['v-pppama-']},
#  'πολιτείᾳ': {'lemmas': ['πολιτεία'], 'postags': ['n-s---fd-']},
#  'θησόμεθα': {'lemmas': ['τίθημι'], 'postags': ['v1pfim---']},
#  'ἐπειδὰν': {'lemmas': ['ἐπειδάν'], 'postags': ['c--------']},
#  'νομοθετήσωμεν': {'lemmas': ['νομοθετέω'], 'postags': ['v1pasa---']},
#  'πείθεσθαι': {'lemmas': ['πείθω'], 'postags': ['v--pne---']},
#  'πειθομένους': {'lemmas': ['πείθω'], 'postags': ['v-pppema-']},
#  'κολάζειν': {'lemmas': ['κολάζω'], 'postags': ['v--pna---']},
#  'δεῖ': {'lemmas': ['δεῖ', 'δέω2', 'δέω', 'δέω1', 'δέομαι'],
#   'postags': ['v3siia---', 'v3spia---', 'v2spie---']},
#  'τῆς': {'lemmas': ['ὁ', 'ὅς'],
#   'postags': ['l-s---fg-', 'p-s---fg-', 'a-s---fa_']},
#  'πόλεως': {'lemmas': ['πόλις'], 'postags': ['n-s---fg-']},
#  'ἔχειν': {'lemmas': ['ἔχω'], 'postags': ['v--pna---']},
#  'σκέψασθε': {'lemmas': ['σκέπτομαι'],
#   'postags': ['v2pame---', 'v2pamm---', 'v2paie---']},
#  'γάρ': {'lemmas': ['γάρ'], 'postags': ['d--------']},
#  'ὅσην': {'lemmas': ['ὅσος'], 'postags': ['a-s---fa-']},
#  'πρόνοιαν': {'lemmas': ['πρόνοια'], 'postags': ['n-s---fa-']},
#  'σωφροσύνης': {'lemmas': ['σωφροσύνη'], 'postags': ['n-s---fg-']},
#  'ἐποιήσατο': {'lemmas': ['ποιέω'], 'postags': ['v3saim---', 'v3saia---']},
#  'ὁ': {'lemmas': ['ὁ'], 'postags': ['l-s---mn-']},
#  'Σόλων': {'lemmas': ['Σόλων', 'Σόλοι'],
#   'postags': ['n-s---mn-', 'n-p---mg-', 'n-s---mv-']},
#  'ἐκεῖνος': {'lemmas': ['ἐκεῖνος'],
#   'postags': ['a-s---mn_', 'p-s---mn-', 'a-s---mn-']},
#  'παλαιὸς': {'lemmas': ['παλαιός'], 'postags': ['a-s---mn-']},
#  'νομοθέτης': {'lemmas': ['νομοθέτης'], 'postags': ['n-s---mn-']},
#  'Δράκων': {'lemmas': ['Δράκων'], 'postags': ['n-s---mn-']},
#  'κατὰ': {'lemmas': ['κατά', 'κατὰ'],
#   'postags': ['r--------', 'd--------', 'c--------']},
#  'χρόνους': {'lemmas': ['χρόνος'], 'postags': ['n-p---ma-']},
#  'ἐκείνους': {'lemmas': ['ἐκεῖνος', 'ἐκείνος'],
#   'postags': ['a-p---ma_', 'p-p---ma-']},
#  'νομοθέται': {'lemmas': ['νομοθέτης'], 'postags': ['n-p---mn-']},
#  'πρῶτον': {'lemmas': ['πρῶτος', 'πρότερος'],
#   'postags': ['a-s---na-', 'a-s---ma-', 'a-s---nnp', 'a-s---nn-']},
#  'παίδων': {'lemmas': ['παῖς'], 'postags': ['n-p---mg-', 'n-s---mv-']},
#  'ἡμετέρων': {'lemmas': ['ἡμέτερος'], 'postags': ['a-p---mg-', 'a-p---ng-']},
#  'ἐνομοθέτησαν': {'lemmas': ['νομοθετέω'], 'postags': ['v3paia---']},
#  'διαρρήδην': {'lemmas': ['διαρρήδην'], 'postags': ['d--------']},
#  'ἀπέδειξαν': {'lemmas': ['ἀποδείκνυμι'], 'postags': ['v3paia---']},
#  'χρὴ': {'lemmas': ['χρή'], 'postags': ['v3spia---']},
#  'τὸν': {'lemmas': ['ὁ', 'ὁς', 'ὅς', 'τὸν'],
#   'postags': ['l-s---ma-', 'p-s---ma-', 'a-s---ma-']},
#  'παῖδα': {'lemmas': ['παῖς'],
#   'postags': ['n-s---ma-', 'n-s---fa-', 'n-s----a-']},
#  'ἐλεύθερον': {'lemmas': ['ἐλεύθερος'],
#   'postags': ['a-s---na-', 'a-s---ma-', 'a-s---nn-']},
#  'ἐπιτηδεύειν': {'lemmas': ['ἐπιτηδεύω'], 'postags': ['v--pna---']},
#  'τραφῆναι': {'lemmas': ['τρέφω'], 'postags': ['v--anp---']},
#  'ἔπειτα': {'lemmas': ['ἔπειτα'], 'postags': ['d--------', 'c--------']},
#  'δεύτερον': {'lemmas': ['δεύτερος'],
#   'postags': ['a-s---na-', 'a-s---nn-', 'a-s---ma-']},
#  'μειρακίων': {'lemmas': ['μειράκιον'], 'postags': ['n-p---ng-']},
#  'τρίτον': {'lemmas': ['τρίτος'],
#   'postags': ['a-s---na-', 'a-s---nn-', 'a-s---ma-']},
#  'ἐφεξῆς': {'lemmas': ['ἐφεξῆς'], 'postags': ['d--------']},
#  'ἄλλων': {'lemmas': ['ἄλλος'],
#   'postags': ['a-p---fg_',
#    'a-p---mg_',
#    'p-p---ng-',
#    'p-p---mg-',
#    'a-p---ng_',
#    'p-p---fg-',
#    'a-p---mg-',
#    'a-p---fg-',
#    'a-p---ng-']},
#  'ἡλικιῶν': {'lemmas': ['ἡλικία'], 'postags': ['n-p---fg-']},
#  'μόνον': {'lemmas': ['μόνος', 'μόνον'],
#   'postags': ['a-s---na-',
#    'a-s---ma-',
#    'a-s---nn-',
#    'd--------',
#    'a-s---nv-']},
#  'ἰδιωτῶν': {'lemmas': ['ἰδιώτης'], 'postags': ['n-p---mg-', 'n-p---ng-']},
#  'ῥητόρων': {'lemmas': ['ῥήτωρ'], 'postags': ['n-p---mg-']},
#  'τούτους': {'lemmas': ['οὗτος'],
#   'postags': ['a-p---ma_', 'p-p---ma-', 'a-p---ma-']},
#  'ἀναγράψαντες': {'lemmas': ['ἀναγράφω'], 'postags': ['v-papamn-']},
#  'παρακατέθεντο': {'lemmas': ['παρακατατίθεμαι'], 'postags': ['v3paim---']},
#  'αὐτῶν': {'lemmas': ['αὐτός'],
#   'postags': ['p-p---mg-',
#    'p-p---ng-',
#    'a-p---mg_',
#    'a-p---ng_',
#    'p-p---fg-',
#    'a-p---mg-',
#    'a-p---fg_',
#    'a-p---ng-',
#    'a-p---fg-']},
#  'ἐπέστησαν': {'lemmas': ['ἐφίστημι'], 'postags': ['v3paia---']},
#  'φύλακας': {'lemmas': ['φύλαξ'], 'postags': ['n-p---ma-']},
#  'βούλομαι': {'lemmas': ['βούλομαι'], 'postags': ['v1spie---']},
#  'νυνὶ': {'lemmas': ['νυνί'], 'postags': ['d--------']},
#  'ὅνπερ': {'lemmas': ['ὅς'], 'postags': ['p-s---ma-', 'a-s---ma_']},
#  'διέξειμι': {'lemmas': ['διέξειμι'], 'postags': ['v1spia---']},
#  'οἳ': {'lemmas': ['ὅς', 'ὁ', 'ἕ'],
#   'postags': ['p-p---mn-', 'l-p---mn-', 'p-s---md-']},
#  'κεῖνται': {'lemmas': ['κεῖμαι'], 'postags': ['v3ppie---']},
#  'εὐκοσμίας': {'lemmas': ['εὐκοσμία'], 'postags': ['n-s---fg-']},
#  'ὑμετέρων': {'lemmas': ['ὑμέτερος'], 'postags': ['a-p---mg-', 'a-p---ng-']},
#  'οὕτω': {'lemmas': ['οὕτως'], 'postags': ['d--------']},
#  'ἄν': {'lemmas': ['ἄν1', 'ἐάν', 'ἄν', 'ἄν2', 'ἀν'],
#   'postags': ['d--------', 'c--------']},
#  'μάλιστα': {'lemmas': ['μάλιστα', 'μάλα'],
#   'postags': ['d--------', 'd-------s-----', 'd-------s']},
#  'ὑπολαμβάνω': {'lemmas': ['ὑπολαμβάνω'],
#   'postags': ['v1spsa---', 'v1spia---']},
#  'λόγους': {'lemmas': ['λόγος', 'λογός'],
#   'postags': ['n-p---ma-', 'n-p---md-']},
#  'εὐμαθεῖς': {'lemmas': ['εὐμαθής'], 'postags': ['a-p---ma-']},
#  'γενέσθαι': {'lemmas': ['γίγνομαι'], 'postags': ['v--anm---']},
#  'ἅμα': {'lemmas': ['ἅμα'],
#   'postags': ['d--------', 'r--------', 'c--------']},
#  'διεξελθεῖν': {'lemmas': ['διεξέρχομαι'], 'postags': ['v--ana---']},
#  'ἔχουσιν': {'lemmas': ['ἔχω'],
#   'postags': ['v3ppia---', 'v-pppamd-', 'v-pppand-']},
#  'πάλιν': {'lemmas': ['πάλιν'], 'postags': ['d--------']},
#  'τοῦτο': {'lemmas': ['οὗτος'],
#   'postags': ['p-s---na-',
#    'a-s---nn_',
#    'p-s---nn-',
#    'a-s---na_',
#    'a-s---na-',
#    'a-s---nn-']},
#  'ἀντεξετάσαι': {'lemmas': ['ἀντεξετάζω'], 'postags': ['v--ana---']},
#  'τρόπους': {'lemmas': ['τρόπος'], 'postags': ['n-p---ma-']},
#  'εὑρήσετε': {'lemmas': ['εὑρίσκω'], 'postags': ['v2pfia---']},
#  'ἐναντίως': {'lemmas': ['ἐναντίος'], 'postags': ['d-------p']},
#  'ἅπασι': {'lemmas': ['ἅπας'], 'postags': ['a-p---md-', 'a-p---nd-']},
#  'βεβιωκότα': {'lemmas': ['βιόω'], 'postags': ['v-srpama-']},
#  'διδασκάλοις': {'lemmas': ['διδάσκαλος'], 'postags': ['n-p---md-']},
#  'ἐξ': {'lemmas': ['ἐκ'], 'postags': ['r--------']},
#  'ἀνάγκης': {'lemmas': ['ἀνάγκη'], 'postags': ['n-s---fg-']},
#  'παρακατατιθέμεθα': {'lemmas': ['παρακατατίθεμαι'], 'postags': ['v1ppie---']},
#  'ἡμετέρους': {'lemmas': ['ἡμέτερος'], 'postags': ['a-p---ma-']},
#  'παῖδας': {'lemmas': ['παῖς'],
#   'postags': ['n-p---ma-', 'n-p---fa-', 'n-p----a-']},
#  'ἐστιν': {'lemmas': ['εἰμί'], 'postags': ['v3spia---']},
#  'βίος': {'lemmas': ['βίος'], 'postags': ['n-s---mn-']},
#  'ἀπὸ': {'lemmas': ['ἀπό'], 'postags': ['r--------']},
#  'σωφρονεῖν': {'lemmas': ['σωφρονέω'], 'postags': ['v--pna---']},
#  'ἀπορία': {'lemmas': ['ἀπορία'], 'postags': ['n-s---fn-']},
#  'ἐκ': {'lemmas': ['ἐκ'], 'postags': ['r--------']},
#  'ἐναντίων': {'lemmas': ['ἐναντίος'], 'postags': ['a-p---ng-', 'a-p---mg-']},
#  'ὅμως': {'lemmas': ['ὅμως'],
#   'postags': ['d--------', 'd-------_-----', 'c--------', 'd-------_']},
#  'ἀπιστῶν': {'lemmas': ['ἀπιστέω'], 'postags': ['v-sppamn-']},
#  'φαίνεται': {'lemmas': ['φαίνω'], 'postags': ['v3spie---', 'v3spie--------']},
#  'ἀποδείκνυσι': {'lemmas': ['ἀποδείκνυμι'], 'postags': ['v3spia---']},
#  'ἣν': {'lemmas': ['ὅς'], 'postags': ['a-s---fa_', 'p-s---fa-', 'a-s---fa-']},
#  'ὥραν': {'lemmas': ['ὥρα'], 'postags': ['n-s---fa-']},
#  'προσήκει': {'lemmas': ['προσήκω'], 'postags': ['v3spia---']},
#  'ἰέναι': {'lemmas': ['εἶμι', 'ἔρχομαι'], 'postags': ['v--pna---']},
#  'εἰς': {'lemmas': ['εἰς'], 'postags': ['r--------']},
#  'τὸ': {'lemmas': ['ὁ', 'ὅς'],
#   'postags': ['l-s---na-',
#    'l-s---nn-',
#    'l-s---nd-',
#    'p-s---na-',
#    'p-s---nn-',
#    'a-s---nn-',
#    'a-s---na_',
#    'a-s---nn_',
#    'l-s---nv-']},
#  'διδασκαλεῖον': {'lemmas': ['διδασκαλεῖον'], 'postags': ['n-s---na-']},
#  'πόσων': {'lemmas': ['πόσος'], 'postags': ['a-p---mg-']},
#  'εἰσιέναι': {'lemmas': ['εἰσίημι', 'εἴσειμι', 'εἰσέρχομαι'],
#   'postags': ['v--pna---']},
#  'πηνίκα': {'lemmas': ['πηνίκα'], 'postags': ['d--------']},
#  'ἀπιέναι': {'lemmas': ['ἄπειμι2', 'ἀφίημι', 'ἀπέρχομαι'],
#   'postags': ['v--pna---']},
#  'διδασκάλους': {'lemmas': ['διδάσκαλος'], 'postags': ['n-p---ma-']},
#  'διδασκαλεῖα': {'lemmas': ['διδασκαλεῖον'],
#   'postags': ['n-p---nv-', 'n-p---na-']},
#  'παιδοτρίβας': {'lemmas': ['παιδοτρίβης'], 'postags': ['n-p---ma-']},
#  'παλαίστρας': {'lemmas': ['παλαίστρα'],
#   'postags': ['n-p---fa-', 'n-s---fg-']},
#  'ἀνοίγειν': {'lemmas': ['ἀνοίγνυμι'], 'postags': ['v--pna---']},
#  'ἀπαγορεύει': {'lemmas': ['ἀπαγορεύω'], 'postags': ['v3spia---']},
#  'πρὶν': {'lemmas': ['πρίν', 'πρὶν'], 'postags': ['c--------', 'd--------']},
#  'ἂν': {'lemmas': ['ἄν1', 'ἐάν', 'ἄν2', 'ἄν', 'ἀν', 'εἄν'],
#   'postags': ['d--------', 'c--------', 'd-------------']},
#  'ἥλιος': {'lemmas': ['ἥλιος'], 'postags': ['n-s---mn-']},
#  'ἀνίσχῃ': {'lemmas': ['ἀνά-ἴσχω'], 'postags': ['v3spsa---']},
#  'κλῄειν': {'lemmas': ['κλείω1'], 'postags': ['v--pna---']},
#  'προστάττει': {'lemmas': ['προστάσσω'], 'postags': ['v3spia---']},
#  'πρὸ': {'lemmas': ['πρό'], 'postags': ['r--------', 'd--------']},
#  'ἡλίου': {'lemmas': ['ἥλιος'], 'postags': ['n-s---mg-']},
#  'δεδυκότος': {'lemmas': ['δύω2'], 'postags': ['v-srpamg-']},
#  'ἐρημίας': {'lemmas': ['ἐρημία'], 'postags': ['n-p---fa-', 'n-s---fg-']},
#  'σκότος': {'lemmas': ['σκότος'], 'postags': ['n-s---na-', 'n-s---nn-']},
#  'πλείστῃ': {'lemmas': ['πλεῖστος', 'πολύς'],
#   'postags': ['a-s---fd-', 'a-s---fds']},
#  'ὑποψίᾳ': {'lemmas': ['ὑποψία'], 'postags': ['n-s---fd-']},
#  'ποιούμενος': {'lemmas': ['ποιέω', 'ποιόω'], 'postags': ['v-sppemn-']},
#  'νεανίσκους': {'lemmas': ['νεανίσκος', 'νεάνισκος'],
#   'postags': ['n-p---ma-']},
#  'εἰσφοιτῶντας': {'lemmas': ['εἰσφοιτάω'], 'postags': ['v-pppama-']},
#  'οὕς': {'lemmas': ['ὅς'], 'postags': ['a-p---ma_', 'p-p---ma-']},
#  'τινας': {'lemmas': ['τις'],
#   'postags': ['p-p---ma-',
#    'a-p---fa_',
#    'a-p---ma_',
#    'p-p---fa-',
#    'a-p----a-',
#    'a-p---ma-',
#    'a-p---fa-']},
#  'ἅς': {'lemmas': ['ὅς'], 'postags': ['a-p---fa_', 'p-p---fa-']},
#  'ἡλικίας': {'lemmas': ['ἡλικία'], 'postags': ['n-p---fa-', 'n-s---fg-']},
#  'ἀρχὴν': {'lemmas': ['ἀρχή', 'ἀρχήν'], 'postags': ['n-s---fa-', 'd--------']},
#  'ἥτις': {'lemmas': ['ὅστις'], 'postags': ['p-s---fn-']},
#  'ἔσται': {'lemmas': ['εἰμί'], 'postags': ['v3sfim---']},
#  'ἐπιμελησομένη': {'lemmas': ['ἐπιμελέομαι'], 'postags': ['v-sfpefn-']},
#  'παιδαγωγῶν': {'lemmas': ['παιδαγωγός'], 'postags': ['n-p---mg-']},
#  'ἐπιμελείας': {'lemmas': ['ἐπιμέλεια'],
#   'postags': ['n-s---fg-', 'n-p---fa-']},
#  'Μουσείων': {'lemmas': ['Μουσεῖον'], 'postags': ['n-p---ng-']},
#  'διδασκαλείοις': {'lemmas': ['διδασκαλεῖον'], 'postags': ['n-p---nd-']},
#  'Ἑρμαίων': {'lemmas': ['Ἕρμαιον'], 'postags': ['n-p---ng-']},
#  'ταῖς': {'lemmas': ['ὁ'], 'postags': ['l-p---fd-']},
#  'παλαίστραις': {'lemmas': ['παλαίστρα'], 'postags': ['n-p---fd-']},
#  'τελευταῖον': {'lemmas': ['τελευταῖος'],
#   'postags': ['a-s---na-', 'a-s---ma-', 'a-s---nn-']},
#  'συμφοιτήσεως': {'lemmas': ['συμφοίτησις'], 'postags': ['n-s---fg-']},
#  'χορῶν': {'lemmas': ['χορός'], 'postags': ['n-p---mg-']},
#  'κυκλίων': {'lemmas': ['κύκλιος'], 'postags': ['a-p---mg-']},
#  'κελεύει': {'lemmas': ['κελεύω'], 'postags': ['v3spia---', 'v2spie---']},
#  'χορηγὸν': {'lemmas': ['χορηγός'], 'postags': ['n-s---ma-']},
#  'μέλλοντα': {'lemmas': ['μέλλω'],
#   'postags': ['v-sppama-', 'v-pppana-', 'v-pppann-']},
#  'οὐσίαν': {'lemmas': ['οὐσία'], 'postags': ['n-s---fa-']},
#  'ἑαυτοῦ': {'lemmas': ['ἑαυτοῦ'], 'postags': ['p-s---mg-', 'p-s---ng-']},
#  'ἀναλίσκειν': {'lemmas': ['ἀναλίσκω'], 'postags': ['v--pna---']},
#  'ὑπὲρ': {'lemmas': ['ὑπέρ'], 'postags': ['r--------']},
#  'τετταράκοντα': {'lemmas': ['τετταράκοντα', 'τεσσαράκοντα'],
#   'postags': ['a-_---___', 'a--------']},
#  'ἔτη': {'lemmas': ['ἔτος'],
#   'postags': ['n-p---na-', 'n-s---na-', 'n-p---nn-']},
#  'γεγονότα': {'lemmas': ['γίγνομαι'],
#   'postags': ['v-srpama-', 'v-prpana-', 'v-srpamd-', 'v-prpann-']},
#  'πράττειν': {'lemmas': ['πράσσω'], 'postags': ['v--pna---']},
#  'ἵν᾽': {'lemmas': ['ἵνα'], 'postags': ['c--------', 'd--------']},
#  'ἤδη': {'lemmas': ['ἤδη', 'ἦδη', 'ἠδή'], 'postags': ['d--------']},
#  'σωφρονεστάτῃ': {'lemmas': ['σώφρων'], 'postags': ['a-s---fds']},
#  'αὑτοῦ': {'lemmas': ['ἑαυτοῦ', 'ἑαυτός'],
#   'postags': ['p-s---mg-', 'p-s---ng-']},
#  'ἡλικίᾳ': {'lemmas': ['ἡλικία'],
#   'postags': ['n-s---fd-', 'n-p---fn-', 'n-s---fg-']},
#  'ὤν': {'lemmas': ['εἰμί', 'οὖν'], 'postags': ['v-sppamn-', 'd--------']},
#  'οὕτως': {'lemmas': ['οὕτως'], 'postags': ['d--------']},
#  'ἐντυγχάνῃ': {'lemmas': ['ἐντυγχάνω'], 'postags': ['v3spsa---']},
#  'ὑμετέροις': {'lemmas': ['ὑμέτερος'], 'postags': ['a-p---md-', 'a-p---nd-']},
#  'παισίν': {'lemmas': ['παῖς'], 'postags': ['n-p---md-']},
#  'ἀναγνώσεται': {'lemmas': ['ἀναγιγνώσκω'], 'postags': ['v3sfim---']},
#  'εἰδῆτε': {'lemmas': ['οἶδα'], 'postags': ['v2prsa---']},
#  'ἡγήσατο': {'lemmas': ['ἁγέομαι', 'ἡγέομαι'],
#   'postags': ['v3saie---', 'v3saim---']},
#  'τραφέντα': {'lemmas': ['τρέφω'], 'postags': ['v-sappma-']},
#  'ἄνδρα': {'lemmas': ['ἀνήρ'], 'postags': ['n-s---ma-']},
#  'γενόμενον': {'lemmas': ['γίγνομαι'],
#   'postags': ['v-sapmma-', 'v-sapmna-', 'v-sapmnv-', 'v-sapmnn-']},
#  'χρήσιμον': {'lemmas': ['χρήσιμος'],
#   'postags': ['a-s---ma-', 'a-s---na-', 'a-s---nn-', 'a-s---fa-']},
#  'ἔσεσθαι': {'lemmas': ['εἰμί'], 'postags': ['v--fnm---']},
#  'φύσις': {'lemmas': ['φύσις'], 'postags': ['n-s---fn-', 'n-p---fa-']},
#  'ἀνθρώπου': {'lemmas': ['ἄνθρωπος'], 'postags': ['n-s---mg-', 'n-s---fg-']},
#  'εὐθὺς': {'lemmas': ['εὐθύς2', 'εὐθύς'], 'postags': ['d--------']},
#  'πονηρὰν': {'lemmas': ['πονηρός'], 'postags': ['a-s---fa-']},
#  'λάβῃ': {'lemmas': ['λαμβάνω'], 'postags': ['v3sasa---']},
#  'παιδείας': {'lemmas': ['παιδεία'], 'postags': ['n-s---fg-', 'n-p---fa-']},
#  'κακῶς': {'lemmas': ['κακός'],
#   'postags': ['d--------', 'd-------p', 'd-------_']},
#  'τεθραμμένων': {'lemmas': ['τρέφω'], 'postags': ['v-prpemg-']},
#  'παραπλησίους': {'lemmas': ['παραπλήσιος'],
#   'postags': ['a-p---ma-', 'a-p---fa-']},
#  'πολίτας': {'lemmas': ['πολίτης'], 'postags': ['n-p---ma-']},
#  'τουτῳί': {'lemmas': ['οὗτος'], 'postags': ['a-s---md_']},
#  'τούς': {'lemmas': ['ὁ'], 'postags': ['l-p---ma-']},
#  'λέγε': {'lemmas': ['λέγω3', 'λέγω2'], 'postags': ['v2spma---', 'v3siia---']},
#  'αὐτοῖς': {'lemmas': ['αὐτός'],
#   'postags': ['p-p---md-',
#    'p-p---nd-',
#    'a-p---md_',
#    'a-p---nd_',
#    'a-p---md-',
#    'p-p---fd-',
#    'a-p---nd-',
#    'p-p----d-']},
#  'διδάσκαλοι': {'lemmas': ['διδάσκαλος'], 'postags': ['n-p---mn-']},
#  'ἀνοιγέτωσαν': {'lemmas': ['ἀνοίγνυμι'], 'postags': ['v3ppma---']},
#  'ἀνιόντος': {'lemmas': ['ἄνειμι'], 'postags': ['v-sppamg-']},
#  'κλειέτωσαν': {'lemmas': ['κλέω'], 'postags': ['v3ppma---']},
#  'δύνοντος': {'lemmas': ['δύω2'], 'postags': ['v-sppamg-']},
#  'ἐξέστω': {'lemmas': ['ἔξεστι'], 'postags': ['v3spma---']},
#  'ἡλικίαν': {'lemmas': ['ἡλικία'], 'postags': ['n-s---fa-']},
#  'οὖσιν': {'lemmas': ['εἰμί'], 'postags': ['v-pppamd-', 'v-pppand-']},
#  'ἔνδον': {'lemmas': ['ἔνδον'], 'postags': ['d--------']},
#  'ὄντων': {'lemmas': ['εἰμί'],
#   'postags': ['v-pppamg-', 'v-pppang-', 'v-ppmang-', 'v3ppma---']},
#  'ἐὰν': {'lemmas': ['ἐάν'], 'postags': ['c--------', 'd--------']},
#  'υἱὸς': {'lemmas': ['υἱός'], 'postags': ['n-s---mn-']},
#  'διδασκάλου': {'lemmas': ['διδάσκαλος'], 'postags': ['n-s---mg-']},
#  'ἀδελφὸς': {'lemmas': ['ἀδελφός'], 'postags': ['n-s---mn-']},
#  'θυγατρὸς': {'lemmas': ['θυγάτηρ'], 'postags': ['n-s---fg-']},
#  'ἀνήρ': {'lemmas': ['ἀνήρ'], 'postags': ['n-s---mn-']},
#  'τις': {'lemmas': ['τις'],
#   'postags': ['p-s---mn-',
#    'a-s---mn_',
#    'a-s---fn_',
#    'p-s---fn-',
#    'a-s---mn-',
#    'a-s---fn-',
#    'a-s----n-']},
#  'ταῦτ᾽': {'lemmas': ['οὗτος'],
#   'postags': ['p-p---na-', 'p-p---nn-', 'a-p---na-', 'a-p---na_']},
#  'εἰσίῃ': {'lemmas': ['εἴσειμι'], 'postags': ['v3spsa---']},
#  'θανάτῳ': {'lemmas': ['θάνατος'], 'postags': ['n-s---md-']},
#  'ζημιούσθω': {'lemmas': ['ζημιόω'], 'postags': ['v3spme---']},
#  'γυμνασιάρχαι': {'lemmas': ['γυμνασιάρχης'], 'postags': ['n-p---mn-']},
#  'Ἑρμαίοις': {'lemmas': ['Ἕρμαιον'], 'postags': ['n-p---nd-']},
#  'εἄτωσαν': {'lemmas': ['ἐάω'], 'postags': ['v3ppma---']},
#  'συγκαθιέναι': {'lemmas': ['συγκαθίημι'], 'postags': ['v--pna---']},
#  'μηδένα': {'lemmas': ['μηδείς'],
#   'postags': ['p-s---ma-', 'a-s---ma_', 'p-s---na-', 'p-p---na-']},
#  'τρόπῳ': {'lemmas': ['τρόπος'], 'postags': ['n-s---md-']},
#  'μηδενί': {'lemmas': ['μηδείς'],
#   'postags': ['a-s---md_', 'a-s---md-', 'a-s---nd_']},
#  'ἐπιτρέπῃ': {'lemmas': ['ἐπιτρέπω'], 'postags': ['v3spsa---']},
#  'ἐξείργῃ': {'lemmas': ['ἐξέργω'], 'postags': ['v3spsa---']},
#  'γυμνασίου': {'lemmas': ['γυμνάσιον'], 'postags': ['n-s---ng-']},
#  'ἔνοχος': {'lemmas': ['ἔνοχος'], 'postags': ['a-s---mn-']},
#  'ἔστω': {'lemmas': ['εἰμί'], 'postags': ['v3spma---']},
#  'γυμνασιάρχης': {'lemmas': ['γυμνασιάρχης'], 'postags': ['n-s---mn-']},
#  'ἐλευθέρων': {'lemmas': ['ἐλεύθερος'],
#   'postags': ['a-p---mg-', 'a-p---fg-', 'a-p---ng-']},
#  'φθορᾶς': {'lemmas': ['φθορά'], 'postags': ['n-s---fg-']},
#  'χορηγοὶ': {'lemmas': ['χορηγός'], 'postags': ['n-p---mn-']},
#  'καθιστάμενοι': {'lemmas': ['καθίστημι'], 'postags': ['v-pppemn-']},
#  'δήμου': {'lemmas': ['δῆμος'], 'postags': ['n-s---mg-']},
#  'ἔστωσαν': {'lemmas': ['εἰμί'], 'postags': ['v3ppma---']},
#  'ταῦτα': {'lemmas': ['οὗτος'],
#   'postags': ['p-p---na-',
#    'p-p---nn-',
#    'a-p---na_',
#    'a-p---na-',
#    'a-p---nn_',
#    'a-p---nn-',
#    'p-p---nd-']},
#  'τοίνυν': {'lemmas': ['τοίνυν'], 'postags': ['d--------']},
#  'νομοθετεῖ': {'lemmas': ['νομοθετέω'], 'postags': ['v3spia---']},
#  'ἀδικημάτων': {'lemmas': ['ἀδίκημα'], 'postags': ['n-p---ng-']},
#  'μεγάλων': {'lemmas': ['μέγας'],
#   'postags': ['a-p---ngp', 'a-p---fg-', 'a-p---ng-', 'a-p---mg-']},
#  'μέν': {'lemmas': ['μέν'], 'postags': ['d--------']},
#  'γιγνομένων': {'lemmas': ['γίγνομαι'],
#   'postags': ['v-pppeng-', 'v-pppemg-', 'v-pppefg-']},
#  'οἶμαι': {'lemmas': ['οἴομαι', 'οἱόμαι'],
#   'postags': ['v1spie---', 'v1spie--------']},
#  'πράττεσθαί': {'lemmas': ['πράσσω'], 'postags': ['v--pne---']},
#  'τιν᾽': {'lemmas': ['τις'],
#   'postags': ['p-p---na-',
#    'p-s---fa-',
#    'p-s---ma-',
#    'a-s---ma-',
#    'a-s---ma_',
#    'a-s---fa_']},
#  'ὧν': {'lemmas': ['ὅς', 'οὖν', 'οὗν'],
#   'postags': ['p-p---ng-',
#    'p-p---mg-',
#    'p-p---fg-',
#    'a-p---mg_',
#    'a-p---ng_',
#    'a-p---fg_',
#    'd--------']},
#  'προσῆκεν': {'lemmas': ['προσήκω'], 'postags': ['v3siia---']},
#  'τούτου': {'lemmas': ['οὗτος'],
#   'postags': ['p-s---ng-',
#    'p-s---mg-',
#    'a-s---mg_',
#    'a-s---ng_',
#    'a-s---ng-',
#    'a-s---mg-',
#    'a-s---fg-']},
#  'ἔθεντο': {'lemmas': ['τίθημι'], 'postags': ['v3paim---', 'v3paim--------']},
#  'παλαιοί': {'lemmas': ['παλαιός'], 'postags': ['a-p---mn-']},
#  'γοῦν': {'lemmas': ['γοῦν'], 'postags': ['d--------']},
#  'λέγει': {'lemmas': ['λέγω3', 'λέγω2', 'λέγω'],
#   'postags': ['v3spia---', 'v3spia--------']},
#  'νόμος': {'lemmas': ['νόμος'], 'postags': ['n-s---mn-']},
#  'ἐάν': {'lemmas': ['ἐάν'], 'postags': ['c--------']},
#  'τινα': {'lemmas': ['τις'],
#   'postags': ['p-s---ma-',
#    'a-s---fa_',
#    'a-s---ma_',
#    'p-p---na-',
#    'a-s---fa-',
#    'p-s---fa-',
#    'a-s---ma-',
#    'a-p---na_',
#    'p-p---nn-',
#    'a-p---nn_',
#    'a-s---na-']},
#  'ἐκμισθώσῃ': {'lemmas': ['ἐκμισθόω'], 'postags': ['v3sasa---']},
#  'ἑταιρεῖν': {'lemmas': ['ἑταιρέω'], 'postags': ['v--pna---']},
#  'πατὴρ': {'lemmas': ['πατήρ'], 'postags': ['n-s---mn-']},
#  'θεῖος': {'lemmas': ['θεῖος2', 'θεῖος1'],
#   'postags': ['n-s---mn-', 'a-s---mn-']},
#  'ἐπίτροπος': {'lemmas': ['ἐπίτροπος'], 'postags': ['a-s---mn-']},
#  'ὅλως': {'lemmas': ['ὅλος', 'ὅλοξ'], 'postags': ['d--------', 'd-------p']},
#  'κυρίων': {'lemmas': ['κύριος'], 'postags': ['n-p---mg-']},
#  'κατ᾽': {'lemmas': ['κατά'], 'postags': ['r--------']},
#  'αὐτοῦ': {'lemmas': ['αὐτός', 'αὐτοῦ', 'αὐτοός'],
#   'postags': ['a-s---mg_',
#    'p-s---mg-',
#    'p-s---ng-',
#    'a-s---ng_',
#    'd--------',
#    'a-s---mg-',
#    'a-s---ng-',
#    'p-s----g-',
#    'a-s---md-']},
#  'παιδὸς': {'lemmas': ['παῖς'], 'postags': ['n-s---mg-', 'n-s---fg-']},
#  'ἐᾷ': {'lemmas': ['ἐάω'], 'postags': ['v3spsa---', 'v3spia---']},
#  'μισθώσαντος': {'lemmas': ['μισθόω'], 'postags': ['v-sapamg-']},
#  'μισθωσαμένου': {'lemmas': ['μισθόω'], 'postags': ['v-sapmmg-']},
#  'ἐξεμίσθωσε': {'lemmas': ['ἐκμισθόω'], 'postags': ['v3saia---']},
#  'φησίν': {'lemmas': ['φημί'], 'postags': ['v3spia---', 'v3spia--------']},
#  'ἐμισθώσατο': {'lemmas': ['μισθόω'], 'postags': ['v3saim---']},
#  'κατά': {'lemmas': ['κατά'],
#   'postags': ['r--------', 'c--------', 'd--------', 'd-------_']},
#  'ἴσα': {'lemmas': ['ἴσος'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'ἐπιτίμια': {'lemmas': ['ἐπιτίμιον'], 'postags': ['n-p---na-']},
#  'ἑκατέρῳ': {'lemmas': ['ἑκάτερος'], 'postags': ['a-s---md-', 'a-s---nd-']},
#  'πεποίηκε': {'lemmas': ['ποιέω'], 'postags': ['v3sria---', 'v2srma---']},
#  'ἐπάναγκες': {'lemmas': ['ἐπανάγκης'], 'postags': ['a-s---nn-', 'a-s---na-']},
#  'παιδὶ': {'lemmas': ['παῖς'],
#   'postags': ['n-s---md-', 'n-s---fd-', 'n-s----d-']},
#  'ἡβήσαντι': {'lemmas': ['ἡβάω'], 'postags': ['v-sapamd-']},
#  'τρέφειν': {'lemmas': ['τρέφω'], 'postags': ['v--pna---']},
#  'πατέρα': {'lemmas': ['πατήρ'], 'postags': ['n-s---ma-']},
#  'μη': {'lemmas': ['μη', 'μηδέ', 'μή'], 'postags': ['d-------_', 'd--------']},
#  '-δὲ': {'lemmas': ['δέ', 'μηδέ', '-δέ', 'οὐδέ', 'οδέ', 'δὲ'],
#   'postags': ['c--------', 'd--------']},
#  'οἴκησιν': {'lemmas': ['οἴκησις'], 'postags': ['n-s---fa-']},
#  'παρέχειν': {'lemmas': ['παρέχω'], 'postags': ['v--pna---']},
#  'ὃς': {'lemmas': ['ὅς', 'ὅς2'],
#   'postags': ['p-s---mn-', 'p3s---fn-', 'a-s---mn_']},
#  'ἐκμισθωθῇ': {'lemmas': ['ἐκμισθόω'], 'postags': ['v3sasp---']},
#  'ἀποθανόντα': {'lemmas': ['ἀποθνήσκω', 'ἀποθνῄσκω'],
#   'postags': ['v-sapama-']},
#  'θαπτέτω': {'lemmas': ['θάπτω'], 'postags': ['v3spma---']},
#  'τ-': {'lemmas': ['ὁ', 'τε', 'τά', 'τέ'],
#   'postags': ['l-s---na-',
#    'l-s---nn-',
#    'l-s---nd-',
#    'l-p---na-',
#    'l-p---nn-',
#    'c--------',
#    'l-s---mg-',
#    'l-s---ng-',
#    'l-s---md-',
#    'd-------_']},
#  'ἆλλα': {'lemmas': ['ἄλλος', 'ἆλλος'],
#   'postags': ['p-p---na-', 'a-p---na_', 'a-p---nn_', 'p-p---nn-']},
#  'ποιείτω': {'lemmas': ['ποιέω'], 'postags': ['v3spma---']},
#  'νομιζόμενα': {'lemmas': ['νομίζω'], 'postags': ['v-pppena-', 'v-pppenn-']},
#  'δή': {'lemmas': ['δή'], 'postags': ['d--------']},
#  'ζῶντος': {'lemmas': ['ζάω'], 'postags': ['v-sppamg-']},
#  'ἀφαιρεῖται': {'lemmas': ['ἀφαιρέω'], 'postags': ['v3spie---']},
#  'ὄνησιν': {'lemmas': ['ὄνησις'], 'postags': ['n-s---fa-']},
#  'παιδοποιίας': {'lemmas': ['παιδοποιία'], 'postags': ['n-s---fg-']},
#  'ὥσπερ': {'lemmas': ['ὥσπερ'], 'postags': ['c--------', 'd--------']},
#  'ἐκείνου': {'lemmas': ['ἐκεῖνος', 'ἐκείνος', 'εκεῖνος'],
#   'postags': ['p-s---mg-',
#    'a-s---ng_',
#    'a-s---mg-',
#    'p-s---ng-',
#    'a-s---mg_']},
#  'παρρησίαν': {'lemmas': ['παρρησία'], 'postags': ['n-s---fa-']},
#  'τελευτήσαντα': {'lemmas': ['τελευτάω'],
#   'postags': ['v-sapama-', 'v-papann-']},
#  'αὐτόν': {'lemmas': ['αὐτός'],
#   'postags': ['p-s---ma-', 'a-s---ma_', 'p-s---na-', 'a-s---ma-']},
#  'ἡνίκα': {'lemmas': ['ἡνίκα'], 'postags': ['c--------', 'd--------']},
#  'εὐεργετούμενος': {'lemmas': ['εὐεργετέω'], 'postags': ['v-sppemn-']},
#  'αἰσθάνεται': {'lemmas': ['αἰσθάνομαι'], 'postags': ['v3spim---']},
#  'πάσχει': {'lemmas': ['πάσχω'], 'postags': ['v3spia---']},
#  'τιμᾶται': {'lemmas': ['τιμάω'],
#   'postags': ['v3spse---', 'v3spip---', 'v3spie---']},
#  'θεῖον': {'lemmas': ['θεῖος1', 'θεῖος2', 'θέω', 'θεῖος'],
#   'postags': ['a-s---nn-',
#    'n-s---ma-',
#    'v-sppana-',
#    'a-s---na-',
#    'n-s---na-',
#    'a-s---ma-']},
#  'θάπτειν': {'lemmas': ['θάπτω'], 'postags': ['v--pna---']},
#  'ποιεῖν': {'lemmas': ['ποιέω'], 'postags': ['v--pna---']},
#  'τίνα': {'lemmas': ['τις', 'ὁς', 'τίς'],
#   'postags': ['a-s---ma_',
#    'p-p---nn-',
#    'a-s---fa_',
#    'p-s---ma-',
#    'a-p---nn_',
#    'a-s---fa-',
#    'p-p---na-',
#    'p-s---na-',
#    'a-s----a-']},
#  'ἕτερον': {'lemmas': ['ἕτερος'],
#   'postags': ['a-s---ma-', 'a-s---nn-', 'a-s---na-']},
#  'νόμον': {'lemmas': ['νόμος'], 'postags': ['n-s---ma-']},
#  'ἔθηκε': {'lemmas': ['τίθημι'], 'postags': ['v3saia---']},
#  'φύλακα': {'lemmas': ['φύλαξ'], 'postags': ['n-s---ma-', 'n-s---fa-']},
#  ';': {'lemmas': ['punc1', ';'], 'postags': ['u--------']},
#  'προαγωγείας': {'lemmas': ['προαγωγεία'], 'postags': ['n-s---fg-']},
#  'μέγιστα': {'lemmas': ['μέγας'],
#   'postags': ['a-p---nas', 'a-p---nns', 'a-p---nn-', 'a-p---na-']},
#  'ἐπιγράψας': {'lemmas': ['ἐπιγράφω'], 'postags': ['v-sapamn-']},
#  'γυναῖκα': {'lemmas': ['γυνή'], 'postags': ['n-s---fa-']},
#  'προαγωγεύῃ': {'lemmas': ['προαγωγεύω'], 'postags': ['v3spsa---']},
#  'ποῖον': {'lemmas': ['ποῖος'],
#   'postags': ['a-s---nn-', 'a-s---na-', 'a-s---ma-']},
#  'ἄλλον': {'lemmas': ['ἄλλος'],
#   'postags': ['p-s---ma-', 'a-s---ma_', 'a-s---ma-']},
#  'ὕβρεως': {'lemmas': ['ὕβρις'], 'postags': ['n-s---fg-']},
#  'ἑνὶ': {'lemmas': ['εἷς', 'ἑν'],
#   'postags': ['a-s---nd_',
#    'n-s---nd-',
#    'r--------',
#    'n-s---md-',
#    'a-s---md_',
#    'a-s---nd-']},
#  'κεφαλαίῳ': {'lemmas': ['κεφάλαιος'], 'postags': ['a-s---nd-']},
#  'ἅπαντα': {'lemmas': ['ἅπας'],
#   'postags': ['a-p---na-', 'a-p---nn-', 'a-s---ma-', 'a-p---mn-']},
#  'τοιαῦτα': {'lemmas': ['τοιοῦτος'],
#   'postags': ['p-p---na-',
#    'a-p---na_',
#    'p-p---nn-',
#    'a-p---nn_',
#    'a-p---na-']},
#  'συλλαβὼν': {'lemmas': ['συλλαμβάνω'], 'postags': ['v-sapamn-']},
#  'ἔχει': {'lemmas': ['ἔχω', 'ἐχώ', 'χέω'],
#   'postags': ['v3spia---', 'v3siia---']},
#  'ᾧ': {'lemmas': ['ὅς'],
#   'postags': ['p-s---nd-',
#    'p-s---md-',
#    'a-s---nd_',
#    'a-s---md_',
#    'p-s---ng-',
#    'a-s---md-']},
#  'γέγραπται': {'lemmas': ['γράφω'], 'postags': ['v3srie---']},
#  'ὑβρίζῃ': {'lemmas': ['ὑβρίζω'], 'postags': ['v3spsa---']},
#  'ὑβρίζει': {'lemmas': ['ὑβρίζω'], 'postags': ['v3spia---']},
#  'που': {'lemmas': ['πού', 'που'], 'postags': ['d--------']},
#  'μισθούμενος': {'lemmas': ['μισθόω'], 'postags': ['v-sppemn-']},
#  'τινὰ': {'lemmas': ['τις'],
#   'postags': ['p-s---ma-',
#    'a-s---fa_',
#    'a-s---ma_',
#    'a-p---nn_',
#    'p-s---fa-',
#    'a-s---fa-',
#    'a-s---ma-',
#    'a-s----a-',
#    'a-p---na_',
#    'p-p---na-',
#    'a-s---na-',
#    'a-p---na-']},
#  'δούλων': {'lemmas': ['δοῦλος'],
#   'postags': ['n-p---mg-', 'a-p---mg-', 'a-p---fg-']},
#  'παράνομόν': {'lemmas': ['παράνομος'], 'postags': ['a-s---na-']},
#  'ποιῇ': {'lemmas': ['ποιέω'], 'postags': ['v3spsa---', 'v2spse---']},
#  'τινά': {'lemmas': ['τις'],
#   'postags': ['p-s---ma-',
#    'p-s---fa-',
#    'a-s---fa_',
#    'a-s---ma_',
#    'a-s---fa-',
#    'a-p---na-']},
#  'γραφὰς': {'lemmas': ['γραφή'], 'postags': ['n-p---fa-']},
#  'πεποίηκεν': {'lemmas': ['ποιέω'], 'postags': ['v3sria---']},
#  'τίμημα': {'lemmas': ['τίμημα'], 'postags': ['n-s---na-', 'n-s---nn-']},
#  'ἐπέθηκεν': {'lemmas': ['ἐπιτίθημι'], 'postags': ['v3saia---']},
#  'ὅ': {'lemmas': ['ὅς', 'ὁ', 'ὁς'],
#   'postags': ['p-s---na-',
#    'l-s---mn-',
#    'a-s---nn_',
#    'p-s---nn-',
#    'a-s---na_']},
#  'παθεῖν': {'lemmas': ['πάσχω'], 'postags': ['v--ana---']},
#  'ἀποτεῖσαι': {'lemmas': ['ἀποτίνω'], 'postags': ['v--ana---']},
#  'Ἀθηναίων': {'lemmas': ['Ἀθήναιος', 'Ἀθήναιον', 'Ἀθηναῖος', 'Ἀθήναια'],
#   'postags': ['n-p---mg-', 'n-p---ng-', 'a-p---mg-']},
#  'ὑβρίσῃ': {'lemmas': ['ὑβρίζω'], 'postags': ['v3sasa---']},
#  'γραφέσθω': {'lemmas': ['γράφω'], 'postags': ['v3spme---']},
#  'κύριος': {'lemmas': ['κύριος', 'κῦρος'],
#   'postags': ['n-s---mn-', 'a-s---mn-', 'n-s---ng-']},
#  'θεσμοθέτας': {'lemmas': ['θεσμοθέτης'], 'postags': ['n-p---ma-']},
#  'ἐπιγραψάμενος': {'lemmas': ['ἐπιγράφω'], 'postags': ['v-sapmmn-']},
#  'οὗ': {'lemmas': ['ὅς', 'οὗ', 'ὁς'],
#   'postags': ['p-s---mg-',
#    'p-s---ng-',
#    'd--------',
#    'a-s---mg_',
#    'a-s---ng_']},
#  'δικαστήριον': {'lemmas': ['δικαστήριον'],
#   'postags': ['n-s---nn-', 'n-s---na-']},
#  'καταψηφίσηται': {'lemmas': ['καταψηφίζομαι'], 'postags': ['v3sase---']},
#  'παραδοθεὶς': {'lemmas': ['παραδίδωμι'], 'postags': ['v-sappmn-']},
#  'ἕνδεκα': {'lemmas': ['ἕνδεκα'],
#   'postags': ['a-_---___', 'a--------', 'm--------']},
#  'τεθνάτω': {'lemmas': ['θνήσκω'], 'postags': ['v3srma---']},
#  'αὐθημερόν': {'lemmas': ['αὐθήμερος'], 'postags': ['d--------']},
#  'ἀργύριον': {'lemmas': ['ἀργύριον'], 'postags': ['n-s---na-', 'n-s---nn-']},
#  'καταψηφισθῇ': {'lemmas': ['καταψηφίζομαι'], 'postags': ['v3sase---']},
#  'ἀποτεισάτω': {'lemmas': ['ἀποτίνω'], 'postags': ['v3sama---']},
#  'ἡμέραις': {'lemmas': ['ἡμέρα'], 'postags': ['n-p---fd-']},
#  'δίκην': {'lemmas': ['δίκη'], 'postags': ['n-s---fa-']},
#  'παραχρῆμα': {'lemmas': ['παραχρῆμα'], 'postags': ['d--------']},
#  'δύνηται': {'lemmas': ['δύναμαι'], 'postags': ['v3spse---']},
#  'ἀποτίνειν': {'lemmas': ['ἀποτίνω'], 'postags': ['v--pna---']},
#  'ἕως': {'lemmas': ['ἕως', 'ἔως', 'ἑώς'],
#   'postags': ['c--------', 'r--------', 'd-------_', 'd--------']},
#  'εἱρχθήτω': {'lemmas': ['ἔργω1'], 'postags': ['v3samp---']},
#  'ἔνοχοι': {'lemmas': ['ἔνοχος'], 'postags': ['a-p---mn-']},
#  'ἔστασαν': {'lemmas': ['ἵστημι'], 'postags': ['v3paia---']},
#  'ταῖσδε': {'lemmas': ['ὅδε'], 'postags': ['a-p---fd_']},
#  'αἰτίαις': {'lemmas': ['αἰτία'], 'postags': ['n-p---fd-']},
#  'οἰκετικὰ': {'lemmas': ['οἰκετικός'], 'postags': ['a-p---na-']},
#  'ἐξαμαρτάνοντες': {'lemmas': ['ἐξαμαρτάνω'], 'postags': ['v-pppamn-']},
#  'ἴσως': {'lemmas': ['ἴσως', 'ἴσος', 'ἰσός'], 'postags': ['d--------']},
#  'θαυμάσειεν': {'lemmas': ['θαυμάζω'], 'postags': ['v3saoa---']},
#  'ἐξαίφνης': {'lemmas': ['ἐξαίφνης'], 'postags': ['d--------']},
#  'ἀκούσας': {'lemmas': ['ἀκούω', 'ἀκέω', 'ἀέκων'],
#   'postags': ['v-sapamn-',
# ...
#  'νεωτέρους': {'lemmas': ['νέος', 'νεώτερος'],
#   'postags': ['a-p---mac', 'a-p---ma-']},
#  'διδάσκει': {'lemmas': ['διδάσκω'], 'postags': ['v3spia---']},
#  'αἰσχύνεσθαι': {'lemmas': ['αἰσχύνω'], 'postags': ['v--pne---']},
#  'πρεσβυτέρους': {'lemmas': ['πρέσβυς'],
#   'postags': ['a-p---mac', 'a-p---ma-']},
#  'πάνθ᾽': {'lemmas': ['πᾶς'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'ὑστέρους': {'lemmas': ['ὕστερος'], 'postags': ['a-p---ma-']},
#  'τιμᾶν': {'lemmas': ['τιμάω'], 'postags': ['v--pna---']},
#  'γῆρας': {'lemmas': ['γῆρας'], 'postags': ['n-s---na-', 'n-s---nn-']},
#  'ὃ': {'lemmas': ['ὅς', 'ὁ', 'ὁς'],
#   'postags': ['p-s---na-',
#    'p-s---nn-',
#    'l-s---mn-',
#    'a-s---na_',
#    'l-s---nn-',
#    'a-s---nn_',
#    'p-s---fa-']},
#  'ἀφιξόμεθα': {'lemmas': ['ἀφικνέομαι'], 'postags': ['v1pfim---']},
#  'ἄρα': {'lemmas': ['ἄρα'], 'postags': ['d--------']},
#  'διαγενώμεθα': {'lemmas': ['διαγίγνομαι'], 'postags': ['v1pasm---']},
#  'ἦσαν': {'lemmas': ['εἰμί', 'ἄω3'], 'postags': ['v3piia---', 'v3paia---']},
#  'σώφρονες': {'lemmas': ['σώφρων'], 'postags': ['a-p---mn-']},
#  'ἀρχαῖοι': {'lemmas': ['ἀρχαῖος'], 'postags': ['a-p---mn-']},
#  'ἐκεῖνοι': {'lemmas': ['ἐκεῖνος'], 'postags': ['a-p---mn_', 'p-p---mn-']},
#  'ῥήτορες': {'lemmas': ['ῥήτωρ'], 'postags': ['n-p---mn-']},
#  'Περικλῆς': {'lemmas': ['Περικλέης', 'Περικλῆς'],
#   'postags': ['n-s---mv-', 'n-s---mn-']},
#  'Θεμιστοκλῆς': {'lemmas': ['Θεμιστοκλῆς'], 'postags': ['n-s---mn-']},
#  'Ἀριστείδης': {'lemmas': ['Ἀριστείδης'], 'postags': ['n-s---mn-']},
#  'ἀνόμοιον': {'lemmas': ['ἀνόμοιος'], 'postags': ['a-s---fa-']},
#  'ἔχων': {'lemmas': ['ἔχω', 'χόω', 'ἐχώ', 'έχώ', 'χάω'],
#   'postags': ['v-sppamn-', 'v-spgamn-', 'v3piia---', 'v-spiamn-']},
#  'ἐπωνυμίαν': {'lemmas': ['ἐπωνυμία', 'ἐπωνύμιος'],
#   'postags': ['n-s---fa-', 'a-s---fa-']},
#  'ὥστε': {'lemmas': ['ὥστε'], 'postags': ['c--------', 'd--------']},
#  'ἔθει': {'lemmas': ['ἔθος', 'θέω'], 'postags': ['n-s---nd-', 'v3siia---']},
#  'πράττομεν': {'lemmas': ['πράσσω'], 'postags': ['v1ppia---']},
#  'χεῖρα': {'lemmas': ['χείρ'], 'postags': ['n-s---fa-']},
#  'ἔξω': {'lemmas': ['ἔξω'], 'postags': ['d--------', 'r--------']},
#  'ἔχοντες': {'lemmas': ['ἔχω'], 'postags': ['v-pppamn-']},
#  'τότε': {'lemmas': ['τότε'], 'postags': ['d--------']},
#  'θρασύ': {'lemmas': ['θρασύς'], 'postags': ['a-s---nn-']},
#  'ἐδόκει': {'lemmas': ['δοκέω'], 'postags': ['v3siia---']},
#  'εὐλαβοῦντο': {'lemmas': ['εὐλαβέομαι'], 'postags': ['v3piie---']},
#  'αὐτὸ': {'lemmas': ['αὐτός'],
#   'postags': ['p-s---na-',
#    'a-s---nn_',
#    'a-s---na_',
#    'p-s---nn-',
#    'a-s---nn-',
#    'a-s---na-']},
#  'μέγα': {'lemmas': ['μέγας'],
#   'postags': ['a-s---na-', 'a-s---nn-', 'a-s---fn_']},
#  'σημεῖον': {'lemmas': ['σημεῖον'], 'postags': ['n-s---na-', 'n-s---nn-']},
#  'ἔργῳ': {'lemmas': ['ἔργον'], 'postags': ['n-s---nd-']},
#  'ἐπιδείξειν': {'lemmas': ['ἐπιδείκνυμι'], 'postags': ['v--fna---']},
#  'οἶδ᾽': {'lemmas': ['οἶδα'], 'postags': ['v1sria---']},
#  'ἐκπεπλεύκατε': {'lemmas': ['ἐκπλέω'], 'postags': ['v2pria---']},
#  'Σαλαμῖνα': {'lemmas': ['Σαλαμίς'], 'postags': ['n-s---fa-']},
#  'τεθεωρήκατε': {'lemmas': ['θεωρέω'], 'postags': ['v2pria---']},
#  'Σόλωνος': {'lemmas': ['Σόλων'], 'postags': ['n-s---mg-']},
#  'εἰκόνα': {'lemmas': ['εἰκών'], 'postags': ['n-s---fa-', 'n-s---ma-']},
#  'αὐτοὶ': {'lemmas': ['αὐτός'],
#   'postags': ['p-p---mn-', 'a-p---mn_', 'd--------', 'a-p---mn-']},
#  'μαρτυρήσαιτ᾽': {'lemmas': ['μαρτυρέω'], 'postags': ['v2paoa---']},
#  'ἀγορᾷ': {'lemmas': ['ἀγορά'], 'postags': ['n-s---fd-']},
#  'Σαλαμινίων': {'lemmas': ['Σαλαμίνιος'], 'postags': ['n-p---mg-']},
#  'ἀνάκειται': {'lemmas': ['ἀνάκειμαι'], 'postags': ['v3spie---']},
#  'ἐστίν': {'lemmas': ['εἰμί'], 'postags': ['v3spia---']},
#  'ὑπόμνημα': {'lemmas': ['ὑπόμνημα'], 'postags': ['n-s---nn-', 'n-s---na-']},
#  'μίμημα': {'lemmas': ['μίμημα'], 'postags': ['n-s---nn-']},
#  'σχήματος': {'lemmas': ['σχῆμα'], 'postags': ['n-s---ng-']},
#  'διελέγετο': {'lemmas': ['διαλέγω'], 'postags': ['v3siie---']},
#  'ὅσον': {'lemmas': ['ὅσος'],
#   'postags': ['a-s---na-', 'a-s---nn-', 'a-s---ma-', 'p-s---ma-']},
#  'διαφέρει': {'lemmas': ['διαφέρω'], 'postags': ['v3spia---', 'v2spie---']},
#  'ἐπεμνήσθην': {'lemmas': ['ἐπιμιμνήσκομαι'], 'postags': ['v1saip---']},
#  'ᾐσχύνοντο': {'lemmas': ['αἰσχύνω'], 'postags': ['v3piie---']},
#  'οὑτοσὶ': {'lemmas': ['οὗτος'],
#   'postags': ['p-s---mn-', 'a-s---mn_', 'a-s---mn-']},
#  'πάλαι': {'lemmas': ['πάλαι', 'πάλα'], 'postags': ['d--------', 'n-p---fn-']},
#  'πρώην': {'lemmas': ['πρώην'], 'postags': ['d--------']},
#  'ποτὲ': {'lemmas': ['ποτέ', 'ποτός'], 'postags': ['d--------']},
#  'ῥίψας': {'lemmas': ['ῥίπτω'], 'postags': ['v-sapamn-']},
#  'θ-': {'lemmas': ['ὁ'], 'postags': ['l-s---na-']},
#  'οἰμάτιον': {'lemmas': ['ἰμάτιον'], 'postags': ['n-s---na-']},
#  'γυμνὸς': {'lemmas': ['γυμνός'], 'postags': ['a-s---mn-']},
#  'ἐπαγκρατίαζεν': {'lemmas': ['παγκρατιάζω'], 'postags': ['v3siia---']},
#  'ἐκκλησίᾳ': {'lemmas': ['ἐκκλησία'], 'postags': ['n-s---fd-']},
#  'διακείμενος': {'lemmas': ['διάκειμαι'], 'postags': ['v-srpemn-']},
#  'σῶμα': {'lemmas': ['σῶμα'],
#   'postags': ['n-s---na-', 'n-s---nn-', 'n-s---nv-']},
#  'μέθης': {'lemmas': ['μέθη'], 'postags': ['n-s---fg-']},
#  'βδελυρίας': {'lemmas': ['βδελυρία'], 'postags': ['n-s---fg-', 'n-p---fa-']},
#  'ἐγκαλύψασθαι': {'lemmas': ['ἐγκαλύπτω'], 'postags': ['v--anm---']},
#  'αἰσχυνθέντας': {'lemmas': ['αἰσχύνω'], 'postags': ['v-pappma-']},
#  'τοιούτοις': {'lemmas': ['τοιοῦτος'],
#   'postags': ['a-p---md_',
#    'p-p---md-',
#    'p-p---nd-',
#    'a-p---nd_',
#    'a-p---nd-',
#    'a-p---md-']},
#  'συμβούλοις': {'lemmas': ['σύμβουλος'], 'postags': ['n-p---md-']},
#  'χρώμεθα': {'lemmas': ['χράομαι'], 'postags': ['v1ppse---', 'v1ppie---']},
#  'συνιδὼν': {'lemmas': ['σύν-εἶδον'], 'postags': ['v-sapamn-']},
#  'ἀπέδειξεν': {'lemmas': ['ἀποδείκνυμι'], 'postags': ['v3saia---']},
#  'ἀπελαύνει': {'lemmas': ['ἀπελαύνω'], 'postags': ['v3spia---']},
#  'βήματος': {'lemmas': ['βῆμα'], 'postags': ['n-s---ng-']},
#  'εἴ': {'lemmas': ['εἰ', 'εἴ'], 'postags': ['c--------']},
#  'προγόνων': {'lemmas': ['πρόγονος'], 'postags': ['n-p---mg-']},
#  'ἐστὶν': {'lemmas': ['εἰμί'], 'postags': ['v3spia---']},
#  'ἐστρατηγηκότων': {'lemmas': ['στρατηγέω'], 'postags': ['v-prpamg-']},
#  '-δέ': {'lemmas': ['δέ'], 'postags': ['c--------', 'd--------']},
#  'τέχνην': {'lemmas': ['τέχνη'], 'postags': ['n-s---fa-']},
#  'ἐργάζεται': {'lemmas': ['ἐργάζομαι'], 'postags': ['v3spie---']},
#  'ἐπικουρῶν': {'lemmas': ['ἐπί-ἐπικουρέω'], 'postags': ['v-sppamn-']},
#  'ἀναγκαίᾳ': {'lemmas': ['ἀναγκαῖος'], 'postags': ['a-s---fd-']},
#  'τροφῇ': {'lemmas': ['τροφή', 'τροφεύς'],
#   'postags': ['n-s---fd-', 'n-s---md-']},
#  'ἀσπάζεται': {'lemmas': ['ἀσπάζομαι'], 'postags': ['v3spie---']},
#  'πολλάκις': {'lemmas': ['πολλάκις'], 'postags': ['d--------']},
#  'τίνας': {'lemmas': ['τις', 'τίς'],
#   'postags': ['p-p---ma-', 'a-p---fa_', 'a-p---ma_', 'a-p----a-']},
#  'ᾤετο': {'lemmas': ['οἴομαι'], 'postags': ['v3siie---']},
#  'δεῖν': {'lemmas': ['δεῖ', 'δέω1', 'δέω2', 'δέω'],
#   'postags': ['v--pna---', 'v-spp-nn-', 'v-sppana-', 'v-spp-na-']},
#  'ποῦ': {'lemmas': ['πού', 'ποῦ'], 'postags': ['d--------']},
#  'δηλοῖ': {'lemmas': ['δηλόω'], 'postags': ['v3spia---']},
#  'δοκιμασία': {'lemmas': ['δοκιμασία'], 'postags': ['n-s---fn-']},
#  'λέγῃ': {'lemmas': ['λέγω3'], 'postags': ['v3spsa---']},
#  'τύπτων': {'lemmas': ['τύπτω'], 'postags': ['v-sppamn-']},
#  'μητέρα': {'lemmas': ['μήτηρ'], 'postags': ['n-s---fa-']},
#  'τρέφων': {'lemmas': ['τρέφω'], 'postags': ['v-sppamn-']},
#  'παρέχων': {'lemmas': ['παραχώννυμι', 'παρέχω'],
#   'postags': ['v3piia---', 'v-spiamn-']},
#  'νὴ': {'lemmas': ['νή'], 'postags': ['r--------', 'd--------']},
#  'Δία': {'lemmas': ['Ζεύς', 'Δίον', 'Δίη'],
#   'postags': ['n-s---ma-',
#    'n-p---nn-',
#    'n-p---nv-',
#    'n-p---na-',
#    'n-s---fn-',
#    'n-s---fv-']},
#  'ἔγωγέ': {'lemmas': ['ἐγώ'], 'postags': ['p1s---mn-']},
#  'φημι': {'lemmas': ['φημί'], 'postags': ['v1spia---']},
#  'ἴσου': {'lemmas': ['ἴσος'], 'postags': ['a-s---ng-']},
#  'θεοῖς': {'lemmas': ['θεός'], 'postags': ['n-p---md-']},
#  'ἐστὶ': {'lemmas': ['εἰμί'], 'postags': ['v3spia---']},
#  'φαῦλος': {'lemmas': ['φαῦλος'], 'postags': ['a-s---mn-']},
#  'ποτε': {'lemmas': ['ποτέ'], 'postags': ['d--------']},
#  'ὑπ᾽': {'lemmas': ['ὑπό'], 'postags': ['r--------']},
#  'πείσονται': {'lemmas': ['πάσχω'], 'postags': ['v3pfim---']},
#  'ἀλλότριοι': {'lemmas': ['ἀλλότριος'], 'postags': ['a-p---mn-']},
#  'ὅλη': {'lemmas': ['ὅλος'], 'postags': ['a-s---fn-']},
#  'τίσι': {'lemmas': ['τις'],
#   'postags': ['p-p---md-', 'a-p---md_', 'a-p---fd_', 'p-p---nd-']},
#  'ἀπεῖπε': {'lemmas': ['ἀπεῖπον'], 'postags': ['v3saia---']},
#  'στρατείας': {'lemmas': ['στρατεία'], 'postags': ['n-p---fa-', 'n-s---fg-']},
#  'ἐστρατευμένος': {'lemmas': ['στρατεύω'], 'postags': ['v-srpemn-']},
#  'ὅσαι': {'lemmas': ['ὅσος'], 'postags': ['a-p---fn-', 'p-p---fn-']},
#  'προσταχθῶσιν': {'lemmas': ['προστάσσω'], 'postags': ['v3pasp---']},
#  'ἀσπίδα': {'lemmas': ['ἀσπίς'], 'postags': ['n-s---fa-']},
#  'ἀποβεβληκώς': {'lemmas': ['ἀποβάλλω'], 'postags': ['v-srpamn-']},
#  'δίκαια': {'lemmas': ['δίκαιος'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'λέγων': {'lemmas': ['λέγω3', 'λέγω2', 'λέγω'],
#   'postags': ['v-sppamn-', 'v-sppamv_']},
#  'ἄνθρωπε': {'lemmas': ['ἄνθρωπος'], 'postags': ['n-s---mv-']},
#  'ἧς': {'lemmas': ['ὅς', 'εἷς', 'ὁς'],
#   'postags': ['p-s---fg-',
#    'a-s---fg_',
#    'p-s---fa-',
#    'n-s---mn-',
#    'p-s---mg-']},
#  'ὅπλα': {'lemmas': ['ὅπλον'], 'postags': ['n-p---na-', 'n-p---nn-']},
#  'τίθεσαι': {'lemmas': ['τίθημι'], 'postags': ['v2spie---']},
#  'δειλίαν': {'lemmas': ['δειλία'], 'postags': ['n-s---fa-']},
#  'δυνατὸς': {'lemmas': ['δυνατός'], 'postags': ['a-s---mn-']},
#  'εἶ': {'lemmas': ['εἰμί', 'εἶμι', 'εἰ'],
#   'postags': ['v2spia---', 'c--------']},
#  'ἐπαμῦναι': {'lemmas': ['ἐπαμύνω'], 'postags': ['v--ana---']},
#  'μηδὲ': {'lemmas': ['μηδέ'], 'postags': ['d--------', 'c--------']},
#  'συμβουλεύειν': {'lemmas': ['συμβουλεύω'], 'postags': ['v--pna---']},
#  'βουλεύειν': {'lemmas': ['βουλεύω'], 'postags': ['v--pna---']},
#  'ἀξίου': {'lemmas': ['ἀξιόω', 'ἄξιος'],
#   'postags': ['v2spma---', 'a-s---ng-']},
#  'πεπορνευμένος': {'lemmas': ['πορνεύω'], 'postags': ['v-srpemn-']},
#  'ἡταιρηκώς': {'lemmas': ['ἑταιρέω'], 'postags': ['v-srpamn-']},
#  'ἐφ᾽': {'lemmas': ['ἐπί'], 'postags': ['r--------']},
#  'ὕβρει': {'lemmas': ['ὕβρις'], 'postags': ['n-s---fd-', 'n-d---fn-']},
#  'πεπρακότα': {'lemmas': ['πιπράσκω'], 'postags': ['v-srpama-']},
#  'κοινὰ': {'lemmas': ['κοινός'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'ῥᾳδίως': {'lemmas': ['ῥᾴδιος'], 'postags': ['d--------']},
#  'ἀποδώσεσθαι': {'lemmas': ['ἀποδίδωμι'], 'postags': ['v--fnm---']},
#  'τέταρτον': {'lemmas': ['τέταρτος'],
#   'postags': ['a-s---na-', 'a-s---ma-', 'a-s---nn-']},
#  'πατρῷα': {'lemmas': ['πατρῷος'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'κατεδηδοκώς': {'lemmas': ['κατεσθίω'], 'postags': ['v-srpamn-']},
#  'κληρονόμος': {'lemmas': ['κληρονόμος'], 'postags': ['n-s---mn-']},
#  'γένηται': {'lemmas': ['γίγνομαι'], 'postags': ['v3sasm---']},
#  'ἰδίαν': {'lemmas': ['ἴδιος'], 'postags': ['a-s---fa-']},
#  'οἰκίαν': {'lemmas': ['οἰκία'], 'postags': ['n-s---fa-']},
#  'οἰκήσαντα': {'lemmas': ['οἰκέω'], 'postags': ['v-sapama-']},
#  'παραπλησίως': {'lemmas': ['παραπλήσιος'],
#   'postags': ['d-------_', 'a-p---ma-', 'd-------p', 'd--------']},
#  'διαθήσειν': {'lemmas': ['διατίθημι'], 'postags': ['v--fna---']},
#  'οἷόν': {'lemmas': ['οἷος'],
#   'postags': ['a-s---ma-', 'a-s---nn-', 'a-s---na-', 'p-s---nn-']},
#  'τ᾽': {'lemmas': ['τε', 'σύ', 'τ᾽', 'τέ'],
#   'postags': ['d--------', 'c--------', 'p2s----a-']},
#  'νομοθέτῃ': {'lemmas': ['νομοθέτης'], 'postags': ['n-s---md-']},
#  'ἄνθρωπον': {'lemmas': ['ἄνθρωπος'], 'postags': ['n-s---fa-', 'n-s---ma-']},
#  'πονηρόν': {'lemmas': ['πονηρός'],
#   'postags': ['a-s---ma-', 'a-s---nn-', 'a-s---na-']},
#  'δημοσίᾳ': {'lemmas': ['δημοσίᾳ', 'δημόσιος'],
#   'postags': ['d--------', 'a-s---fd-']},
#  'χρηστόν': {'lemmas': ['χρηστός'], 'postags': ['a-s---ma-']},
#  'ῥήτορα': {'lemmas': ['ῥήτωρ'], 'postags': ['n-s---ma-']},
#  'ἥκειν': {'lemmas': ['ἥκω'], 'postags': ['v--pna---']},
#  'λόγων': {'lemmas': ['λόγος', 'λογός'],
#   'postags': ['n-p---mg-', 'n-p---mn-']},
#  'ἐπιμεληθέντα': {'lemmas': ['ἐπιμελέομαι'], 'postags': ['v-sapema-']},
#  'βίου': {'lemmas': ['βίος', 'βιός'], 'postags': ['n-s---mg-']},
#  'ἀνδρὸς': {'lemmas': ['ἀνήρ'], 'postags': ['n-s---mg-']},
#  'καλοῦ': {'lemmas': ['καλός'], 'postags': ['a-s---mg-', 'a-s---ng-']},
#  'ἀγαθοῦ': {'lemmas': ['ἀγαθός'], 'postags': ['a-s---mg-', 'a-s---ng-']},
#  'ἁπλῶς': {'lemmas': ['ἁπλῶς', 'ἁπλός', 'ἁπλόος', 'ἁπλώς'],
#   'postags': ['d--------', 'd-------p']},
#  'ῥηθῇ': {'lemmas': ['ἐρῶ'], 'postags': ['v3sasp---']},
#  'χρήσιμα': {'lemmas': ['χρήσιμος'], 'postags': ['a-p---na-', 'a-p---nn-']},
#  'λεγόμενα': {'lemmas': ['λέγω3'], 'postags': ['v-pppena-', 'v-pppenn-']},
#  'ἀκούουσι': {'lemmas': ['ἀκούω'], 'postags': ['v-pppamd-', 'v3ppia---']},
#  'βδελυροῦ': {'lemmas': ['βδελυρός'], 'postags': ['a-s---mg-']},
#  'καταγελάστως': {'lemmas': ['καταγέλαστος'], 'postags': ['d-------p']},
#  'κεχρημένου': {'lemmas': ['χράω2'], 'postags': ['v-srpemg-']},
#  'πατρῴαν': {'lemmas': ['πατρῷος'], 'postags': ['a-s---fa-']},
#  'κατεδηδοκότος': {'lemmas': ['κατεσθίω'], 'postags': ['v-srpamg-']},
#  'λεχθῇ': {'lemmas': ['λέγω3'], 'postags': ['v3sasp---']},
#  'συνοίσειν': {'lemmas': ['συμφέρω'], 'postags': ['v--fna---']},
#  'ἐξείργει': {'lemmas': ['ἐξέργω'], 'postags': ['v3spia---']},
#  'συκοφαντῇ': {'lemmas': ['συκοφαντέω'], 'postags': ['v3spsa---']},
#  'ἀσελγαίνῃ': {'lemmas': ['ἀσελγαίνω'], 'postags': ['v3spsa---']},
#  'μηκέτι': {'lemmas': ['μηκέτι'], 'postags': ['d--------']},
#  'τοιοῦτον': {'lemmas': ['τοιοῦτος'],
#   'postags': ['a-s---na_',
#    'p-s---ma-',
#    'a-s---nn_',
#    'p-s---na-',
#    'p-s---nn-',
#    'a-s---ma_',
#    'a-s---na-',
#    'a-s---ma-',
#    'a-s---nn-']},
#  'ἐπαγγειλάτω': {'lemmas': ['ἐπαγγέλλω'], 'postags': ['v3sama---']},
#  'δικαστηρίῳ': {'lemmas': ['δικαστήριον'], 'postags': ['n-s---nd-']},
#  'διαγιγνώσκειν': {'lemmas': ['διαγιγνώσκω'], 'postags': ['v--pna---']},
#  'ἥκω': {'lemmas': ['ἥκω'], 'postags': ['v1spia---']},
#  'νενομοθέτηται': {'lemmas': ['νομοθετέω'], 'postags': ['v3srie---']},
#  'ἔτι': {'lemmas': ['ἔτι'], 'postags': ['d--------']},
#  'προσέθεσθε': {'lemmas': ['προστίθημι'], 'postags': ['v2paim---']},
#  'καινὸν': {'lemmas': ['καινός'], 'postags': ['a-s---ma-', 'a-s---na-']},
#  'καλὸν': {'lemmas': ['καλός'],
#   'postags': ['a-s---na-', 'a-s---ma-', 'a-s---nn-']},
#  'παγκράτιον': {'lemmas': ['παγκράτιον'], 'postags': ['n-s---na-']},
#  'ἐπαγκρατίασεν': {'lemmas': ['παγκρατιάζω'], 'postags': ['v3saia---']},
#  'ὑπεραισχυνθέντες': {'lemmas': ['ὑπεραισχύνομαι'], 'postags': ['v-papemn-']},
#  'πράγματι': {'lemmas': ['πρᾶγμα'], 'postags': ['n-s---nd-']},
#  'καθ᾽': {'lemmas': ['κατά', 'καθά'], 'postags': ['r--------', 'd--------']},
#  'ἑκάστην': {'lemmas': ['ἕκαστος'], 'postags': ['a-s---fa-']},
#  'ἐκκλησίαν': {'lemmas': ['ἐκκλησία'], 'postags': ['n-s---fa-']},
#  'ἀποκληροῦν': {'lemmas': ['ἀποκληρόω'], 'postags': ['v--pna---']},
#  'φυλὴν': {'lemmas': ['φυλή'], 'postags': ['n-s---fa-']},
#  'προεδρεύσει': {'lemmas': ['προεδρεύω'], 'postags': ['v3sfia---']},
#  'προσέταξεν': {'lemmas': ['προστάσσω'], 'postags': ['v3saia---']},
#  'τιθεὶς': {'lemmas': ['τίθημι'], 'postags': ['v-sppamn-']},
#  'καθῆσθαι': {'lemmas': ['κάθημαι'], 'postags': ['v--rnm---']},
#  'φυλέτας': {'lemmas': ['φυλέτης'], 'postags': ['n-p---ma-']},
#  'βοηθοῦντας': {'lemmas': ['βοηθέω'], 'postags': ['v-pppama-']},
#  'βοήθειάν': {'lemmas': ['βοήθεια'], 'postags': ['n-s---fa-']},
#  'ποθεν': {'lemmas': ['ποθεν'], 'postags': ['d--------']},
#  'μεταπεμψόμεθα': {'lemmas': ['μεταπέμπω'], 'postags': ['v1pasm---']},
#  'δυνησομένους': {'lemmas': ['δύναμαι'], 'postags': ['v-pfpmma-']},
#  'ἔστι': {'lemmas': ['εἰμί'], 'postags': ['v3spia---']},
#  'οὐδὲν': {'lemmas': ['οὐδείς'],
#   'postags': ['a-s---nn_',
#    'p-s---na-',
#    'p-s---nn-',
#    'a-s---na_',
#    'a-s---na-',
#    'a-s---nn-']},
#  'ὄφελος': {'lemmas': ['ὄφελος'], 'postags': ['n-s---nn-', 'n-s---na-']},
#  'ζητεῖν': {'lemmas': ['ζητέω'], 'postags': ['v--pna---']},
#  'τοιούτους': {'lemmas': ['τοιοῦτος'],
#   'postags': ['a-p---ma_', 'p-p---ma-', 'a-p---ma-']},
#  ...}

# %%
forms_with_multiple_lemmas = {}
forms_with_multiple_postags = {}

# Popoliamo i due dizionari
for form, info in dizionario_gorman_statistica.items():
    lemmas = info.get('lemmas', [])
    postags = info.get('postags', [])
    
    if len(lemmas) > 1:
        forms_with_multiple_lemmas[form] = lemmas
        
    if len(postags) > 1:
        forms_with_multiple_postags[form] = postags

# Calcoliamo numero e percentuali
total_forms = len(dizionario_gorman_statistica)

num_forms_multi_lemma = len(forms_with_multiple_lemmas)
perc_forms_multi_lemma = (num_forms_multi_lemma / total_forms) * 100

num_forms_multi_postag = len(forms_with_multiple_postags)
perc_forms_multi_postag = (num_forms_multi_postag / total_forms) * 100

# Creiamo i DataFrame
df_multi_lemma = pd.DataFrame(
    [(form, lemmas) for form, lemmas in forms_with_multiple_lemmas.items()],
    columns=['form', 'lemmas']
)

df_multi_postag = pd.DataFrame(
    [(form, postags) for form, postags in forms_with_multiple_postags.items()],
    columns=['form', 'postags']
)

# Stampa dei risultati
print("Totale forme nel dizionario:", total_forms)
print(f"Forme con più di un lemma: {num_forms_multi_lemma} "
      f"({perc_forms_multi_lemma:.2f}%)")
print(f"Forme con più di un postag: {num_forms_multi_postag} "
      f"({perc_forms_multi_postag:.2f}%)")

print("\nDizionario delle forme con più di un lemma:")
print(forms_with_multiple_lemmas)

print("\nDizionario delle forme con più di un postag:")
print(forms_with_multiple_postags)

print("\nDataFrame delle forme con più di un lemma:")
print(df_multi_lemma)

print("\nDataFrame delle forme con più di un postag:")
print(df_multi_postag)
# Out:
# Totale forme nel dizionario: 69388
# Forme con più di un lemma: 2563 (3.69%)
# Forme con più di un postag: 5945 (8.57%)
#
# Dizionario delle forme con più di un lemma:
# {'τῶν': ['ὁ', 'ὅς'], ',': ['punc1', ',', 'ἒ', '·'], 'ὦ': ['ὦ', 'εἰμί'], 'οὔ': ['οὐ', 'οὔτε', 'οὐκ', 'οὔ'], '-τε': ['τε', '-τε', 'οὔτε'], 'γραφὴν': ['γραφής', 'γραφή'], '-τ᾽': ['τε', 'οὔτε', '-τε'], 'ἐν': ['ἐν', 'εἰς'], 'ἀλλ᾽': ['ἀλλά', 'ἀλλ᾽'], 'ὡς': ['ὡς', 'ὥς'], 'δὲ': ['δέ', 'δὲ', 'οὐδέ'], 'τήν': ['ὁ', 'ὅς'], 'παρὰ': ['παρά', 'πηρά'], 'τοὺς': ['ὁ', 'ὅ', 'ὅς'], 'καὶ': ['καί', 'καὶ'], 'ἰδίᾳ': ['ἴδιος', 'ἰδίᾳ'], '(': ['punc1', '(', '̔', '（'], 'προϊόντος': ['πρόειμι1', 'πρόειμι2'], 'τοῦ': ['ὁ', 'ὅς', 'ὀ', 'ὁς', 'τις', 'τὁ'], 'λόγου': ['λόγος', 'λογόω'], ')': ['punc1', ')', '̓', '）'], 'μὴ': ['μή', 'μὴ'], 'τῇ': ['ὁ', 'ὅς', 'τῇ', 'ὁς'], ':': ['punc1', 'ἒ'], 'εἰδὼς': ['οἶδα', 'εἰδοί'], 'δ᾽': ['δέ', 'δ᾽'], 'ὄντα': ['εἰμί', 'εἴμι', 'ὄντα'], 'τὴν': ['ὁ', 'ὅς'], '.': ['punc1', 'ἒ', '.', 'punct1'], 'οἱ': ['ὁ', 'ἕ', 'οὗ', 'ὀ'], 'λέγεσθαι': ['λέγω3', 'λέγω2'], 'μὲν': ['μέν', 'μὲν'], 'ὅλου': ['ὅλος', 'ὅλοξ'], 'φανήσεται': ['φαίνω', 'φανάω'], '-θ᾽': ['τε', 'οὔτε', '-τε'], 'πόλις': ['πόλις', 'πόόλις'], 'αἰτία': ['αἴτιος', 'αἰτία'], 'ὥς': ['ὡς', 'ὥς'], 'οὐ': ['οὐ', 'οὐκ', 'οὐδέ'], 'ἀλλὰ': ['ἀλλά', 'ἀλλὰ'], 'ῥᾴδιον': ['ῥᾴδιος', 'ῥα
'], 'ἐν': ['r--------', 'd--------'], 'ἀλλ᾽': ['c--------', 'd--------'], 'ὡς': ['c--------', 'd--------', 'r--------', 'd-------_'], 'νομίζω': ['v1spia---', 'v1spsa---'], 'μέτριον': ['a-s---ma-', 'a-s---nn-', 'a-s---na-'], 'πρὸς': ['r--------', 'd-------_', 'd--------'], 'ἕκαστα': ['a-p---na-', 'a-p---nn-'], 'τούτων': ['p-p---ng-', 'p-p---mg-', 'a-p---mg_', 'a-p---ng_', 'p-p---fg-', 'a-p---fg_', 'a-p---ng-', 'a-p---mg-', 'a-p---fg-'], 'ὁρῶν': ['v-sppamn-', 'v-sppann-', 'v-sppamv-'], 'δὲ': ['c--------', 'd--------'], 'τήν': ['l-s---fa-', 'p-s---fa-'], 'τε': ['d--------', 'c--------'], 'μεγάλα': ['a-p---na_', 'a-p---na-', 'a-p---nn-', 'a-d---fn-', 'a-p---nd-', 'a-s---na-', 'a-s---fn-'], 'τουτουὶ': ['a-s---mg_', 'p-s---mg-', 'a-s---mg-', 'a-s---ng_'], 'παρὰ': ['r--------', 'd--------'], 'τοὺς': ['l-p---ma-', 'p-p---ma-'], 'καὶ': ['c--------', 'd--------', 'd-------_', 'd-------s'], 'αὐτὸς': ['p-s---mn-', 'a-s---mn_', 'a-s---mn-'], 'ἰδίᾳ': ['a-s---fd-', 'd--------'], 'ὃν': ['a-s---ma_', 'p-s---ma-', 'a-s---ma-', 'p-s---na-', 'p-s---nn-'], 'τρόπον': ['n-s---ma-', 'n-s---na-'], 'προϊόντος': ['v-sppamg-', 'v-sppang-'], 'ἐπιδείξω': ['v1sfia---', 'v1sasa---'], 'τοῦ': ['l-s---mg-', 'l-s---ng-', 'p-s---ng-', 'l-s---fg-', 'a-s---ng-', 'p-s---mg-', 'l-p---mg-', 'l-p---ng-'], 'λόγου': ['n-s---mg-', 'v2spma---'], 'ἕν': ['a-s---na_', 'a-s---nn_', 'n-s---na-', 'a-s---na-', 'n-s---nn-', 'a-s---nn-'], 'τι': ['p-s---na-', 'a-s---na_', 'p-s---nn-', 'a-s---nn_', 'a-s---na-', 'a-s---nn-', 'p-s---nv-'], 'μὴ': ['d--------', 'c--------', 'd-------_', 'd-------------'], 'τῇ': ['l-s---fd-', 'l-----fd-', 'l-s---md-', 'l-s----d------', 'l-s---fg-', 'l-s---mg-', 'p-s---fd-', 'd--------', 'l-s---fa-'], 'πόλει': ['n-s---fd-', 'n-s---fn-', 'n-d---fn-'], 'τοῖς': ['l-p---md-', 'l-p---nd-', 'l-p----d------', 'l-p---fd-', 'l-p---mg-'], 'ὑμῖν': ['p-p---md-', 'p2p---md-', 'p2p----d-', 'p2p---fd-', 'p-p----d-', 'p-p----g-'], ':': ['u--------', 'e--------'], 'εἰδὼς': ['v-srpamn-', 'n-p---ma-'], 'δ᾽': ['d--------', 'c--------', 'a-_---___', 'd-------------'], 'αὐτὸν': ['p-s---ma-', 'a-s---ma_', 'a-s---ma-', 'p-s---na-'], 'ὄντα': ['v-sppama-', 'v-pppana-', 'v-pppann-', 'n-p---nn-', 'n-p---na-'], 'οἷς': ['p-p---nd-', 'p-p---md-', 'a-p---md_', 'a-p---nd_', 'a-p---md-'], 'ὀλίγῳ': ['a-s---nd-', 'a-s---md-'], 'πρότερον': ['a-s---na-', 'a-s---ma-', 'd-------c', 'a-s---nn-'], 'αὐτῷ': ['p-s---md-', 'a-s---md_', 'a-s---nd_', 'p-s---nd-', 'a-s---md-', 'a-s---nd-', 'p-s----d-'], 'τὴν': ['l-s---fa-', 'p-s---fa-'], '.': ['u--------', 'e--------'], 'ἔοικεν': ['v3sria---', 'v3plia---'], 'οἱ': ['l-p---mn-', 'p-s---md-', 'p-s---fd-', 'l-s---md-', 'l-s---mn-', 'l-p---mg-', 'l-p---mv-'], 'δημοσίοις': ['a-p---md-', 'a-p---nd-'], 'οὐκ': ['d--------', 'c--------', 'd-------------'], 'ψευδεῖς': ['a-p---mn-', 'a-p---ma-', 'a-p---fn-', 'a-p---fa-'], 'γὰρ': ['d--------', 'd-------------'], 'πολλὰ': ['a-p---na-', 'a-p---nn-', 'a-p---fa-', 'a-d---fn-', 'a-d---fa-', 'a-s---fn-'], 'κοινῶν': ['a-p---ng-', 'a-p---fg-', 'a-p---mg-'], 'μὲν': ['d--------', 'd-------------', 'c--------'], 'ὅλου': ['a-s---mg-', 'a-s---ng-'], 'φανήσεται': ['v3sfip---', 'v3sfim---', 'v3sasm---'], '-θ᾽': ['d--------', 'c--------'], 'ἡ': ['l-s---fn-', 'l-s---fv-'], 'πόλις': ['n-p---fa-', 'n-s---fn-'], 'αἰτία': ['a-s---fn-', 'n-s---fn-'], 'οὖσα': ['v-sppafn-', 'v-sppmfn-', 'v-spgafn-'], 'ὑμεῖς': ['p-p---mn-', 'p2p----n-', 'p-p---fn-', 'p2p---mn-'], 'ἐγώ': ['p1s---mn-', 'p-s----n-', 'p1s---fn-'], 'οὗ ...
#
# DataFrame delle forme con più di un lemma:
#                form                     lemmas
# 0               τῶν                    [ὁ, ὅς]
# 1                 ,           [punc1, ,, ἒ, ·]
# 2                 ὦ                  [ὦ, εἰμί]
# 3                οὔ        [οὐ, οὔτε, οὐκ, οὔ]
# 4               -τε            [τε, -τε, οὔτε]
# ...             ...                        ...
# 2558  διαψηφίζεσθαι  [διαψηφίζω, διαψηφίζομαι]
# 2559         διῆκεν            [διήκω, διίημι]
# 2560       Αἰολίδος          [Αἰολίς, Αἰολεύς]
# 2561        Μειδίας         [Μειδίης, Μειδίας]
# 2562     ἐτρέφθησαν             [τρέφω, τρέπω]
#
# [2563 rows x 2 columns]
#
# DataFrame delle forme con più di un postag:
#             form                                            postags
# 0         οὐδένα  [p-s---ma-, a-s---ma_, a-s---ma-, p-p---na-, p...
# 1            τῶν  [l-p---mg-, l-p---ng-, l-p---fg-, p-p---ng-, p...
# 2              ,                             [u--------, e--------]
# 3              ὦ                             [i--------, v1spsa---]
# 4         ἄνδρες                             [n-p---mv-, n-p---mn-]
# ...          ...                                                ...
# 5940  παμπλήθεις                             [a-p---mn-, a-p---fa-]
# 5941     Κινάδων                             [n-s---mn-, n-s---mv-]
# 5942   δεκαρχίας                             [n-p---fa-, n-s---fg-]
# 5943  διαβατήρια                             [n-p---na-, n-p---nn-]
# 5944      ἤρχετε                             [v2piia---, v2prma---]
#
# [5945 rows x 2 columns]

# %%
lemma_pos_dic_gorman.to_csv("lemmas_postags_relation_senza_correzioni.csv", index=False, encoding='utf-8')

# %%
#forse avrei dovuto usare output_gorman_con_relation, qui ho usato i no anomalies dai quali avevo già corretto alcune anomalie di postag!!!!!

# %%
def create_dictonary_of_lemmas(dataframes_unificati):
    df_per_lemma = pd.concat(dataframes_unificati).reset_index(drop=True)
    lemma_dict = {}
    
    # Get unique forms from both DataFrames
    forms = list(dict.fromkeys(list(df_per_lemma['@form'])))
    forms = [s for s in forms if pd.notna(s)]
    for form in forms:
        lemmas_df = (list(df_per_lemma[df_per_lemma['@form'] == form].iloc[0].dropna())[1:])


        # Extract unique @postag values for the form from df1
        #postags = df_per_lemma.loc[df_per_lemma['@form'] == form, '@postag'].dropna().unique().tolist()

        # Add to the dictionary
        lemma_dict[form] = {
                'lemmas': lemmas_df
            }
       
    return lemma_dict    
def merge_dic(dic_chat,dic_chat_2):
    merged = {}

    for form in set(dic_chat.keys()).union(dic_chat_2.keys()):
        lemmas = []
        # Aggiungiamo i lemmi dal primo dizionario, se esistono
        if form in dic_chat:
            lemmas.extend(dic_chat[form]['lemmas'])
        # Aggiungiamo i lemmi dal secondo dizionario, se esistono
        if form in dic_chat_2:
            lemmas.extend(dic_chat_2[form]['lemmas'])
        # Rimuoviamo i duplicati preservando l'ordine
        unique_lemmas = []
        seen = set()
        for lemma in lemmas:
            if lemma not in seen:
                unique_lemmas.append(lemma)
                seen.add(lemma)
        merged[form] = {'lemmas': unique_lemmas}
    return merged    



# Funzione per popolare le colonne per ogni riga del DataFrame
def popola_riga(row,dict_forms):
    form = row['form']
    if form in dict_forms:
        lemmas = dict_forms[form].get('lemmas', [])
        #postags = dict_forms[form].get('postags', [])
        # Assegniamo i valori dei lemmas nelle colonne corrispondenti
        for idx, lemma in enumerate(lemmas):
            row[f'lemma_chat_{idx+1}'] = lemma

        # Assegniamo i valori dei postags nelle colonne corrispondenti
        #for idx, postag in enumerate(postags):
        #    row[f'postag_pedalion_{idx+1}'] = postag
    return row

def add_chat_lemmas(df, lemma_dict):
    #df = pd.concat(dataframes_unificati).reset_index(drop=True)[['@id','@form','@lemma','@postag','@relation']]      

    # Dizionario di esempio
    dict_forms = lemma_dict

    # Determiniamo il numero massimo di elementi nelle liste "lemmas" e "postags"
    max_lemmas = max(len(info.get('lemmas', [])) for info in dict_forms.values())
    #max_postags = max(len(info.get('postags', [])) for info in dict_forms.values())

    # Aggiungiamo le colonne per i lemmas
    for i in range(1, max_lemmas + 1):
        df[f'lemma_chat_{i}'] = ''

    # Aggiungiamo le colonne per i postags
    #for i in range(1, max_postags + 1):
    #    df[f'postag_pedalion_{i}'] = ''
    df = df.apply(popola_riga, axis=1, args=(dict_forms,))

    return df

# %%
#mettere la dir dove sono i file chatgpt
lis_chat = os.listdir('lemmatizzazioni gorman con chatgpt')
final_dic = {}
for chat in lis_chat:
     df = pd.read_csv(file_path, on_bad_lines='skip', quoting=3)
     df.columns = df.columns.str.replace(r'^"(.*)"$', r'\1', regex=True)
     df=df.replace(r'^"(.*)"$', r'\1', regex=True)
     dic = create_dictonary_of_lemmas([df])
     final_dic = merge_dic(dic,final_dic)

# %%
lemma_pos_dic_gorman = pd.read_csv('lemmas_postags_relation_senza_correzioni.csv')
df = add_chat_lemmas(lemma_pos_dic_gorman,final_dic)

df.to_csv('lemmatizzazioni_postags_con_relation_gpt_gorman.csv')
# Out:
# C:\Users\lcolo\AppData\Local\Temp\ipykernel_2456\1388200419.py:1: DtypeWarning: Columns (4,5,6,10,11,12,13,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   lemma_pos_dic_gorman = pd.read_csv('lemmas_postags_relation_senza_correzioni.csv')

# %%
import pandas as pd

final_dic = {}
folder_path = 'lemmatizzazioni gorman con chatgpt/' # Percorso della cartella

for chat in lis_chat:
    file_path = folder_path + chat  # Costruisce il percorso completo del file
    print(f"Tentativo di lettura del file: {file_path}")  # Stampa il file in elaborazione

    try:
        df = pd.read_csv(file_path, on_bad_lines='skip', quoting=3)
        df.columns = df.columns.str.replace(r'^"(.*)"$', r'\1', regex=True)
        df=df.replace(r'^"(.*)"$', r'\1', regex=True)
        dic = create_dictonary_of_lemmas([df])
        final_dic = merge_dic(dic, final_dic)
    except pd.errors.ParserError as e:
        print(f"Errore nel file {file_path}: {e}")
# Out:
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_aeschines-1-1-50-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_aeschines-1-101-150-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_aeschines-1-151-196-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_aeschines-1-51-100-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_antiphon-1-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_antiphon-2-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_antiphon-5-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_antiphon-6-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_appian-bc-1-0-1-4-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_appian-bc-1-11-14-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_appian-bc-1-5-7-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_appian-bc-1-8-10-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_aristotle-politics-book-1-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_aristotle-politics-book-2-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-1-9-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-10-19-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-20-29-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-30-39-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-40-49-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-50-59-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-60-69-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen12-70-81-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-1-9-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-10-19-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-20-29-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-30-39-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-40-49-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-50-59-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-60-69-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-70-79-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-80-89-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_athen13-90-95-jan-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dem-59-neaira-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-1-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-18-1-50-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-18-101-150-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-18-151-200-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-18-201-275-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-18-276-324-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-18-51-100-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-4-phil1-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-46-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-47-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-49-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-50-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-52-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_demosthenes-53-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_diodsic-11-1-20-bu4.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_diodsic-11-81-92-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_diodsic11-21-40-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_diodsic11-41-60-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_diodsic11-61-80-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dion-hal-1-1-15-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dion-hal-1-16-30-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dion-hal-1-31-45-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dion-hal-1-46-60-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dion-hal-1-61-75-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_dion-hal-1-76-90-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-1-19-bu3-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-100-119-bu3-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-120-149-bu2-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-150-169-bu3-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-170-189-bu2-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-190-216-bu2-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-20-39-bu2-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-40-59-bu2-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-60-79-bu2-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_hdt-1-80-99-bu5-2019.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_josephus-bj-1-1-2-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_josephus-bj-1-11-15-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_josephus-bj-1-16-20-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_josephus-bj-1-21-25-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_josephus-bj-1-3-5-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_josephus-bj-1-6-10-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-1-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-12-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-13-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-14-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-15.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-19-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_lysias-23-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plato-apology.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plut-alcib-1-17-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plut-alcib-18-39-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plut-fortuna-romanorum-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plutarch-alex-fort-aut-virt-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plutarch-lycurgus-1-15-bu4.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_plutarch-lycurgus-16-31-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-10-1-10-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-10-11-20-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-10-21-35-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-10-36-49-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-1-10-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-11-20-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-21-30-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-31-40-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-41-50-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-51-60-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-2-61-71-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-21-1-10-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-21-11-20-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-21-21-30-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-21-31-47-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-6-16-30-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-6-2-15-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-6-31-45-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-6-46-58-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-9-1-20-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-9-21-33-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius-9-34-45-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-1-9-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-10-19-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-20-29-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-30-39-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-40-49-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-50-59-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_polybius1-60-69-2017.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-cyr-7-1-3-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-cyr-7-4-5-tree.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-cyr-8-1-8-4-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-cyr-8-5-7-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-cyr-8-8-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-hell-1-1-4-bu2.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-hell-1-5-7-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-hell-2-bu1.csv
# Tentativo di lettura del file: lemmatizzazioni gorman con chatgpt/lemma_chat_xen-hell-3-bu1.csv

# %% [markdown]
# QUI INVECE STO CARICANDO E PULENDO I LEMMI DI CHATGPT:

# %%
def create_merged_dataframe_with_postags(df1, df2):
    """
    Merges two DataFrames into a structured DataFrame containing:
    - '@form': The form (key).
    - Lemmas from df1 ('gorman_lemma_X').
    - Lemmas from df2 ('gpt_lemma_X').
    - Postags from df1 ('postag_X').

    Args:
    df1 (pd.DataFrame): The first DataFrame containing '@form', '@lemma', and '@postag'.
    df2 (pd.DataFrame): The second DataFrame containing '@form' and '@lemmaPerseus1', '@lemmaPerseus2', '@lemmaPerseus3'.

    Returns:
    pd.DataFrame: The merged DataFrame.
    """
    # Initialize the dictionary
    lemma_dict = {}

    # Get unique forms from both DataFrames
    forms = list(dict.fromkeys(list(df1['@form']) +  list(df2['@form'])))

    for form in forms:
        # Extract lemmas from df1
        lemmas_df1 = df1.loc[df1['@form'] == form, '@lemma'].dropna().unique().tolist()

        # Extract lemmas from df2
        lemmas_df2 = (
            df2.loc[
                df2['@form'] == form, ['@lemmaPerseus1', '@lemmaPerseus2']
            ]
            .stack()
            .dropna()
            .unique()
            .tolist()
        )

        # Extract unique @postag values for the form from df1
        postags = df1.loc[df1['@form'] == form, '@postag'].dropna().unique().tolist()

        # Add to the dictionary
        lemma_dict[form] = {
            'lemmas_df1': lemmas_df1,
            'lemmas_df2': lemmas_df2,
            'postags': postags
        }

    # Determine the maximum lengths
    max_len_df1 = max(len(lemmas['lemmas_df1']) for lemmas in lemma_dict.values())
    max_len_df2 = max(len(lemmas['lemmas_df2']) for lemmas in lemma_dict.values())
    max_len_postags = max(len(lemmas['postags']) for lemmas in lemma_dict.values())

    # Create the columns for the DataFrame
    columns = (
        ['@form'] +
        [f'gorman_lemma_{i+1}' for i in range(max_len_df1)] +
        [f'gpt_lemma_{i+1}' for i in range(max_len_df2)] +
        [f'postag_{i+1}' for i in range(max_len_postags)]
    )

    # Build the DataFrame rows
    data = []
    for form, lemmas in lemma_dict.items():
        row = {'@form': form}
        # Add lemmas from df1 (gorman), filling with empty strings if necessary
        for i in range(max_len_df1):
            row[f'gorman_lemma_{i+1}'] = lemmas['lemmas_df1'][i] if i < len(lemmas['lemmas_df1']) else ''
        # Add lemmas from df2 (gpt), filling with empty strings if necessary
        for i in range(max_len_df2):
            row[f'gpt_lemma_{i+1}'] = lemmas['lemmas_df2'][i] if i < len(lemmas['lemmas_df2']) else ''
        # Add postags from df1, filling with empty strings if necessary
        for i in range(max_len_postags):
            row[f'postag_{i+1}'] = lemmas['postags'][i] if i < len(lemmas['postags']) else ''
        data.append(row)

    # Create the DataFrame
    merged_df = pd.DataFrame(data, columns=columns)

    return merged_df

# %%
import pickle

# %%
with open('lemma_dic_pedialion.pkl', 'rb') as file:         #sto importando il dizionario dei lemmi di pedalion
    lemma_dic_pedialion = pickle.load(file)

# %%
# Funzione per popolare le colonne per ogni riga del DataFrame -> data una riga, se trova una form corrispondente nel dizionario di pedalion mi popola i lemmi
def popola_riga(row,dict_forms):
    form = row['@form']
    if form in dict_forms:
        lemmas = dict_forms[form].get('lemmas', [])
        #postags = dict_forms[form].get('postags', [])
        # Assegniamo i valori dei lemmas nelle colonne corrispondenti
        for idx, lemma in enumerate(lemmas):
            row[f'lemma_pedalion_{idx+1}'] = lemma

        # Assegniamo i valori dei postags nelle colonne corrispondenti
        #for idx, postag in enumerate(postags):
        #    row[f'postag_pedalion_{idx+1}'] = postag
    return row

def add_pedalion_lemmas(df, lemma_dict):      #prende in input dataframe unificati qui di gorman con gpt a cui si vuole concatenare pedalion. 
    #df = pd.concat(dataframes_unificati).reset_index(drop=True)[['@id','@form','@lemma','@postag','@relation']]      

    # Dizionario di esempio
    dict_forms = lemma_dict

    # Determiniamo il numero massimo di elementi nelle liste "lemmas" e "postags"
    max_lemmas = max(len(info.get('lemmas', [])) for info in dict_forms.values())           #vede quale form ha più lemmi e quella è la lunghezza massima per aggiungere tot lemma pedalion1, lemma pedalion 2 etc.
    #max_postags = max(len(info.get('postags', [])) for info in dict_forms.values())

    # Aggiungiamo le colonne per i lemmas           
    for i in range(1, max_lemmas + 1):
        df[f'lemma_pedalion_{i}'] = ''

    # Aggiungiamo le colonne per i postags
    #for i in range(1, max_postags + 1):
    #    df[f'postag_pedalion_{i}'] = ''
    df = df.apply(popola_riga, axis=1, args=(dict_forms,))                      #sto popolando le righe del dataframe per ogni form vado a cercare se la form esiste nel dizionario, se esiste prenso i lemmas e li metto in lemma pedalion 1, lemma pedalion 2...

    return df

# %%
import pandas as pd
import os

# Esempio di file unico:
file_unico = 'lemmas_postags_relation_senza_correzioni.csv'

# Carica il dataframe principale
df = pd.read_csv(file_unico)

# Rimuovi eventuali righe con lemmi di punteggiatura
df = df[~df['lemma1'].str.contains('punc', na=False)]
df.reset_index(drop=True, inplace=True)

# Carica il dataframe dei lemmi di ChatGPT 
# (assicurati che il nome corrisponda a quello che vuoi effettivamente usare)
lemma_chat = pd.read_csv('lemmatizzazioni gorman con chatgpt/lemma_chat_'+list_dir[i][:-4]+'.csv',on_bad_lines='skip')
lemma_chat.dropna(how='all', inplace=True)
lemma_chat.reset_index(drop=True, inplace=True)

# Seleziona le colonne di interesse dal primo dataframe
df1 = df[['form','lemma1','postag1']].rename(columns={
    'form': '@form',
    'lemma1': '@lemma',
    'postag1': '@postag'
})

# Esegui il merge con la tua funzione personalizzata
merged_df = create_merged_dataframe_with_postags(df1, lemma_chat)

# Se devi aggiungere lemmi da Pedalion, qui usi la tua funzione
# NOTA: se 'df_filtrato' era il dataframe di partenza, 
#       potresti voler passare 'merged_df' invece di 'df_filtrato'
merged_df = add_pedalion_lemmas(merged_df, lemma_dic_pedialion)

# Salva il risultato finale in CSV
nome_output = os.path.splitext(os.path.basename(file_unico))[0] + '_senza_ripetizioni.csv'
merged_df.to_csv('tabelle_confronto_lemmi_gpt_gorman_relation/' + nome_output, index=False)
# Out:
# C:\Users\lcolo\AppData\Local\Temp\ipykernel_18944\1274708932.py:8: DtypeWarning: Columns (4,5,6,10,11,12,13,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_unico)

# %%
#DIZIONARIO GORMAN-GPT-PEDALION:

# %%
lis_dir = os.listdir('correzione lemmi')

# %%
lis_dir = os.listdir('correzione lemmi')
df_lis = [pd.read_csv('correzione lemmi/'+i) for i in lis_dir]

# %%
def create_dic(df):
    # Define the columns (adjust as needed)
    lemma_cols = [
            'gorman_lemma_1',
    'gorman_lemma_2',
    'gorman_lemma_3',
    'gorman_lemma_4',
    'gorman_lemma_5',
    'gorman_lemma_6',
    'gorman_lemma_7',
    'gorman_lemma_8',
    'gorman_lemma_9',
    'gorman_lemma_10',
    'gorman_lemma_11',
    'gorman_lemma_12',
    'gorman_lemma_13',
    'gorman_lemma_14',
    'gpt_lemma_1',
    'gpt_lemma_2',
    'gpt_lemma_3',
    'gpt_lemma_4',
    'gpt_lemma_5',
    'gpt_lemma_6',
    'gpt_lemma_7',
    'gpt_lemma_8',
    'gpt_lemma_9',
    'gpt_lemma_10',
    'gpt_lemma_11',
    'gpt_lemma_12',
    'gpt_lemma_13',
    'gpt_lemma_14',
            'lemma_pedalion_1', 'lemma_pedalion_2', 'lemma_pedalion_3',
            'lemma_pedalion_4', 'lemma_pedalion_5', 'lemma_pedalion_6',
            'lemma_pedalion_7', 'lemma_pedalion_8', 'lemma_pedalion_9',
            'lemma_pedalion_10', 'lemma_pedalion_11', 'lemma_pedalion_12',
            'lemma_pedalion_13', 'lemma_pedalion_14', 'lemma_pedalion_15',
            'lemma_pedalion_16', 'lemma_pedalion_17'
        ]
    postag_cols = ['postag_1',
    'postag_2',
    'postag_3',
    'postag_4',
    'postag_5',
    'postag_6',
    'postag_7',
    'postag_8',
    'postag_9',
    'postag_10',
    'postag_11',
    'postag_12',
    'postag_13',
    'postag_14',
    'postag_15',
    'postag_16',
    'postag_17',
    'postag_18',
    'postag_19']

    # Dictionary to store consolidated data per @form
    form_dict = {}
    for _, row in df.iterrows():
        form = row['@form']
        if form not in form_dict:
            form_dict[form] = {"lemmas": set(), "postags": set()}
        # Gather lemma values (avoiding missing values)
        for col in lemma_cols:
            if col in df.columns:
                value = row[col]
                if pd.notnull(value):
                    form_dict[form]["lemmas"].add(value)
        # Gather postag values similarly
        for col in postag_cols:
            if col in df.columns:
                value = row[col]
                if pd.notnull(value):
                    form_dict[form]["postags"].add(value)
    return form_dict

def merge_list_of_dicts(dict_list):
    merged = {}
    for d in dict_list:
        for form, values in d.items():
            if form in merged:
                merged[form]['lemmas'].update(values['lemmas'])
                merged[form]['postags'].update(values['postags'])
            else:
                merged[form] = {
                    'lemmas': set(values['lemmas']),
                    'postags': set(values['postags'])
                }
    return merged

lis_dir = os.listdir('correzione lemmi')
lis = [pd.read_csv('correzione lemmi/'+i) for i in lis_dir]
      
dic_lis = []
for df in lis:
    dic = create_dic(df)
    dic_lis.append(dic)
merged_dic = merge_list_of_dicts(dic_lis)  
def create_dic_exclusion(df,dict):
    # Define the columns (adjust as needed)
    lemma_cols = [
        'gorman_lemma_1',
 'gorman_lemma_2',
 'gorman_lemma_3',
 'gorman_lemma_4',
 'gorman_lemma_5',
 'gorman_lemma_6',
 'gorman_lemma_7',
 'gorman_lemma_8',
 'gorman_lemma_9',
 'gorman_lemma_10',
 'gorman_lemma_11',
 'gorman_lemma_12',
 'gorman_lemma_13',
 'gorman_lemma_14',
'gpt_lemma_1',
 'gpt_lemma_2',
 'gpt_lemma_3',
 'gpt_lemma_4',
 'gpt_lemma_5',
 'gpt_lemma_6',
 'gpt_lemma_7',
 'gpt_lemma_8',
 'gpt_lemma_9',
 'gpt_lemma_10',
 'gpt_lemma_11',
 'gpt_lemma_12',
 'gpt_lemma_13',
 'gpt_lemma_14',
        'lemma_pedalion_1', 'lemma_pedalion_2', 'lemma_pedalion_3',
        'lemma_pedalion_4', 'lemma_pedalion_5', 'lemma_pedalion_6',
        'lemma_pedalion_7', 'lemma_pedalion_8', 'lemma_pedalion_9',
        'lemma_pedalion_10', 'lemma_pedalion_11', 'lemma_pedalion_12',
        'lemma_pedalion_13', 'lemma_pedalion_14', 'lemma_pedalion_15',
        'lemma_pedalion_16', 'lemma_pedalion_17'
    ]
    postag_cols = ['postag_1',
 'postag_2',
 'postag_3',
 'postag_4',
 'postag_5',
 'postag_6',
 'postag_7',
 'postag_8',
 'postag_9',
 'postag_10',
 'postag_11',
 'postag_12',
 'postag_13',
 'postag_14',
 'postag_15',
 'postag_16',
 'postag_17',
 'postag_18',
 'postag_19']

    # Dictionary to store consolidated data per @form
    form_dict = {}
    for _, row in df.iterrows():
        form = row['@form']
        if form not in dict:
            if form not in form_dict:
                form_dict[form] = {"lemmas": set(), "postags": set()}
            # Gather lemma values (avoiding missing values)
            for col in lemma_cols:
                if col in df.columns:
                    value = row[col]
                    if pd.notnull(value):
                        form_dict[form]["lemmas"].add(value)
            # Gather postag values similarly
            for col in postag_cols:
                if col in df.columns:
                    value = row[col]
                    if pd.notnull(value):
                        form_dict[form]["postags"].add(value)
    return form_dict
lis_dir = os.listdir('tabelle_confronto_lemmi_gpt_gorman_relation')
lis = [pd.read_csv('tabelle_confronto_lemmi_gpt_gorman_relation/'+i) for i in lis_dir]
      

dic_lis = []
for df in lis:
    dic = create_dic_exclusion(df,merged_dic)
    dic_lis.append(dic)
#aggiungo alla lista il dizionazio pulito
dic_lis.append(merged_dic)  
#creao un unico dizionario pulito finale
final_dict = merge_list_of_dicts(dic_lis)
#Visualizzazione
# Optionally, convert sets to sorted lists for easier viewing
for form, values in final_dict.items():
    values['lemmas'] = sorted(list(values['lemmas']))
    values['postags'] = sorted(list(values['postags']))

# Now, merged_dic is a unique dictionary with no repetitions.
# To convert this merged dictionary to a DataFrame:
df_to_see = pd.DataFrame([
    {'@form': form, 'lemmas': values['lemmas'], 'postags': values['postags']}
    for form, values in final_dict.items()
])


lemmas_expanded = pd.DataFrame(df_to_see ['lemmas'].tolist(), index=df_to_see.index)
lemmas_expanded.columns = [f'lemma_{i+1}' for i in range(lemmas_expanded.shape[1])]

# For the 'postags' column
postags_expanded = pd.DataFrame(df_to_see ['postags'].tolist(), index=df_to_see.index)
postags_expanded.columns = [f'postag_{i+1}' for i in range(postags_expanded.shape[1])]

# Step 3: Concatenate the @form column with the new expanded columns
final_df = pd.concat([df_to_see [['@form']], lemmas_expanded, postags_expanded], axis=1)
# Out:
# C:\Users\lcolo\AppData\Local\Temp\ipykernel_18944\3069676472.py:180: DtypeWarning: Columns (4,5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   lis = [pd.read_csv('tabelle_confronto_lemmi_gpt_gorman_relation/'+i) for i in lis_dir]

# %%
final_df
# Out:
#              @form     lemma_1 lemma_2 lemma_3 lemma_4 lemma_5   postag_1  \
# 0           οὐδένα      οὐδείς    None    None    None    None  p-s---ma-
# 1           πώποτε      πώποτε    None    None    None    None  d--------
# 2          πολιτῶν     πολίτης    None    None    None    None  n-p---mg-
# 3                ὦ        εἰμί       ὦ    None    None    None  i--------
# 4           ἄνδρες        ἀνήρ    None    None    None    None  n-p---mv-
# ...            ...         ...     ...     ...     ...     ...        ...
# 69476  εἰσηγεῖσθαι  εἰσηγέομαι    None    None    None    None       None
# 69477        εἴ-τ᾽        εἴτε    None    None    None    None       None
# 69478       ῥᾴδίως      ῥᾴδιος    None    None    None    None       None
# 69479          ὧδὶ         ὧδὶ    None    None    None    None       None
# 69480      ξενικός     ξενικός    None    None    None    None       None
#
#       postag_2 postag_3 postag_4 postag_5 postag_6 postag_7 postag_8
# 0         None     None     None     None     None     None     None
# 1         None     None     None     None     None     None     None
# 2         None     None     None     None     None     None     None
# 3         None     None     None     None     None     None     None
# 4         None     None     None     None     None     None     None
# ...        ...      ...      ...      ...      ...      ...      ...
# 69476     None     None     None     None     None     None     None
# 69477     None     None     None     None     None     None     None
# 69478     None     None     None     None     None     None     None
# 69479     None     None     None     None     None     None     None
# 69480     None     None     None     None     None     None     None
#
# [69481 rows x 14 columns]

# %%
final_df.to_csv('dizionario_gpt_gorman_pedalion_relation.csv')
