# %%
import os
import pandas as pd
import re

# %%
def dataframes_to_horizontal_text(dataframes, output_path):
    """
    Converts a list of DataFrames with columns @id, @form, @lemma, and @postag to a horizontal 
    text format where each sentence is a separate line, and tokens are separated by spaces. 
    Unicode NO-BREAK SPACE (U+00A0) is replaced by a regular space.

    Parameters:
        dataframes (list of pd.DataFrame): List of DataFrames containing the data.
        output_path (str): Path to save the resulting text file.

    Returns:
        None
    """
    horizontal_output = []
    
    for df in dataframes:
        # Join tokens (@form column) with spaces, replacing NO-BREAK SPACE (U+00A0) with a regular space
        sentence_text = " ".join(token.replace("\u00A0", " ") for token in df["@form"])
        horizontal_output.append(sentence_text)

    # Save to file
    with open(output_path, "w", encoding="utf-8") as f:
        f.write("\n".join(horizontal_output))

# %%
def extract_number(file_path):
    # Use regex to find the numeric part of the filename
    return int(re.search(r'(\d+)\.csv$', file_path).group(1))

# %%
#salvo tutte le directory delle opere
lis_dir = sorted(os.listdir('output_gorman_con_relation')) #inserire la directory giusta

# %%
#Preparazione dei file in txt. Da runnare una sola volta

for opera in lis_dir:
    opera_dir = 'output_gorman_con_relation/'+ opera
    all_sorted_csv_filepaths = []
    opera_dir_list = os.listdir(opera_dir) #contiene i file csv di ogni opera i.e. ['0.csv','1.csv']
    #opera_dir.remove('.DS_Store')
    opera_dir_list = sorted(opera_dir_list, key=extract_number) 
    dataframes = [pd.read_csv(opera_dir + '/' + dir, sep=';') for dir in opera_dir_list] #faccio una lista di dataframes (di frasi): Utile per Horizontal
    #all_opera da sistemare in modo da salvare tutte le opere in una lista di dfs
    all_opera = pd.concat(dataframes,ignore_index=True) #concateno tutte le frasi: unico df con frasi di opera (utile per conllu)
    #creo il file orizzontale e lo salvo
    dataframes_to_horizontal_text(dataframes, 'Input Horizontal Treetagger/horizontal_' + opera[:-4]+ '.txt')

# %%
risultati_treetagger_sporchi = os.listdir('risultati_treetagger_sporchi')

# %%
risultati_treetagger_sporchi
# Out:
# ['horizontal_aeschines-1-1-50-bu1.txt',
#  'horizontal_aeschines-1-101-150-bu1.txt',
#  'horizontal_aeschines-1-151-196-bu1.txt',
#  'horizontal_aeschines-1-51-100-bu1.txt',
#  'horizontal_antiphon-1-bu2.txt',
#  'horizontal_antiphon-2-bu2.txt',
#  'horizontal_antiphon-5-bu2.txt',
#  'horizontal_antiphon-6-bu2.txt',
#  'horizontal_appian-bc-1-0-1-4-bu1.txt',
#  'horizontal_appian-bc-1-11-14-bu1.txt',
#  'horizontal_appian-bc-1-5-7-bu1.txt',
#  'horizontal_appian-bc-1-8-10-bu1.txt',
#  'horizontal_aristotle-politics-book-1-bu1.txt',
#  'horizontal_aristotle-politics-book-2-bu2.txt',
#  'horizontal_athen12-1-9-2019.txt',
#  'horizontal_athen12-10-19-2019.txt',
#  'horizontal_athen12-20-29-2019.txt',
#  'horizontal_athen12-30-39-jan-15.txt',
#  'horizontal_athen12-40-49-jan-15.txt',
#  'horizontal_athen12-50-59-jan-15.txt',
#  'horizontal_athen12-60-69-jan-15.txt',
#  'horizontal_athen12-70-81-jan-15.txt',
#  'horizontal_athen13-1-9-jan-15.txt',
#  'horizontal_athen13-10-19-jan-15.txt',
#  'horizontal_athen13-20-29-jan-15.txt',
#  'horizontal_athen13-30-39-jan-15.txt',
#  'horizontal_athen13-40-49-jan-15.txt',
#  'horizontal_athen13-50-59-jan-15.txt',
#  'horizontal_athen13-60-69-jan-15.txt',
#  'horizontal_athen13-70-79-jan-15.txt',
#  'horizontal_athen13-80-89-jan-15.txt',
#  'horizontal_athen13-90-95-jan-15.txt',
#  'horizontal_dem-59-neaira-2019.txt',
#  'horizontal_demosthenes-1-bu1.txt',
#  'horizontal_demosthenes-18-1-50-bu2.txt',
#  'horizontal_demosthenes-18-101-150-bu2.txt',
#  'horizontal_demosthenes-18-151-200-bu2.txt',
#  'horizontal_demosthenes-18-201-275-bu1.txt',
#  'horizontal_demosthenes-18-276-324-bu1.txt',
#  'horizontal_demosthenes-18-51-100-bu1.txt',
#  'horizontal_demosthenes-4-phil1-bu1.txt',
#  'horizontal_demosthenes-46-tree.txt',
#  'horizontal_demosthenes-47-tree.txt',
#  'horizontal_demosthenes-49-tree.txt',
#  'horizontal_demosthenes-50-tree.txt',
#  'horizontal_demosthenes-52-tree.txt',
#  'horizontal_demosthenes-53-tree.txt',
#  'horizontal_diodsic-11-1-20-bu4.txt',
#  'horizontal_diodsic-11-81-92-bu1.txt',
#  'horizontal_diodsic11-21-40-bu2.txt',
#  'horizontal_diodsic11-41-60-bu1.txt',
#  'horizontal_diodsic11-61-80-bu1.txt',
#  'horizontal_dion-hal-1-1-15-bu2.txt',
#  'horizontal_dion-hal-1-16-30-bu1.txt',
#  'horizontal_dion-hal-1-31-45-bu1.txt',
#  'horizontal_dion-hal-1-46-60-bu1.txt',
#  'horizontal_dion-hal-1-61-75-bu1.txt',
#  'horizontal_dion-hal-1-76-90-bu1.txt',
#  'horizontal_hdt-1-1-19-bu3-2019.txt',
#  'horizontal_hdt-1-100-119-bu3-2019.txt',
#  'horizontal_hdt-1-120-149-bu2-2019.txt',
#  'horizontal_hdt-1-150-169-bu3-2019.txt',
#  'horizontal_hdt-1-170-189-bu2-2019.txt',
#  'horizontal_hdt-1-190-216-bu2-2019.txt',
#  'horizontal_hdt-1-20-39-bu2-2019.txt',
#  'horizontal_hdt-1-40-59-bu2-2019.txt',
#  'horizontal_hdt-1-60-79-bu2-2019.txt',
#  'horizontal_hdt-1-80-99-bu5-2019.txt',
#  'horizontal_josephus-bj-1-1-2-bu1.txt',
#  'horizontal_josephus-bj-1-11-15-bu1.txt',
#  'horizontal_josephus-bj-1-16-20-bu1.txt',
#  'horizontal_josephus-bj-1-21-25-bu1.txt',
#  'horizontal_josephus-bj-1-3-5-bu2.txt',
#  'horizontal_josephus-bj-1-6-10-bu1.txt',
#  'horizontal_lysias-1-bu1.txt',
#  'horizontal_lysias-12-bu1.txt',
#  'horizontal_lysias-13-bu1.txt',
#  'horizontal_lysias-14-bu1.txt',
#  'horizontal_lysias-15.txt',
#  'horizontal_lysias-19-bu1.txt',
#  'horizontal_lysias-23-bu1.txt',
#  'horizontal_plato-apology.txt',
#  'horizontal_plut-alcib-1-17-bu1.txt',
#  'horizontal_plut-alcib-18-39-bu1.txt',
#  'horizontal_plut-fortuna-romanorum-bu1.txt',
#  'horizontal_plutarch-alex-fort-aut-virt-bu2.txt',
#  'horizontal_plutarch-lycurgus-1-15-bu4.txt',
#  'horizontal_plutarch-lycurgus-16-31-bu2.txt',
#  'horizontal_polybius-10-1-10-bu1.txt',
#  'horizontal_polybius-10-11-20-bu1.txt',
#  'horizontal_polybius-10-21-35-bu2.txt',
#  'horizontal_polybius-10-36-49-bu1.txt',
#  'horizontal_polybius-2-1-10-bu1.txt',
#  'horizontal_polybius-2-11-20-bu1.txt',
#  'horizontal_polybius-2-21-30-bu2.txt',
#  'horizontal_polybius-2-31-40-bu2.txt',
#  'horizontal_polybius-2-41-50-bu1.txt',
#  'horizontal_polybius-2-51-60-bu1.txt',
#  'horizontal_polybius-2-61-71-bu2.txt',
#  'horizontal_polybius-21-1-10-bu1.txt',
#  'horizontal_polybius-21-11-20-bu1.txt',
#  'horizontal_polybius-21-21-30-bu1.txt',
#  'horizontal_polybius-21-31-47-bu1.txt',
#  'horizontal_polybius-6-16-30-bu1.txt',
#  'horizontal_polybius-6-2-15-bu1.txt',
#  'horizontal_polybius-6-31-45-bu1.txt',
#  'horizontal_polybius-6-46-58-bu1.txt',
#  'horizontal_polybius-9-1-20-bu1.txt',
#  'horizontal_polybius-9-21-33-bu1.txt',
#  'horizontal_polybius-9-34-45-bu1.txt',
#  'horizontal_polybius1-1-9-2017.txt',
#  'horizontal_polybius1-10-19-2017.txt',
#  'horizontal_polybius1-20-29-2017.txt',
#  'horizontal_polybius1-30-39-2017.txt',
#  'horizontal_polybius1-40-49-2017.txt',
#  'horizontal_polybius1-50-59-2017.txt',
#  'horizontal_polybius1-60-69-2017.txt',
#  'horizontal_polybius1-70-79-2017.txt',
#  'horizontal_polybius1-80-88-2017.txt',
#  'horizontal_ps-xen-ath-pol-bu2.txt',
#  'horizontal_thuc-1-1-20-bu5.txt',
#  'horizontal_thuc-1-101-120-bu2.txt',
#  'horizontal_thuc-1-121-146-bu3.txt',
#  'horizontal_thuc-1-21-40-bu4.txt',
#  'horizontal_thuc-1-41-60-bu3.txt',
#  'horizontal_thuc-1-61-80-bu3.txt',
#  'horizontal_thuc-1-81-100-bu2.txt',
#  'horizontal_thuc-3-1-20-bu1.txt',
#  'horizontal_thuc-3-21-40-bu1.txt',
#  'horizontal_xen-cyr-1-1-2-bu1.txt',
#  'horizontal_xen-cyr-1-3-4-bu1.txt',
#  'horizontal_xen-cyr-1-5-bu1.txt',
#  'horizontal_xen-cyr-1-6-bu1.txt',
#  'horizontal_xen-cyr-7-1-3-tree.txt',
#  'horizontal_xen-cyr-7-4-5-tree.txt',
#  'horizontal_xen-cyr-8-1-8-4-bu1.txt',
#  'horizontal_xen-cyr-8-5-7-bu1.txt',
#  'horizontal_xen-cyr-8-8-bu1.txt',
#  'horizontal_xen-hell-1-1-4-bu2.txt',
#  'horizontal_xen-hell-1-5-7-bu1.txt',
#  'horizontal_xen-hell-2-bu1.txt',
#  'horizontal_xen-hell-3-bu1.txt']

# %%
dizionario_risultati_treetagger_agdt = {'noun':'n',
                                        'verb':'v',
                                        'preposition': 'r', 
                                        'adjective': 'a', 
                                        'interjection': 'i', 
                                        'proper': 'n', 
                                        'SENT': 'u',
                                          'article': 'l', 
                                          'adverb': 'd', 
                                          'conjunction': 'c',  
                                          'particle': 'g', 
                                          'pronoun': 'p'}

# %%
import os
import re

directory = "risultati_treetagger_sporchi/"

tag_line_regex = re.compile(r'^<[^>]*>')

for filename in os.listdir(directory):

    file_path = os.path.join(directory, filename)

    try:
        with open(file_path, "r", encoding="utf-8") as f:
            lines = f.readlines()
    except Exception as e:
        print(f"Impossibile leggere il file '{filename}': {e}")
        continue

    kept_lines = []

    for line in lines:
        if tag_line_regex.search(line):
            print(f"File: {filename}\nRiga rimossa: {line}\n")
        else:
            kept_lines.append(line)
    try:
        with open(file_path, "w", encoding="utf-8") as f_out:
            f_out.writelines(kept_lines)
    except Exception as e:
        print(f"Impossibile scrivere sul file '{filename}': {e}")
        continue

# %%
lista_risultati_treetagger = []
for risultato in risultati_treetagger_sporchi:
    cols = ['form', 'pos', 'trattino']
    df = pd.read_csv('risultati_treetagger_sporchi/' + risultato, sep = '\t', header = None, names = cols)
    df['pos'] = df['pos'].replace(dizionario_risultati_treetagger_agdt)
    lista_risultati_treetagger.append(df)

# %%
opera_names = os.listdir('output_gorman_con_relation')
gorman_dfs = []
for opera in opera_names:
    opera_list = [pd.read_csv('output_gorman_con_relation/' + opera + '/' + frase) for frase in sorted(os.listdir('output_gorman_con_relation/' + opera), key=lambda fn: int(fn.split('.')[0]))]
    opera_finale = pd.concat(opera_list)
    
    opera_finale = opera_finale[['@form', '@postag']].copy()
  
    
    opera_finale['@postag'] = opera_finale['@postag'].str.get(0)
    gorman_dfs.append(opera_finale)

# %%
"""
Script per calcolare l'accuracy dei POS tra i risultati di TreeTagger e
quelli dell'edizione Gorman, opera per opera.

Prerequisiti (già prodotti dai tuoi due cicli for):
- tree_dfs: lista di DataFrame (uno per opera) con colonne ['form', 'postag']
           dove 'postag' è stato già normalizzato tramite il dizionario
           (prima lettera del tag, ecc.).
- gorman_dfs: lista di DataFrame (uno per opera) con le stesse colonne e
           lo stesso trattamento sul campo 'postag'.
- opera_names: lista di stringhe con i titoli/identificativi delle opere,
           nello stesso ordine delle due liste di DataFrame.

Il modulo fornisce:
- una funzione `compute_accuracy_per_opera` che restituisce un DataFrame con
  l'accuracy per ogni opera e stampa l'accuracy complessiva.
- una helper `load_dfs` se preferisci caricare i csv da cartelle invece di
  passare direttamente le liste di DataFrame già in memoria.

Usage minimo suggerito:
>>> df_accuracy = compute_accuracy_per_opera(opera_names, tree_dfs, gorman_dfs)
>>> df_accuracy.to_csv('accuracy_per_opera.csv', index=False)
"""

import pandas as pd
from pathlib import Path
from typing import List, Tuple

def load_dfs(dir_path: Path, suffix: str = '.csv') -> Tuple[List[str], List[pd.DataFrame]]:
    """Carica tutti i csv in `dir_path` e restituisce (nomi, DataFrame).
    I file vengono letti in ordine alfabetico per garantire l'allineamento
    con i risultati di TreeTagger.
    """
    file_paths = sorted(dir_path.glob(f'*{suffix}'))
    names = [p.stem for p in file_paths]
    
    return names


def compute_accuracy_per_opera(
    opera_names: List[str],
    tree_dfs: List[pd.DataFrame],
    gorman_dfs: List[pd.DataFrame]
) -> pd.DataFrame:
    """Confronta i POS di TreeTagger e Gorman opera per opera.

    Parameters
    ----------
    opera_names : List[str]
        Titoli o ID delle opere.
    tree_dfs : List[pd.DataFrame]
        DataFrame per TreeTagger (per opera) con colonne ['form', 'postag'].
    gorman_dfs : List[pd.DataFrame]
        DataFrame per Gorman (per opera) con colonne ['form', 'postag'].

    Returns
    -------
    pd.DataFrame
        Tabella con 'opera', 'token_totali', 'corretti' e 'accuracy' (%).
    """

    # Sanity‑check di base
    if not (len(opera_names) == len(tree_dfs) == len(gorman_dfs)):
        raise ValueError(
            "Le liste opera_names, tree_dfs e gorman_dfs devono avere la stessa lunghezza."
        )

    risultati = []
    global_correct = 0
    global_total = 0

    for name, df_tt, df_go in zip(opera_names, tree_dfs, gorman_dfs):
        # Allineamento indici (non si sa mai)
        df_tt = df_tt.reset_index(drop=True)
        df_go = df_go.reset_index(drop=True)

        # Controllo lunghezza
        if len(df_tt) != len(df_go):
            print(f"\nWARNING: Lunghezza disallineata per '{name}': {len(df_tt)} token in TreeTagger vs {len(df_go)} in Gorman.")
            print(f"Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.")
            
            # Trova dove inizia il disallineamento
            min_len = min(len(df_tt), len(df_go))
            mismatch_found = False
            
            # Controlla i token per trovare il punto di disallineamento
            for i in range(min_len):
                if df_tt.iloc[i]['form'] != df_go.iloc[i]['@form']:
                    mismatch_found = True
                    print(f"\nDisallineamento trovato all'indice {i}:")
                    print(f"TreeTagger: {df_tt.iloc[i]['form']}")
                    print(f"Gorman: {df_go.iloc[i]['@form']}")
                    
                    # Mostra alcune righe prima e dopo il disallineamento
                    context_size = 5
                    start_idx = max(0, i - context_size)
                    end_idx = min(min_len, i + context_size + 1)
                    
                    print(f"\nContesto TreeTagger (indici {start_idx}-{end_idx-1}):")
                    print(df_tt.iloc[start_idx:end_idx][['form', 'pos']].to_string())
                    
                    print(f"\nContesto Gorman (indici {start_idx}-{end_idx-1}):")
                    print(df_go.iloc[start_idx:end_idx][['@form', '@postag']].to_string())
                    
                    break
            
            if not mismatch_found:
                print("\nNessun disallineamento trovato nei token comuni. Probabilmente uno dei file ha token aggiuntivi alla fine.")
                
            # Usa la lunghezza minima per il confronto
            df_tt = df_tt.iloc[:min_len].reset_index(drop=True)
            df_go = df_go.iloc[:min_len].reset_index(drop=True)

        # Confronto POS
        correct = (df_tt['pos'] == df_go['@postag']).sum()
        total = len(df_tt)
        acc = round((correct / total) * 100, 2)  # percentuale con 2 decimali

        risultati.append({
            'opera': name,
            'token_totali': total,
            'corretti': correct,
            'accuracy': acc
        })

        global_correct += correct
        global_total += total

    df_risultati = pd.DataFrame(risultati).sort_values('opera').reset_index(drop=True)

    overall_acc = round((global_correct / global_total) * 100, 2) if global_total else None
    print(f"\nAccuracy complessiva sulle opere: {overall_acc}%")

    return df_risultati

# %%
opera_names_final = [x[:-4] for x in opera_names]
print(opera_names_final)
# Out:
# ['aeschines-1-1-50-bu1', 'aeschines-1-101-150-bu1', 'aeschines-1-151-196-bu1', 'aeschines-1-51-100-bu1', 'antiphon-1-bu2', 'antiphon-2-bu2', 'antiphon-5-bu2', 'antiphon-6-bu2', 'appian-bc-1-0-1-4-bu1', 'appian-bc-1-11-14-bu1', 'appian-bc-1-5-7-bu1', 'appian-bc-1-8-10-bu1', 'aristotle-politics-book-1-bu1', 'aristotle-politics-book-2-bu2', 'athen12-1-9-2019', 'athen12-10-19-2019', 'athen12-20-29-2019', 'athen12-30-39-jan-15', 'athen12-40-49-jan-15', 'athen12-50-59-jan-15', 'athen12-60-69-jan-15', 'athen12-70-81-jan-15', 'athen13-1-9-jan-15', 'athen13-10-19-jan-15', 'athen13-20-29-jan-15', 'athen13-30-39-jan-15', 'athen13-40-49-jan-15', 'athen13-50-59-jan-15', 'athen13-60-69-jan-15', 'athen13-70-79-jan-15', 'athen13-80-89-jan-15', 'athen13-90-95-jan-15', 'dem-59-neaira-2019', 'demosthenes-1-bu1', 'demosthenes-18-1-50-bu2', 'demosthenes-18-101-150-bu2', 'demosthenes-18-151-200-bu2', 'demosthenes-18-201-275-bu1', 'demosthenes-18-276-324-bu1', 'demosthenes-18-51-100-bu1', 'demosthenes-4-phil1-bu1', 'demosthenes-46-tree', 'demosthenes-47-tree', 'demosthenes-49-tree', 'demosthenes-50-tree', 'demosthenes-52-tree', 'demosthenes-53-tree', 'diodsic-11-1-20-bu4', 'diodsic-11-81-92-bu1', 'diodsic11-21-40-bu2', 'diodsic11-41-60-bu1', 'diodsic11-61-80-bu1', 'dion-hal-1-1-15-bu2', 'dion-hal-1-16-30-bu1', 'dion-hal-1-31-45-bu1', 'dion-hal-1-46-60-bu1', 'dion-hal-1-61-75-bu1', 'dion-hal-1-76-90-bu1', 'hdt-1-1-19-bu3-2019', 'hdt-1-100-119-bu3-2019', 'hdt-1-120-149-bu2-2019', 'hdt-1-150-169-bu3-2019', 'hdt-1-170-189-bu2-2019', 'hdt-1-190-216-bu2-2019', 'hdt-1-20-39-bu2-2019', 'hdt-1-40-59-bu2-2019', 'hdt-1-60-79-bu2-2019', 'hdt-1-80-99-bu5-2019', 'josephus-bj-1-1-2-bu1', 'josephus-bj-1-11-15-bu1', 'josephus-bj-1-16-20-bu1', 'josephus-bj-1-21-25-bu1', 'josephus-bj-1-3-5-bu2', 'josephus-bj-1-6-10-bu1', 'lysias-1-bu1', 'lysias-12-bu1', 'lysias-13-bu1', 'lysias-14-bu1', 'lysias-15', 'lysias-19-bu1', 'lysias-23-bu1', 'plato-apology', 'plut-alcib-1-17-bu1', 'plut-alcib-18-39-bu1', 'plut-fortuna-romanorum-bu1', 'plutarch-alex-fort-aut-virt-bu2', 'plutarch-lycurgus-1-15-bu4', 'plutarch-lycurgus-16-31-bu2', 'polybius-10-1-10-bu1', 'polybius-10-11-20-bu1', 'polybius-10-21-35-bu2', 'polybius-10-36-49-bu1', 'polybius-2-1-10-bu1', 'polybius-2-11-20-bu1', 'polybius-2-21-30-bu2', 'polybius-2-31-40-bu2', 'polybius-2-41-50-bu1', 'polybius-2-51-60-bu1', 'polybius-2-61-71-bu2', 'polybius-21-1-10-bu1', 'polybius-21-11-20-bu1', 'polybius-21-21-30-bu1', 'polybius-21-31-47-bu1', 'polybius-6-16-30-bu1', 'polybius-6-2-15-bu1', 'polybius-6-31-45-bu1', 'polybius-6-46-58-bu1', 'polybius-9-1-20-bu1', 'polybius-9-21-33-bu1', 'polybius-9-34-45-bu1', 'polybius1-1-9-2017', 'polybius1-10-19-2017', 'polybius1-20-29-2017', 'polybius1-30-39-2017', 'polybius1-40-49-2017', 'polybius1-50-59-2017', 'polybius1-60-69-2017', 'polybius1-70-79-2017', 'polybius1-80-88-2017', 'ps-xen-ath-pol-bu2', 'thuc-1-1-20-bu5', 'thuc-1-101-120-bu2', 'thuc-1-121-146-bu3', 'thuc-1-21-40-bu4', 'thuc-1-41-60-bu3', 'thuc-1-61-80-bu3', 'thuc-1-81-100-bu2', 'thuc-3-1-20-bu1', 'thuc-3-21-40-bu1', 'xen-cyr-1-1-2-bu1', 'xen-cyr-1-3-4-bu1', 'xen-cyr-1-5-bu1', 'xen-cyr-1-6-bu1', 'xen-cyr-7-1-3-tree', 'xen-cyr-7-4-5-tree', 'xen-cyr-8-1-8-4-bu1', 'xen-cyr-8-5-7-bu1', 'xen-cyr-8-8-bu1', 'xen-hell-1-1-4-bu2', 'xen-hell-1-5-7-bu1', 'xen-hell-2-bu1', 'xen-hell-3-bu1']

# %%
import re

regex_number   = r'^(?:[0-9]|1[0-9]|20)$'
# regex per “[0]”–“[20]”
regex_bracketed = r'^\[(?:[0-9]|1[0-9]|20)\]$'

for idx, df in enumerate(gorman_dfs):
    # prendo la colonna @form, tolgo NaN e spazi esterni
    s = df['@form'].fillna('').str.strip()

    # costruisco la maschera di righe DA RIMUOVERE:
    to_remove = (
        s.isin(['[', ']'])            # parentesi isolate
        | s.str.match(regex_number)   # numero “nudo” 0–20
        | s.str.match(regex_bracketed)# “[n]” con n 0–20
    )

    # filtro e riscrivo in dfs
    gorman_dfs[idx] = df[~to_remove]

# %%
import re

regex_number   = r'^(?:[0-9]|1[0-9]|20)$'
# regex per “[0]”–“[20]”
regex_bracketed = r'^\[(?:[0-9]|1[0-9]|20)\]$'

for idx, df in enumerate(lista_risultati_treetagger):
    # prendo la colonna @form, tolgo NaN e spazi esterni
    s = df['form'].fillna('').str.strip()

    # costruisco la maschera di righe DA RIMUOVERE:
    to_remove = (
        s.isin(['[', ']'])            # parentesi isolate
        | s.str.match(regex_number)   # numero “nudo” 0–20
        | s.str.match(regex_bracketed)# “[n]” con n 0–20
    )

    # filtro e riscrivo in dfs
    lista_risultati_treetagger[idx] = df[~to_remove]

# %%
# Stampa le lunghezze per conferma
print("Lunghezze:")
print(f"opera_names_final: {len(opera_names_final)}")
print(f"lista_risultati_treetagger: {len(lista_risultati_treetagger)}")

# Confronta gli elementi per indice
min_len = min(len(opera_names_final), len(lista_risultati_treetagger))

for i in range(min_len):
    if not isinstance(lista_risultati_treetagger[i], type(gorman_dfs[i])):
        print(f"[Indice {i}] - Possibile mismatch tipo dati")
    # Se hai modo di confrontare contenuti, potresti farlo qui

# Controlla l'elemento extra se c'è davvero una differenza di lunghezza
if len(lista_risultati_treetagger) > len(opera_names_final):
    print("\nElemento extra in lista_risultati_treetagger:")
    extra = lista_risultati_treetagger[len(opera_names_final)]
    print(f"Indice: {len(opera_names_final)}")
    print(f"Contenuto:\n{extra}")
elif len(opera_names_final) > len(lista_risultati_treetagger):
    print("\nElemento extra in opera_names_final:")
    extra = opera_names_final[len(lista_risultati_treetagger)]
    print(f"Indice: {len(lista_risultati_treetagger)}")
    print(f"Contenuto:\n{extra}")
else:
    print("\nNessuna differenza di lunghezza.")
# Out:
# Lunghezze:
# opera_names_final: 142
# lista_risultati_treetagger: 142
#
# Nessuna differenza di lunghezza.

# %%
# lista_risultati_treetagger.pop(5)
# opera_names_final.pop(5)
# gorman_dfs.pop(5)
# lista_risultati_treetagger.pop(6)
# opera_names_final.pop(6)
# gorman_dfs.pop(6)
# # Lista delle opere da rimuovere
# target_names = ['athen12-30-39-jan-15','athen13-60-69-jan-15', 'athen13-30-39-jan-15', 'athen13-40-49-jan-15', 'athen13-80-89-jan-15', 'dem-59-neaira-2019', 'demosthenes-1-bu1', 'demosthenes-18-201-275-bu1', 'demosthenes-18-276-324-bu1', 'demosthenes-46-tree', 'demosthenes-47-tree', 'demosthenes-49-tree', 'demosthenes-50-tree', 'demosthenes-52-tree', 'demosthenes-53-tree','lysias-13-bu1', 'plut-alcib-1-17-bu1', 'plutarch-lycurgus-1-15-bu4', 'plutarch-lycurgus-16-31-bu2','polybius-21-31-47-bu1', 'polybius1-30-39-2017', 'polybius1-40-49-2017', 'polybius1-50-59-2017', 'ps-xen-ath-pol-bu2', 'thuc-1-121-146-bu3', 'thuc-1-41-60-bu3', 'thuc-1-61-80-bu3', 'xen-cyr-7-1-3-tree', 'xen-cyr-7-4-5-tree']

# # Ciclo per rimuoverle da tutte le liste
# for name in target_names:
#     if name in opera_names_final:
#         idx = opera_names_final.index(name)
#         opera_names_final.pop(idx)
#         lista_risultati_treetagger.pop(idx)
#         gorman_dfs.pop(idx)
#         print(f"Rimossa: {name}")
#     else:
#         print(f"{name} non trovato!")


df_accuracy = compute_accuracy_per_opera(opera_names_final, lista_risultati_treetagger, gorman_dfs)

#df_accuracy.to_csv('accuracy_per_opera_sporchi.csv', index=False)
# Out:
# WARNING: Lunghezza disallineata per 'antiphon-2-bu2': 2887 token in TreeTagger vs 2912 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 160:
# TreeTagger: :
# Gorman: <
#
# Contesto TreeTagger (indici 155-165):
#           form pos
# 155         ὡς   c
# 156  ἀπέκτεινε   v
# 157        τὸν   l
# 158      ἄνδρα   n
# 159          .   u
# 160          :   v
# 161     οὐδεὶς   p
# 162        γὰρ   g
# 163         ἂν   d
# 164        τὸν   l
# 165    ἔσχατον   a
#
# Contesto Gorman (indici 155-165):
#           @form @postag
# 155          ὡς       c
# 156   ἀπέκτεινε       v
# 157         τὸν       l
# 158       ἄνδρα       n
# 159           .       u
# 160           <       u
# 161          Οὔ       d
# 162         -τε       d
# 163         γὰρ       d
# 164  κακούργους       a
# 165       εἰκὸς       v
#
# WARNING: Lunghezza disallineata per 'antiphon-6-bu2': 3944 token in TreeTagger vs 3987 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 25:
# TreeTagger: ἄρα
# Gorman: <
#
# Contesto TreeTagger (indici 20-30):
#            form pos
# 20          τις   p
# 21        ταῦτα   p
# 22      εὔξαιτο   v
# 23            :   v
# 24           εἰ   c
# 25          ἄρα   g
# 26          τις   p
# 27          καὶ   c
# 28  ἀναγκάζοιτο   v
# 29  κινδυνεύειν   v
# 30            ,   u
#
# Contesto Gorman (indici 20-30):
#       @form @postag
# 20      τις       p
# 21    ταῦτα       p
# 22  εὔξαιτο       v
# 23        :       u
# 24       εἰ       c
# 25        <       u
# 26       δ᾽       d
# 27        >       u
# 28      ἄρα       d
# 29      τις       p
# 30      καὶ       d
#
# WARNING: Lunghezza disallineata per 'athen12-30-39-jan-15': 1922 token in TreeTagger vs 1921 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 104:
# TreeTagger: .
# Gorman: ..
#
# Contesto TreeTagger (indici 99-109):
#            form      pos
# 99         ἀμφὶ        r
# 100   βραχίοσιν        n
# 101        ἦσαν        v
# 102         ...        u
# 103          ->  unknown
# 104           .        u
# 105           .        u
# 106         τες  unknown
# 107  ὑπασπίδιον        a
# 108  πολεμιστήν        n
# 109           .        u
#
# Contesto Gorman (indici 99-109):
#           @form @postag
# 99         ἀμφὶ       r
# 100   βραχίοσιν       a
# 101        ἦσαν       v
# 102         ...       -
# 103          ->       -
# 104          ..       -
# 105         τες       -
# 106  ὑπασπίδιον       a
# 107  πολεμιστήν       n
# 108           .       u
# 109  Ἡρακλείδης       n
#
# WARNING: Lunghezza disallineata per 'athen13-40-49-jan-15': 3319 token in TreeTagger vs 3318 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 211:
# TreeTagger: --
# Gorman: ---
#
# Contesto TreeTagger (indici 206-216):
#          form pos
# 206       καὶ   c
# 207   πολίτας   n
# 208       καὶ   c
# 209    ξένους   n
# 210    ἔχουσ᾽   v
# 211        --   u
# 212         -   u
# 213      ὅπου   d
# 214      περὶ   r
# 215       τῆς   l
# 216  γυναικός   n
#
# Contesto Gorman (indici 206-216):
#         @form @postag
# 206       καὶ       d
# 207   πολίτας       n
# 208       καὶ       c
# 209    ξένους       n
# 210    ἔχουσ᾽       v
# 211       ---       u
# 212      ὅπου       d
# 213      περὶ       r
# 214       τῆς       l
# 215  γυναικός       n
# 216       τις       a
#
# WARNING: Lunghezza disallineata per 'athen13-60-69-jan-15': 2404 token in TreeTagger vs 2403 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 2296:
# TreeTagger: ...
# Gorman: ...,
#
# Contesto TreeTagger (indici 2291-2301):
#           form      pos
# 2291        ὧν        p
# 2292  μέμνηται        v
# 2293  Κρατῖνος        n
# 2294       διὰ        r
# 2295    τούτων        p
# 2296       ...  unknown
# 2297         ,        u
# 2298       εἰς        r
# 2299        δὲ        d
# 2300       τὴν        l
# 2301   Δωρίχαν        a
#
# Contesto Gorman (indici 2291-2301):
#          @form @postag
# 2291        ὧν       p
# 2292  μέμνηται       v
# 2293  Κρατῖνος       n
# 2294       διὰ       r
# 2295    τούτων       p
# 2296      ...,       -
# 2297       εἰς       r
# 2298        δὲ       d
# 2299       τὴν       l
# 2300   Δωρίχαν       n
# 2301      τόδ᾽       a
#
# WARNING: Lunghezza disallineata per 'athen13-80-89-jan-15': 3065 token in TreeTagger vs 3062 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 380:
# TreeTagger: :
# Gorman: :
#
# Contesto TreeTagger (indici 375-385):
#            form pos
# 375       δῆλος   a
# 376          ἦν   v
# 377  πτοεόμενος   a
# 378        εἶπέ   v
# 379          τε   c
# 380           :   v
# 381      βούλει   v
# 382          με   p
# 383       ἡδέως   d
# 384      πίνειν   v
# 385           ;   u
#
# Contesto Gorman (indici 375-385):
#           @form @postag
# 375       δῆλος       a
# 376          ἦν       v
# 377  πτοεόμενος       v
# 378        εἶπέ       v
# 379          τε       d
# 380          :        u
# 381      βούλει       v
# 382          με       p
# 383       ἡδέως       d
# 384      πίνειν       v
# 385           ;       u
#
# WARNING: Lunghezza disallineata per 'dem-59-neaira-2019': 10615 token in TreeTagger vs 10486 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 3722:
# TreeTagger: δ
# Gorman: δ’
#
# Contesto TreeTagger (indici 3717-3727):
#          form      pos
# 3717  ταυτησὶ        a
# 3718     αὕτη        p
# 3719    ἐστίν        v
# 3720        .        u
# 3721      ὅτι        c
# 3722        δ  unknown
# 3723        ’  unknown
# 3724    ἀληθῆ        a
# 3725     λέγω        v
# 3726    ταῦτα        p
# 3727        ,        u
#
# Contesto Gorman (indici 3717-3727):
#         @form @postag
# 3717  ταυτησὶ       a
# 3718     αὕτη       p
# 3719    ἐστίν       v
# 3720        .       u
# 3721      ὅτι       c
# 3722       δ’       d
# 3723    ἀληθῆ       a
# 3724     λέγω       v
# 3725    ταῦτα       p
# 3726        ,       u
# 3727   τούτων       p
#
# WARNING: Lunghezza disallineata per 'demosthenes-1-bu1': 2318 token in TreeTagger vs 2193 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 28:
# TreeTagger: τοῦθ
# Gorman: τοῦθ’
#
# Contesto TreeTagger (indici 23-33):
#         form pos
# 23      νυνὶ   d
# 24  σκοπεῖτε   v
# 25         .   u
# 26       ὅτε   c
# 27    τοίνυν   d
# 28      τοῦθ   v
# 29         ’   u
# 30     οὕτως   d
# 31      ἔχει   v
# 32         ,   u
# 33  προσήκει   v
#
# Contesto Gorman (indici 23-33):
#        @form @postag
# 23      νυνὶ       d
# 24  σκοπεῖτε       v
# 25         .       u
# 26       ὅτε       c
# 27    τοίνυν       d
# 28     τοῦθ’       p
# 29     οὕτως       d
# 30      ἔχει       v
# 31         ,       u
# 32  προσήκει       v
# 33  προθύμως       d
#
# WARNING: Lunghezza disallineata per 'demosthenes-18-201-275-bu1': 5644 token in TreeTagger vs 5642 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 966:
# TreeTagger: '
# Gorman: 'πεπόνθεσαν
#
# Contesto TreeTagger (indici 961-971):
#            form pos
# 961           ,   u
# 962      ἠξίουν   v
# 963          ὧν   p
# 964         μὲν   d
# 965          εὖ   d
# 966           '   v
# 967  πεπόνθεσαν   v
# 968         ὑπὸ   r
# 969    Φιλίππου   n
# 970       χάριν   r
# 971      αὐτοὺς   p
#
# Contesto Gorman (indici 961-971):
#            @form @postag
# 961            ,       u
# 962       ἠξίουν       v
# 963           ὧν       p
# 964          μὲν       d
# 965           εὖ       d
# 966  'πεπόνθεσαν       v
# 967          ὑπὸ       r
# 968     Φιλίππου       n
# 969        χάριν       n
# 970       αὐτοὺς       p
# 971    ἀποδοῦναι       v
#
# WARNING: Lunghezza disallineata per 'demosthenes-18-276-324-bu1': 3858 token in TreeTagger vs 3857 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 220:
# TreeTagger: κ
# Gorman: κ'
#
# Contesto TreeTagger (indici 215-225):
#          form pos
# 215     οὐδὲν   p
# 216       τῶν   l
# 217  τοιούτων   a
# 218       τὸν   l
# 219     καλὸν   a
# 220         κ   r
# 221         '   n
# 222    ἀγαθὸν   a
# 223   πολίτην   n
# 224       δεῖ   v
# 225      τοὺς   l
#
# Contesto Gorman (indici 215-225):
#         @form @postag
# 215     οὐδὲν       p
# 216       τῶν       l
# 217  τοιούτων       p
# 218       τὸν       l
# 219     καλὸν       a
# 220        κ'       c
# 221    ἀγαθὸν       a
# 222   πολίτην       n
# 223       δεῖ       v
# 224      τοὺς       l
# 225      ὑπὲρ       r
#
# WARNING: Lunghezza disallineata per 'demosthenes-46-tree': 2204 token in TreeTagger vs 2160 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 58:
# TreeTagger: τ
# Gorman: τ’
#
# Contesto TreeTagger (indici 53-63):
#             form pos
# 53     Φορμίωνος   n
# 54        πολλοί   a
# 55             ·   u
# 56         εἰσιν   v
# 57           ἅμα   d
# 58             τ   v
# 59             ’   u
# 60         εἰκός   v
# 61          ἐστι   v
# 62          τοὺς   l
# 63  ἐγχειροῦντας   v
#
# Contesto Gorman (indici 53-63):
#            @form @postag
# 53     Φορμίωνος       n
# 54        πολλοί       a
# 55             ·       u
# 56         εἰσιν       v
# 57           ἅμα       d
# 58            τ’       d
# 59         εἰκός       v
# 60          ἐστι       v
# 61          τοὺς       l
# 62  ἐγχειροῦντας       v
# 63            τὰ       l
#
# WARNING: Lunghezza disallineata per 'demosthenes-47-tree': 6326 token in TreeTagger vs 6227 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 49:
# TreeTagger: ἀλλ
# Gorman: ἀλλ’
#
# Contesto TreeTagger (indici 44-54):
#              form      pos
# 44          μηδὲν        p
# 45           αὐτῷ        p
# 46          πλέον        a
# 47        γένηται        v
# 48              ,        u
# 49            ἀλλ        v
# 50              ’  unknown
# 51  ἐπισκηψάμενος        v
# 52           ταῖς        l
# 53     μαρτυρίαις        n
# 54              ὁ        l
#
# Contesto Gorman (indici 44-54):
#             @form @postag
# 44          μηδὲν       p
# 45           αὐτῷ       p
# 46          πλέον       a
# 47        γένηται       v
# 48              ,       u
# 49           ἀλλ’       c
# 50  ἐπισκηψάμενος       v
# 51           ταῖς       l
# 52     μαρτυρίαις       n
# 53              ὁ       l
# 54      ἀδικηθεὶς       v
#
# WARNING: Lunghezza disallineata per 'demosthenes-49-tree': 5079 token in TreeTagger vs 5000 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 19:
# TreeTagger: ὑπ
# Gorman: ὑπ’
#
# Contesto TreeTagger (indici 14-24):
#       form pos
# 14   πατρὶ   n
# 15      τῷ   l
# 16     ἐμῷ   a
# 17  φεύγει   v
# 18     νῦν   d
# 19      ὑπ   v
# 20       ’   u
# 21    ἐμοῦ   p
# 22  ταύτην   p
# 23     τὴν   l
# 24   δίκην   n
#
# Contesto Gorman (indici 14-24):
#      @form @postag
# 14   πατρὶ       n
# 15      τῷ       l
# 16     ἐμῷ       a
# 17  φεύγει       v
# 18     νῦν       d
# 19     ὑπ’       r
# 20    ἐμοῦ       p
# 21  ταύτην       a
# 22     τὴν       l
# 23   δίκην       n
# 24       .       u
#
# WARNING: Lunghezza disallineata per 'demosthenes-50-tree': 5412 token in TreeTagger vs 5303 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 191:
# TreeTagger: δ
# Gorman: δ’
#
# Contesto TreeTagger (indici 186-196):
#        form      pos
# 186  λέγειν        v
# 187    πρὸς        r
# 188    ὑμᾶς        p
# 189       ·        u
# 190      εἰ        c
# 191       δ  unknown
# 192       ’  unknown
# 193   ἐστὶν        v
# 194   ἀληθῆ        a
# 195     καὶ        c
# 196  μηδεὶς        p
#
# Contesto Gorman (indici 186-196):
#       @form @postag
# 186  λέγειν       v
# 187    πρὸς       r
# 188    ὑμᾶς       p
# 189       ·       u
# 190      εἰ       c
# 191      δ’       d
# 192   ἐστὶν       v
# 193   ἀληθῆ       a
# 194     καὶ       c
# 195  μηδεὶς       p
# 196      ἄν       d
#
# WARNING: Lunghezza disallineata per 'demosthenes-52-tree': 2519 token in TreeTagger vs 2484 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 69:
# TreeTagger: ἐφ
# Gorman: ἐφ’
#
# Contesto TreeTagger (indici 64-74):
#              form      pos
# 64      πιστεύειν        v
# 65              ἢ        c
# 66           τοῖς        l
# 67  ἀδυνατωτέροις        a
# 68              ,        u
# 69             ἐφ        v
# 70              ’  unknown
# 71           ὑμῖν        p
# 72         αὐτοῖς        p
# 73         ἔσεσθε        v
# 74             τὸ        l
#
# Contesto Gorman (indici 64-74):
#             @form @postag
# 64      πιστεύειν       v
# 65              ἢ       c
# 66           τοῖς       l
# 67  ἀδυνατωτέροις       a
# 68              ,       u
# 69            ἐφ’       r
# 70           ὑμῖν       p
# 71         αὐτοῖς       a
# 72         ἔσεσθε       v
# 73             τὸ       l
# 74           ἔθος       n
#
# WARNING: Lunghezza disallineata per 'demosthenes-53-tree': 2394 token in TreeTagger vs 2336 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 5:
# TreeTagger: ἀλλ
# Gorman: ἀλλ’
#
# Contesto TreeTagger (indici 0-10):
#            form      pos
# 0           ὅτι        c
# 1           μὲν        d
# 2            οὐ        d
# 3    συκοφαντῶν        v
# 4             ,        u
# 5           ἀλλ        v
# 6             ’  unknown
# 7   ἀδικούμενος        v
# 8           καὶ        c
# 9   ὑβριζόμενος        v
# 10          ὑπὸ        r
#
# Contesto Gorman (indici 0-10):
#           @form @postag
# 0           ὅτι       c
# 1           μὲν       d
# 2            οὐ       d
# 3    συκοφαντῶν       v
# 4             ,       u
# 5          ἀλλ’       c
# 6   ἀδικούμενος       v
# 7           καὶ       d
# 8   ὑβριζόμενος       v
# 9           ὑπὸ       r
# 10       τούτων       p
#
# WARNING: Lunghezza disallineata per 'lysias-13-bu1': 5615 token in TreeTagger vs 5614 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 2808:
# TreeTagger: ὅτ
# Gorman: ὅτ'
#
# Contesto TreeTagger (indici 2803-2813):
#             form pos
# 2803         εἰς   r
# 2804         τὴν   l
# 2805      βουλὴν   n
# 2806  κομισθῆναι   v
# 2807           ,   u
# 2808          ὅτ   a
# 2809           '   v
# 2810         ἐπὶ   r
# 2811         τοῦ   l
# 2812       βωμοῦ   n
# 2813     ἐκάθητο   v
#
# Contesto Gorman (indici 2803-2813):
#            @form @postag
# 2803         εἰς       r
# 2804         τὴν       l
# 2805      βουλὴν       n
# 2806  κομισθῆναι       v
# 2807           ,       u
# 2808         ὅτ'       c
# 2809         ἐπὶ       r
# 2810         τοῦ       l
# 2811       βωμοῦ       n
# 2812     ἐκάθητο       v
# 2813  Μουνιχίασι       d
#
# WARNING: Lunghezza disallineata per 'plut-alcib-1-17-bu1': 4406 token in TreeTagger vs 4405 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 3871:
# TreeTagger: '
# Gorman: 'ν
#
# Contesto TreeTagger (indici 3866-3876):
#          form pos
# 3866        ·   u
# 3867  μάλιστα   d
# 3868      μὲν   g
# 3869   λέοντα   n
# 3870       μὴ   d
# 3871        '   v
# 3872        ν   r
# 3873    πόλει   n
# 3874  τρέφειν   v
# 3875        ·   u
# 3876       ἢν   c
#
# Contesto Gorman (indici 3866-3876):
#         @form @postag
# 3866        ·       u
# 3867  μάλιστα       d
# 3868      μὲν       d
# 3869   λέοντα       n
# 3870       μὴ       d
# 3871       'ν       r
# 3872    πόλει       n
# 3873  τρέφειν       v
# 3874        ·       u
# 3875       ἢν       c
# 3876       δʼ       d
#
# WARNING: Lunghezza disallineata per 'plutarch-lycurgus-1-15-bu4': 5302 token in TreeTagger vs 5301 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 1687:
# TreeTagger: δ
# Gorman: δ'
#
# Contesto TreeTagger (indici 1682-1692):
#              form      pos
# 1682          τῆς        l
# 1683       γνώμης        n
# 1684  μετασχόντας        v
# 1685            .        u
# 1686          εἴη        v
# 1687            δ  unknown
# 1688            '        v
# 1689           ἂν        d
# 1690           τι        p
# 1691          καὶ        c
# 1692           τὸ        l
#
# Contesto Gorman (indici 1682-1692):
#             @form @postag
# 1682          τῆς       l
# 1683       γνώμης       n
# 1684  μετασχόντας       v
# 1685            .       u
# 1686          εἴη       v
# 1687           δ'       d
# 1688           ἂν       d
# 1689           τι       p
# 1690          καὶ       d
# 1691           τὸ       l
# 1692          τοῦ       l
#
# WARNING: Lunghezza disallineata per 'plutarch-lycurgus-16-31-bu2': 5339 token in TreeTagger vs 5337 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 2055:
# TreeTagger: -
# Gorman: - - -
#
# Contesto TreeTagger (indici 2050-2060):
#            form pos
# 2050      μοῦσα   n
# 2051     λίγεια   a
# 2052        καὶ   c
# 2053       δίκα   n
# 2054  εὐρυάγυια   a
# 2055          -   u
# 2056          -   u
# 2057          -   u
# 2058   Πίνδαρος   n
# 2059         δέ   g
# 2060      φησιν   v
#
# Contesto Gorman (indici 2050-2060):
#           @form @postag
# 2050      μοῦσα       n
# 2051     λίγεια       a
# 2052        καὶ       c
# 2053       δίκα       n
# 2054  εὐρυάγυια       a
# 2055      - - -       u
# 2056   Πίνδαρος       n
# 2057         δέ       d
# 2058      φησιν       v
# 2059          :       u
# 2060       ἔνθα       d
#
# WARNING: Lunghezza disallineata per 'polybius-21-31-47-bu1': 3985 token in TreeTagger vs 3982 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 878:
# TreeTagger: περιεβα
# Gorman: περιεβα...
#
# Contesto TreeTagger (indici 873-883):
#             form pos
# 873     νουνεχὴς   a
# 874           ὢν   v
# 875          καὶ   c
# 876  στρατηγικός   a
# 877            ,   u
# 878      περιεβα   v
# 879          ...   u
# 880      γένοιτο   v
# 881       κομιδὴ   n
# 882          τῶν   l
# 883          ἔξω   d
#
# Contesto Gorman (indici 873-883):
#            @form @postag
# 873     νουνεχὴς       a
# 874           ὢν       v
# 875          καὶ       c
# 876  στρατηγικός       a
# 877            ,       u
# 878   περιεβα...     NaN
# 879      γένοιτο       v
# 880       κομιδὴ       n
# 881          τῶν       l
# 882          ἔξω       d
# 883  ποριζομένων       v
#
# WARNING: Lunghezza disallineata per 'polybius1-30-39-2017': 3200 token in TreeTagger vs 3199 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 1557:
# TreeTagger: '
# Gorman: 'κείνῳ
#
# Contesto TreeTagger (indici 1552-1562):
#              form pos
# 1552       ὀλίγον   a
# 1553   ὑποχείριοι   a
# 1554    γενόμενοι   v
# 1555          σὺν   r
# 1556         αὐτῷ   p
# 1557            '   v
# 1558        κείνῳ   a
# 1559       πάντες   a
# 1560  ἐζωγρήθησαν   v
# 1561            .   u
# 1562          τῶν   l
#
# Contesto Gorman (indici 1552-1562):
#             @form @postag
# 1552       ὀλίγον       a
# 1553   ὑποχείριοι       a
# 1554    γενόμενοι       v
# 1555          σὺν       r
# 1556         αὐτῷ       a
# 1557       'κείνῳ       p
# 1558       πάντες       a
# 1559  ἐζωγρήθησαν       v
# 1560            .       u
# 1561          τῶν       l
# 1562          μὲν       d
#
# WARNING: Lunghezza disallineata per 'polybius1-40-49-2017': 3440 token in TreeTagger vs 3439 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 686:
# TreeTagger: '
# Gorman: 'κείνη
#
# Contesto TreeTagger (indici 681-691):
#            form pos
# 681        αὐτῷ   p
# 682   διαφέρειν   v
# 683     ἀλλήλων   a
# 684           ,   u
# 685           ᾗ   p
# 686           '   v
# 687       κείνη   a
# 688         μὲν   d
# 689  χερρόνησός   n
# 690       ἐστιν   v
# 691           ,   u
#
# Contesto Gorman (indici 681-691):
#           @form @postag
# 681        αὐτῷ       a
# 682   διαφέρειν       v
# 683     ἀλλήλων       p
# 684           ,       u
# 685           ᾗ       p
# 686      'κείνη       p
# 687         μὲν       d
# 688  χερρόνησός       n
# 689       ἐστιν       v
# 690           ,       u
# 691        αὕτη       p
#
# WARNING: Lunghezza disallineata per 'polybius1-50-59-2017': 3026 token in TreeTagger vs 3025 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 2536:
# TreeTagger: '
# Gorman: 'κείνους
#
# Contesto TreeTagger (indici 2531-2541):
#              form pos
# 2531            .   u
# 2532        ὄντες   v
# 2533     πρότερον   a
# 2534          γὰρ   d
# 2535            ἢ   c
# 2536            '   v
# 2537      κείνους   p
# 2538      ἀλλήλων   p
# 2539  ἐπικρατῆσαι   v
# 2540            ,   u
# 2541       καίπερ   d
#
# Contesto Gorman (indici 2531-2541):
#             @form @postag
# 2531            .       u
# 2532        ὄντες       v
# 2533     πρότερον       a
# 2534          γὰρ       d
# 2535            ἢ       c
# 2536     'κείνους       p
# 2537      ἀλλήλων       p
# 2538  ἐπικρατῆσαι       v
# 2539            ,       u
# 2540       καίπερ       d
# 2541          δύ᾽       a
#
# WARNING: Lunghezza disallineata per 'ps-xen-ath-pol-bu2': 3671 token in TreeTagger vs 3711 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 73:
# TreeTagger: αὐτόθι
# Gorman: <
#
# Contesto TreeTagger (indici 68-78):
#        form pos
# 68    τοῦτο   p
# 69      ἐρῶ   v
# 70        ,   u
# 71      ὅτι   c
# 72  δικαίως   d
# 73   αὐτόθι   d
# 74      καὶ   d
# 75       οἱ   l
# 76  πένητες   n
# 77      καὶ   c
# 78        ὁ   l
#
# Contesto Gorman (indici 68-78):
#        @form @postag
# 68     τοῦτο       p
# 69       ἐρῶ       v
# 70         ,       u
# 71       ὅτι       c
# 72   δικαίως       d
# 73         <       u
# 74  δοκοῦσιν       v
# 75         >       u
# 76    αὐτόθι       d
# 77       καὶ       d
# 78        οἱ       l
#
# WARNING: Lunghezza disallineata per 'thuc-1-121-146-bu3': 5360 token in TreeTagger vs 5366 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 1050:
# TreeTagger: θύματα
# Gorman: <
#
# Contesto TreeTagger (indici 1045-1055):
#           form pos
# 1045     πολλὰ   a
# 1046       οὐχ   d
# 1047    ἱερεῖα   n
# 1048         ,   u
# 1049      ἀλλ᾽   v
# 1050    θύματα   n
# 1051  ἐπιχώρια   a
# 1052         )   u
# 1053         ,   u
# 1054     δοκῶν   v
# 1055        δὲ   g
#
# Contesto Gorman (indici 1045-1055):
#          @form @postag
# 1045     πολλὰ       a
# 1046       οὐχ       d
# 1047    ἱερεῖα       n
# 1048         ,       u
# 1049      ἀλλ᾽       c
# 1050         <       u
# 1051      ἁγνὰ       a
# 1052         >       u
# 1053    θύματα       n
# 1054  ἐπιχώρια       a
# 1055         )       u
#
# WARNING: Lunghezza disallineata per 'thuc-1-41-60-bu3': 2736 token in TreeTagger vs 2739 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 912:
# TreeTagger: τριῶν
# Gorman: <
#
# Contesto TreeTagger (indici 907-917):
#           form pos
# 907        τῶν   l
# 908       νεῶν   n
# 909          ,   u
# 910         ὧν   p
# 911       ἦρχε   v
# 912      τριῶν   a
# 913  στρατηγῶν   n
# 914    ἑκάστου   a
# 915        εἷς   a
# 916          .   u
# 917    ἐπεῖχον   v
#
# Contesto Gorman (indici 907-917):
#          @form @postag
# 907        τῶν       l
# 908       νεῶν       n
# 909          ,       u
# 910         ὧν       p
# 911       ἦρχε       v
# 912          <       u
# 913        τῶν       l
# 914          >       u
# 915      τριῶν       a
# 916  στρατηγῶν       n
# 917    ἑκάστου       a
#
# WARNING: Lunghezza disallineata per 'thuc-1-61-80-bu3': 3790 token in TreeTagger vs 3793 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 3018:
# TreeTagger: τῶν
# Gorman: <
#
# Contesto TreeTagger (indici 3013-3023):
#             form pos
# 3013         καὶ   c
# 3014      ταύτην   p
# 3015          μὴ   d
# 3016     ἀνεῖμεν   v
# 3017         ὑπὸ   r
# 3018         τῶν   l
# 3019    μεγίστων   a
# 3020  νικηθέντες   v
# 3021           ,   u
# 3022       τιμῆς   n
# 3023         καὶ   c
#
# Contesto Gorman (indici 3013-3023):
#            @form @postag
# 3013         καὶ       c
# 3014      ταύτην       p
# 3015          μὴ     NaN
# 3016     ἀνεῖμεν       v
# 3017         ὑπὸ       r
# 3018           <       u
# 3019       τριῶν       a
# 3020           >       u
# 3021         τῶν       l
# 3022    μεγίστων       a
# 3023  νικηθέντες       v
#
# WARNING: Lunghezza disallineata per 'xen-cyr-7-1-3-tree': 5524 token in TreeTagger vs 5395 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 16:
# TreeTagger: ἀμφ
# Gorman: ἀμφ’
#
# Contesto TreeTagger (indici 11-21):
#            form pos
# 11           τῷ   l
# 12           δὲ   d
# 13         Κύρῳ   n
# 14          καὶ   c
# 15         τοῖς   l
# 16          ἀμφ   a
# 17            ’   u
# 18        αὐτὸν   p
# 19  προσήνεγκαν   v
# 20           οἱ   l
# 21   θεράποντες   n
#
# Contesto Gorman (indici 11-21):
#           @form @postag
# 11           τῷ       l
# 12           δὲ       d
# 13         Κύρῳ       n
# 14          καὶ       c
# 15         τοῖς       l
# 16         ἀμφ’       r
# 17        αὐτὸν       p
# 18  προσήνεγκαν       v
# 19           οἱ       l
# 20   θεράποντες       n
# 21     ἐμφαγεῖν       v
#
# WARNING: Lunghezza disallineata per 'xen-cyr-7-4-5-tree': 5504 token in TreeTagger vs 5389 in Gorman.
# Continuando l'esecuzione ma i risultati potrebbero essere inaccurati.
#
# Disallineamento trovato all'indice 55:
# TreeTagger: -δ
# Gorman: -δ’
#
# Contesto TreeTagger (indici 50-60):
#         form pos
# 50        τ-   l
# 51      ἄλλα   a
# 52       οὐκ   d
# 53    ἄφρονα   a
# 54        οὐ   d
# 55        -δ   v
# 56         ’   u
# 57  ἀπόλεμον   a
# 58         ,   u
# 59       καὶ   c
# 60      πάνυ   d
#
# Contesto Gorman (indici 50-60):
#        @form @postag
# 50        τ-       l
# 51      ἄλλα       p
# 52       οὐκ       d
# 53    ἄφρονα       a
# 54        οὐ       d
# 55       -δ’       c
# 56  ἀπόλεμον       a
# 57         ,       u
# 58       καὶ       c
# 59      πάνυ       d
# 60        δὴ       d
#
# Accuracy complessiva sulle opere: 75.44%
